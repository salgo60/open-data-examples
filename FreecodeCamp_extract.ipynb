# %% [markdown]
# target site https://www.football-data.co.uk/englandm.php

# %%
import pandas as pd
url="https://www.football-data.co.uk/englandm.php"
url="https://www.football-data.co.uk/mmz4281/2122/E0.csv"
df_premier21 = pd.read_csv(url, on_bad_lines='skip')

# %%
df_premier21.rename({"FTHG":"home_goals",
                     "FTAG" : "away_goals"},inplace=True)

# %%
df_premier21
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  13/08/2021  20:00       Brentford         Arsenal     2     0   H
# 1    E0  14/08/2021  12:30      Man United           Leeds     5     1   H
# 2    E0  14/08/2021  15:00         Burnley        Brighton     1     2   A
# 3    E0  14/08/2021  15:00         Chelsea  Crystal Palace     3     0   H
# 4    E0  14/08/2021  15:00         Everton     Southampton     3     1   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 375  E0  22/05/2022  16:00  Crystal Palace      Man United     1     0   H
# 376  E0  22/05/2022  16:00       Leicester     Southampton     4     1   H
# 377  E0  22/05/2022  16:00       Liverpool          Wolves     3     1   H
# 378  E0  22/05/2022  16:00        Man City     Aston Villa     3     2   H
# 379  E0  22/05/2022  16:00         Norwich       Tottenham     0     5   A
#
# ...

# %%
import camelot

# %%
tb = camelot.read_pdf("foo.pdf")

# %%
tb.export('foo2.csv', f='csv', compress=True)
tb[0].parsing_report
# Out:
# {'accuracy': 99.02, 'whitespace': 12.24, 'order': 1, 'page': 1}

# %%
tables = camelot.read_pdf('foo.pdf',  flavor='lattice')
print(tables)

tables.export('foo.csv', f='csv', compress=True)
tables[0].to_csv('foo2.csv')  # to a csv file
print(tables[0].df)  # to a df
# Out:
# <TableList n=1>
#               0            1                2                     3  \
# 0  Cycle \nName  KI \n(1/km)  Distance \n(mi)  Percent Fuel Savings
# 1                                                  Improved \nSpeed
# 2        2012_2         3.30              1.3                  5.9%
# 3        2145_1         0.68             11.2                  2.4%
# 4        4234_1         0.59             58.7                  8.5%
# 5        2032_2         0.17             57.8                 21.7%
# 6        4171_1         0.07            173.9                 58.1%
#
#                    4                  5                 6
# 0
# 1  Decreased \nAccel  Eliminate \nStops  Decreased \nIdle
# 2               9.5%              29.2%             17.4%
# 3               0.1%               9.5%              2.7%
# 4               1.3%               8.5%              3.3%
# 5               0.3%               2.7%              1.2%
# ...

# %%
from selenium import webdriver
#from selenium.webdriver.chrome.service import Service
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())

web = 'https://www.thesun.co.uk/sport/football/'
path = '/Users/frankandrade/Downloads/chromedriver'  # introduce path here

# Creating the driver
driver_service = Service(executable_path=path)
#driver = webdriver.Chrome(service=driver_service)
driver = webdriver.Chrome(ChromeDriverManager().install())

driver.get(web)
# Finding Elements
containers = driver.find_elements(by='xpath', value='//div[@class="teaser__copy-container"]')
titles = []
subtitles = []
links = []
for container in containers:
    title = container.find_element(by='xpath', value='./a/h2').text
    subtitle = container.find_element(by='xpath', value='./a/p').text
    link = container.find_element(by='xpath', value='./a').get_attribute('href')
    titles.append(title)
    subtitles.append(subtitle)
    links.append(link)

# Exporting data to a CSV file
my_dict = {'title': titles, 'subtitle': subtitles, 'link': links}
df_headlines = pd.DataFrame(my_dict)
df_headlines.to_csv('headline.csv')

driver.quit()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - About to download new driver from https://chromedriver.storage.googleapis.com/102.0.5005.61/chromedriver_mac64.zip
# [WDM] - Driver has been saved in cache [/Users/magnus/.wdm/drivers/chromedriver/mac64/102.0.5005.61]
# <ipython-input-46-793bc1500ee4>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [/Users/magnus/.wdm/drivers/chromedriver/mac64/102.0.5005.61/chromedriver] found in cache
# <ipython-input-46-793bc1500ee4>:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
# ...

# %%
df_headlines.sample(19)
# Out:
#                       title  \
# 10                  HOT ROD
# 40            SAL SEARCHING
# 17         PHILL YOUR BOOTS
# 34  ENGLAND 5 NETHERLANDS 1
# 18            ALL GON WRONG
# 0
# 6
# 16          ONE WAY TICKETS
# 38         'I WANT TO PLAY'
# 24      'VERY DISAPPOINTED'
# 8
# 43            RICH AND POOR
# 12              ROO THE DAY
# 27          NEYM YOUR PRICE
# 29              CEK HIM OUT
# 5
# 15                MO SELLER
# 30            BOTMAN BEGINS
# 25          TON OF INTEREST
#
#                                              subtitle  \
# 10  Georgina Rodriguez shows bikini tan lines as R...
# 40  Marseille launch £26m permanent bid for Arsena...
# 17  Man City agree £45million deal for Leeds star ...
# 34  Beth Mead scores twice to beat Greaves' 61-yea...
# 18  Higuain slams Arsenal for claims he was too ex...
# 0
# 6
# 16  Raphinha and Di Maria meet in Ibiza as they pr...
# 38  Kepa warns Chelsea to play him or he will seek...
# ...
