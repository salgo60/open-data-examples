# %% [markdown]
# # ESV Regleringsbrev
#
#  This [notebook](https://github.com/salgo60/open-data-examples/blob/master/ESV_Regleringsbrev.ipynb)

# %%
#Import Lib
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import csv 
import feedparser as fp

# %%
link = 'https://www.esv.se/Specialsidor/RSS/ESV--Regleringsbrev/'
feed = fp.parse(link)
df = pd.DataFrame()
feed.feed.title, feed.feed.link, feed.feed.description
# Out:
# ('ESV - Regleringsbrev',
#  'https://www.esv.se/',
#  'Statsliggaren - Regleringsbrev och ändringsbeslut för anslag och myndigheter')

# %%
for f in feed.entries:
    print (f.guid,f.link)
    print ("\t",f.title)
    print ("\t",f.description)
    print ("\t",f.published)
    print ("\t",f.category)
# Out:
# ESV-RBID=21163 https://www.esv.se/statsliggaren/regleringsbrev/?RBID=21163
# 	 Ändringsbeslut Anslag 1:1 Utrikesdepartementet (beslutsdatum 2020-10-26)
# 	 Anslag 1:1
# 	 Tue, 27 Oct 2020 07:00:00 +0100
# 	 Statsliggaren
# ESV-RBID=21116 https://www.esv.se/statsliggaren/regleringsbrev/?RBID=21116
# 	 Ändringsbeslut Anslag 1:16 Näringsdepartementet (beslutsdatum 2020-09-03)
# 	 Anslag 1:16
# 	 Mon, 07 Sep 2020 07:00:00 +0200
# 	 Statsliggaren
# ESV-RBID=21105 https://www.esv.se/statsliggaren/regleringsbrev/?RBID=21105
# 	 Ändringsbeslut Anslag 1:16 Näringsdepartementet (beslutsdatum 2020-08-27)
# 	 Anslag 1:16
# 	 Fri, 28 Aug 2020 07:00:00 +0200
# 	 Statsliggaren
# ESV-RBID=21269 https://www.esv.se/statsliggaren/regleringsbrev/?RBID=21269
# 	 Ändringsbeslut Anslag 1:2, 2:1, 5:2, 7:3, 8:2, 8:3, 8:5, 10:1, 11:1 och 11:3 Kulturdepartementet (beslutsdatum 2020-10-08)
# 	 Anslag 1:2, 2:1, 5:2, 7:3, 8:2, 8:3, 8:5, 10:1, 11:1 och 11:3
# 	 Mon, 12 Oct 2020 07:00:00 +0200
# 	 Statsliggaren
# ...

# %%
feed.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
print(len(feed.entries))
# Out:
# 88
