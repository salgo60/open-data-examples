# %% [markdown]
# ## Diarie Linköpings kommun
# se https://www.linkoping.se/open/data/arende/

# %%
from IPython.display  import JSON
import requests
import json
baseUrl = "http://arendedata.linkoping.se/api/v1/"
endpoint = "Cases?maxItemsInResult=1000&api_key=f3d212d2700f4c80aba7d2a88bc94529"
headers = {'content-type': 'application/json'}
url = baseUrl + endpoint
url
# Out:
# 'http://arendedata.linkoping.se/api/v1/Cases?maxItemsInResult=1000&api_key=f3d212d2700f4c80aba7d2a88bc94529'

# %%
req = requests.get(url,headers=headers)
data = json.loads(req.text)
import pandas as pd
df = pd.DataFrame(data)
df.head(n=40)
# Out:
#       caseNumber                                            subject  ...     diary hasEvents
# 0   KOF 2020-101  Nämndinitiativ: Ökade resurser till föreningar...  ...  KOF 2020      True
# 1   SON 2020-609          IVO genomför en tillsyn vid Hagabergs HVB  ...  SON 2020      True
# 2   SON 2020-608                                        Nytt ärende  ...  SON 2020     False
# 3   BIN 2020-391  Skrivelse - Kollektivtrafiken inför skolstart ...  ...  BIN 2020      True
# 4    ÄN 2020-405                      Lex Sarah Linghems vårdboende  ...   ÄN 2020      True
# 5    KS 2020-448  Höjning av friskvårdsbidrag 2020 på grund av C...  ...   KS 2020     False
# 6   BIN 2020-390  Förlängd undervisning (år) 4 gymnasieskolan lä...  ...  BIN 2020      True
# 7    ÄN 2020-404  Avvikelse region Östergötland till kommun Neur...  ...   ÄN 2020      True
# 8    ÄN 2020-403                Extra ersättning Åleryds vårdboende  ...   ÄN 2020      True
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
df.set_index('registeredDate',inplace=True)

# %%
df
# Out:
#                            caseNumber                                            subject closedDate     diary  hasEvents
# registeredDate
# 2020-06-01T16:31:52.17   KOF 2020-101  Nämndinitiativ: Ökade resurser till föreningar...       None  KOF 2020       True
# 2020-06-01T14:29:00      SON 2020-609          IVO genomför en tillsyn vid Hagabergs HVB       None  SON 2020       True
# 2020-06-01T14:28:00      SON 2020-608                                        Nytt ärende       None  SON 2020      False
# 2020-06-01T14:24:09.25   BIN 2020-391  Skrivelse - Kollektivtrafiken inför skolstart ...       None  BIN 2020       True
# 2020-06-01T14:22:00       ÄN 2020-405                      Lex Sarah Linghems vårdboende       None   ÄN 2020       True
# ...                               ...                                                ...        ...       ...        ...
# ...

# %% [markdown]
# ## Riksdagen

# %%
urlbaseRiks = "http://data.riksdagen.se/dokumentlista/"
urlRiks = urlbaseRiks + "?sok=&doktyp=&rm=&from=2020-06-01&tom=2020-06-30&ts=&bet=&tempbet=&nr=&org=&iid=&webbtv=&talare=&exakt=&planering=&sort=rel&sortorder=desc&rapport=&utformat=json&a=s#soktraff"

# %%
dataRiks = json.loads(requests.get(urlRiks).text)
import pandas as pd
dfRiks = pd.DataFrame(dataRiks["dokumentlista"]["dokument"])
dfRiks.head()
# Out:
#   traff  domain database       datum  ... reservationer debatt debattnamn dokumentnamn
# 0     1  rdwebb  ledamot  2020-06-02  ...          None   None       None         None
# 1     2  rdwebb  ledamot  2020-06-02  ...          None   None       None         None
# 2     3  rdwebb  ledamot  2020-06-02  ...          None   None       None         None
# 3     4  rdwebb  ledamot  2020-06-02  ...          None   None       None         None
# 4     5  rdwebb  ledamot  2020-06-02  ...          None   None       None         None
#
# [5 rows x 61 columns]
