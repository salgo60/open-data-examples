# %% [markdown]
# ## Riksdagens dokument KU-anmälningar
#
# * Denna [Jupyter Notebook](https://github.com/salgo60/open-data-examples/blob/master/Riksdagens%20dokument%20KU-anm%C3%A4lningar.ipynb)
#   * [SFS](https://github.com/salgo60/open-data-examples/blob/master/Riksdagens%20dokument%20SFS.ipynb)
#   * [Motioner]()
# * [Skapa sökfråga](http://data.riksdagen.se/dokumentlista/)  561 träffar
# * [Dokumenttyper](http://data.riksdagen.se/sv/koder/?typ=doktyp&utformat=json)

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 
pd.set_option("display.max.columns", None) 
urlbase ="http://data.riksdagen.se/dokumentlista/?sok=&doktyp=ku-anm&utformat=json&start="

dftot = pd.DataFrame()
for i in range(1,11813):
    url = urlbase + str(i)
    if ((i-1) % 10) == 0:
       print('*', end='', flush=True)
    r = http.request('GET', url)
    data = json.loads(r.data)
    dftot = dftot.append(pd.DataFrame(data["dokumentlista"]["dokument"]),sort=False)
dftot.head()
# Out:
# ***
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-574030fa2336> in <module>
#      12     r = http.request('GET', url)
#      13     data = json.loads(r.data)
# ---> 14     dftot = dftot.append(pd.DataFrame(data["dokumentlista"]["dokument"]),sort=False)
#      15 dftot.head()
#
# KeyError: 'dokument'

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 561 entries, 0 to 0
# Data columns (total 57 columns):
# traff                561 non-null object
# domain               561 non-null object
# database             561 non-null object
# datum                561 non-null object
# id                   561 non-null object
# rdrest               0 non-null object
# slutdatum            0 non-null object
# rddata               0 non-null object
# plats                0 non-null object
# klockslag            0 non-null object
# publicerad           561 non-null object
# systemdatum          561 non-null object
# undertitel           559 non-null object
# kalla                560 non-null object
# kall_id              0 non-null object
# dok_id               561 non-null object
# dokumentformat       0 non-null object
# dokument_url_text    561 non-null object
# dokument_url_html    561 non-null object
# inlamnad             0 non-null object
# motionstid           0 non-null object
# tilldelat            0 non-null object
# lang                 0 non-null object
# url                  0 non-null object
# relurl               0 non-null object
# titel                561 non-null object
# rm                   561 non-null object
# organ                561 non-null object
# relaterat_id         0 non-null object
# doktyp               561 non-null object
# typ                  561 non-null object
# subtyp               561 non-null object
# beteckning           0 non-null object
# tempbeteckning       561 non-null object
# nummer               561 non-null object
# status               1 non-null object
# score                561 non-null object
# sokdata              561 non-null object
# summary              559 non-null object
# notisrubrik          561 non-null object
# notis                559 non-null object
# dokintressent        0 non-null object
# filbilaga            520 non-null object
# avdelning            561 non-null object
# struktur             0 non-null object
# debattgrupp          0 non-null object
# debattdag            0 non-null object
# beslutsdag           0 non-null object
# beredningsdag        0 non-null object
# justeringsdag        0 non-null object
# beslutad             0 non-null object
# debattsekunder       0 non-null object
# ardometyp            0 non-null object
# reservationer        0 non-null object
# debatt               0 non-null object
# debattnamn           561 non-null object
# dokumentnamn         561 non-null object
# dtypes: object(57)
# memory usage: 254.2+ KB

# %%
dftot[['nummer','titel','publicerad','beslutad','datum','summary']]
# Out:
#    nummer                                              titel  publicerad  \
# 0      39  Hemställan om granskning av utrikesminister An...  2020-06-24
# 1      37  Begäran om granskning av Morgan Johanssons han...  2020-06-18
# 2      38  Begäran om granskning av regeringens motstridi...  2020-06-18
# 3      36  Begäran om granskning av regeringens och Isabe...  2020-06-12
# 4      35  Granskning av statsrådet Anna Ekströms uttalan...  2020-06-12
# ..    ...                                                ...         ...
# 16      5  Näringsminister Björn Rosengrens hantering av ...  1900-01-01
# 17      4                   Upphandlingen av Helikopter NH90  1900-01-01
# 18      3  Regeringens agerande när det gäller Hundskolan...  1900-01-01
# 19      2  Näringsministern Björn Rosengrens uttalande om...  1900-01-01
# 0       1  Justitieminister Thomas Bodströms agerande i s...  1900-01-01
#
#    beslutad       datum                                            summary
# 0      None  2020-06-23  MARKUS WIECHEL\n Riksdagsledamot SD 2020-06-23...
# 1      None  2020-06-18  Morgan Johanssons hantering av så kallade komp...
# 2      None  2020-06-17  MARIA STOCKHAUS\n Riksdagsledamot M 2020-06-17...
# 3      None  2020-06-11  JESSICA ROSENCRANTZ\n Riksdagsledamot M 2020-0...
# 4      None  2020-06-10  PATRICK RESLOW\n Riksdagsledamot SD 2020-06-10...
# ..      ...         ...                                                ...
# 16     None  2002-09-06     Näringsminister Björn Rosengrens hantering av
# 17     None  2002-09-02                       Upphandlingen av Helikopter
# 18     None  2002-07-11  Regeringens agerande när det gäller Hundskolan i
# 19     None  2002-07-02  Näringsministern Björn Rosengrens uttalande om...
# 0      None  2002-06-11  Justitieminister Thomas Bodströms agerande i s...
#
# [561 rows x 6 columns]

# %%
dftot.publicerad.unique()
# Out:
# array(['2020-06-24', '2020-06-18', '2020-06-12', '2020-03-11',
#        '2020-02-03', '2020-01-31', '2020-01-29', '2020-01-27',
#        '2020-01-17', '2020-01-16', '2020-01-15', '2020-01-09',
#        '2019-12-19', '2019-12-13', '2019-12-11', '2019-11-29',
#        '2019-11-27', '2019-11-08', '2019-10-25', '2019-10-15',
#        '2019-10-10', '2019-10-09', '2019-07-09', '2019-07-11',
#        '2019-07-08', '2019-06-19', '2019-04-17', '2019-03-29',
#        '2019-03-08', '2019-03-07', '2019-03-05', '2019-02-04',
#        '2019-02-05', '2019-02-01', '2019-01-24', '2018-12-21',
#        '2018-09-19', '2018-08-20', '2018-05-28', '2018-05-25',
#        '2018-05-08', '2018-03-15', '2018-03-12', '2018-02-23',
#        '2018-02-20', '2018-02-19', '2018-01-30', '2018-01-29',
#        '2018-02-01', '2018-01-24', '2018-01-17', '2018-01-11',
#        '2017-12-20', '2017-12-19', '2017-12-05', '2017-10-30',
#        '2017-10-19', '2017-10-10', '2017-09-22', '2017-09-07',
#        '2017-09-01', '2017-08-14', '2017-08-10', '2017-08-09',
#        '2017-06-16', '2017-04-10 10:34:58', '2017-02-08 16:50:43',
#        '2017-01-30 08:31:46', '2017-01-30 08:20:44',
#        '2017-01-27 15:06:57', '2017-01-27 12:39:32',
#        '2017-01-30 08:26:38', '2017-01-27 12:34:19',
#        '2017-01-26 15:38:08', '2016-12-15 12:49:34',
#        '2016-12-09 16:39:10', '2016-12-08 16:46:50',
#        '2016-12-06 16:52:39', '2016-11-25 16:38:20',
#        '2016-10-27 09:03:27', '2016-10-24 16:09:37',
#        '2016-10-21 17:29:57', '2016-10-21 14:00:08',
#        '2016-10-14 17:12:21', '2016-09-23 16:14:27',
#        '2016-09-16 15:42:52', '2016-08-17 13:40:12',
#        '2016-06-29 10:54:13', '2016-06-17 17:29:00',
#        '2016-06-10 12:52:51', '2016-05-24 17:25:17',
#        '2016-05-19 09:47:15', '2016-05-16 10:11:05',
#        '2016-04-27 14:58:33', '2016-04-15 09:46:32',
#        '2016-04-14 13:24:27', '2016-04-08 14:09:14',
#        '2016-03-16 12:20:12', '2016-03-10 14:23:44',
#        '2016-08-22 14:05:32', '2016-01-29 17:19:41',
#        '2016-08-22 14:09:56', '2016-04-05 13:10:21',
#        '2016-04-05 13:08:09', '2016-04-05 13:12:11',
#        '2016-04-06 09:35:24', '2016-08-22 14:03:19',
#        '2016-08-22 14:18:42', '2016-08-22 14:01:07',
#        '2016-08-22 13:52:21', '2016-08-22 14:27:36',
#        '2016-08-22 13:45:46', '2016-08-22 13:43:32',
#        '2016-08-22 13:38:47', '2016-01-29 10:01:41',
#        '2016-01-29 09:41:01', '2016-01-29 07:48:02',
#        '2016-01-29 07:43:05', '2016-02-23 08:17:32',
#        '2016-04-05 13:03:33', '2016-04-06 09:37:15',
#        '2016-01-26 09:13:59', '2016-01-20 15:57:17',
#        '2016-01-19 15:58:58', '2016-01-19 15:55:50',
#        '2015-12-18 17:15:28', '2015-12-18 16:34:12',
#        '2015-12-16 15:53:43', '2015-12-14 16:40:20',
#        '2015-12-09 20:25:24', '2015-12-09 14:41:42',
#        '2015-11-18 06:36:45', '2015-10-08 12:38:41',
#        '2015-10-05 09:38:26', '2015-09-23 07:07:15',
#        '2015-09-04 14:41:13', '2015-08-21 08:55:35',
#        '2015-07-21 14:58:46', '2015-07-06 17:05:57',
#        '2015-04-27 19:40:57', '2015-04-27 14:32:24',
#        '2015-04-20 08:49:59', '2015-04-20 08:47:34',
#        '2015-03-23 16:50:33', '2015-03-23 16:48:42',
#        '2015-03-13 17:15:42', '2015-03-11 16:32:55',
#        '2015-02-03 15:12:56', '2015-02-02 17:00:31',
#        '2015-02-02 14:04:24', '2015-02-02 14:31:50',
#        '2015-01-30 10:08:41', '2015-01-30 10:07:02',
#        '2015-01-30 10:03:22', '2015-01-29 08:49:36',
#        '2015-01-29 08:47:35', '2015-01-12 14:59:26',
#        '2015-01-12 09:49:25', '2015-01-08 14:41:05',
#        '2015-01-07 14:10:52', '2015-01-12 10:01:48',
#        '2014-12-09 17:13:47', '2014-12-08 16:24:32',
#        '2014-11-27 11:52:29', '2014-11-13 16:36:41',
#        '2014-11-10 09:48:50', '2014-11-05 17:02:31',
#        '2014-10-23 13:31:57', '2014-10-27 14:28:17',
#        '2014-10-23 08:51:00', '2014-10-08 09:46:37',
#        '2014-09-11 14:19:33', '2014-09-11 09:23:44',
#        '2014-09-03 17:18:51', '2014-06-18 18:15:13',
#        '2014-06-12 14:36:21', '2014-04-04 17:24:04',
#        '2014-02-14 17:50:20', '2014-02-14 17:47:01',
#        '2014-02-03 10:20:16', '2014-02-03 10:20:10',
#        '2014-02-03 10:24:58', '2014-01-30 15:58:32',
#        '2014-01-29 13:21:05', '2013-12-19 12:28:46',
#        '2013-12-10 18:23:42', '2013-11-27 15:19:09',
#        '2013-11-14 17:01:21', '2013-11-07 16:39:13',
#        '2013-09-25 17:53:43', '2013-04-18 12:53:15',
#        '2013-04-08 14:46:24', '2013-04-03 09:08:04',
#        '2013-02-28 11:49:08', '2013-02-21 15:21:00',
#        '2013-02-14 17:22:59', '2013-02-08 11:13:07',
#        '2013-02-06 11:22:03', '2013-01-09 10:36:21',
#        '2012-12-14 16:51:23', '2012-11-29 14:35:04',
#        '2012-11-30 09:36:13', '2012-10-25 16:50:22',
#        '2012-10-18 16:33:44', '2012-10-25 14:55:26',
#        '2012-10-01 17:09:43', '2012-08-14 14:53:55',
#        '2012-08-14 14:45:41', '2012-08-10 15:13:47',
#        '2012-07-13 10:03:21', '2012-06-25 10:31:57',
#        '2012-06-18 11:49:11', '2012-05-22 17:12:55',
#        '2012-06-06 10:09:15', '2012-03-22 10:08:52',
#        '2012-06-06 10:10:02', '2012-03-08 16:11:41',
#        '2012-02-06 17:27:00', '2012-02-06 17:29:00',
#        '2012-08-06 14:09:09', '2012-02-06 17:29:12',
#        '2012-02-06 17:28:26', '2012-02-06 17:28:55',
#        '2012-01-31 10:17:14', '2012-01-12 16:23:48',
#        '2011-12-20 15:30:10', '2011-12-20 15:30:05',
#        '2011-11-18 16:32:11', '2011-11-18 16:32:05',
#        '2011-09-14 13:46:10', '2011-09-14 10:00:36',
#        '2011-09-14 10:01:12', '2011-09-14 10:03:26',
#        '2011-09-14 10:02:13', '2011-09-14 10:02:36',
#        '2011-09-14 10:03:51', '2011-09-14 10:04:23',
#        '2011-09-14 10:05:03', '1900-01-01', '2011-03-30 14:23:55',
#        '2011-04-04 15:54:30', '2011-05-30 12:41:00',
#        '2011-05-30 12:40:35', '2011-04-04 15:56:19',
#        '2008-02-27 17:25:05', '2008-02-01 15:39:14',
#        '2008-01-25 16:38:31', '2007-12-20 16:29:16'], dtype=object)

# %%
dftot.publicerad.value_counts()
# Out:
# 1900-01-01             293
# 2018-01-30               4
# 2020-06-12               4
# 2017-08-10               3
# 2018-01-24               3
#                       ...
# 2019-06-19               1
# 2016-08-22 14:03:19      1
# 2019-07-08               1
# 2011-11-18 16:32:11      1
# 2017-01-27 15:06:57      1
# Name: publicerad, Length: 248, dtype: int64

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt   
plot = dftot.publicerad.value_counts()[1:30].plot.bar(y='counts', figsize=(25, 5)) 
plt.show()

# %%
organCount = dftot.organ.value_counts() 
organCount
# Out:
# KU     560
# JuU      1
# Name: organ, dtype: int64

# %%
dftot.undertitel.value_counts()[1:50]
# Out:
# Ulrika Karlsson (M)                                        10
# Ingvar Svensson (kd)                                        8
# Carl B Hamilton (fp)                                        7
# Henrik von Sydow (m)                                        7
# Tobias Krantz (fp)                                          5
# Peter Hultqvist (s)                                         5
# Sten Tolgfors (m)                                           5
# Sven-Erik Österberg (s)                                     4
# Karin Pilsäter och Mauricio Rojas (fp)                      4
# Sofia Arkelsten (M)                                         4
# Peter Hultqvist (S)                                         4
# Leif Pagrotsky (s)                                          4
# Stefan Attefall (kd)                                        4
# Thomas Bodström (s)                                         4
# KARIN ENSTRÖM  (M)                                          4
# Hans Hoff (s)                                               4
# Eva Flyborg (fp)                                            4
# Hans Hoff (S)                                               4
# Ulf Holm (mp)                                               4
# Eva-Lena Jansson (s)                                        4
# Johan Hedin (C)                                             3
# Jabar Amin (MP)                                             3
# Luciano Astudillo (s)                                       3
# MARIA MALMER STENERGARD  (M)                                3
# Ingegerd Saarinen (mp)                                      3
# Jonas Millard (SD) och Fredrik Eriksson (SD)                3
# Karin Enström (M)                                           3
# Allan Widman (fp)                                           3
# Ulla Andersson (V)                                          3
# JONAS JACOBSSON GJÖRTLER  (M)                               3
# Edward Riedl (M)                                            3
# Morgan Johansson (S)                                        3
# Lena Ek (c)                                                 3
# Siv Holma (v)                                               3
# Jessica Polfjärd (M)                                        3
# Kerstin Lundgren (c)                                        3
# Anders Ygeman (S)                                           3
# Mats Odell (kd)                                             2
# Susanne Eberstein (s)                                       2
# Matilda Ernkrans (S)                                        2
# Åsa Romson (MP)                                             2
# Ludvig Aspling   (SD)                                       2
# Thomas Östros (s)                                           2
# Maryam Yazdanfar (s)                                        2
# Mikael Damberg (S)                                          2
# MATTIAS KARLSSON I LULEÅ  (M)                               2
# Ulla Hoffmann (v), Rolf Olsson (v) och Alice Åström (v)     2
# Eva-Lena Jansson (S)                                        2
# Cecilia Magnusson (M)                                       2
# Name: undertitel, dtype: int64
