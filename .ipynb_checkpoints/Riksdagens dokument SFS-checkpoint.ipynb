# %% [markdown]
# ## Test Riksdagen dokument SFS
# * [Skapa sökfråga](http://data.riksdagen.se/dokumentlista/)

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 
pd.set_option("display.max.columns", None) 
urlbase ="http://data.riksdagen.se/dokumentlista/?sok=&doktyp=SFS&utformat=json&start="
 
#r = http.request('GET', url)
#data = json.loads(r.data)  
#df = pd.DataFrame(data["dokumentlista"]["dokument"]) 

dftot = pd.DataFrame()
#for i in range(1,525):
for i in range(1,525):
    url = urlbase + str(i)
    if ((i-1) % 10) == 0:
       print('*', end='', flush=True)
    r = http.request('GET', url)
    data = json.loads(r.data)
    dftot = dftot.append(pd.DataFrame(data["dokumentlista"]["dokument"]),sort=False)
dftot.head()
# Out:
# *****************************************************
#   traff  domain  database       datum            id rdrest slutdatum rddata  \
# 0     1  rdwebb  dokument  2020-06-17  sfs-2020-537   None      None   None
# 1     2  rdwebb  dokument  2020-06-17  sfs-2020-527   None      None   None
# 2     3  rdwebb  dokument  2020-06-17  sfs-2020-526   None      None   None
# 3     4  rdwebb  dokument  2020-06-17  sfs-2020-521   None      None   None
# 4     5  rdwebb  dokument  2020-06-17  sfs-2020-516   None      None   None
#
#   plats klockslag           publicerad          systemdatum undertitel kalla  \
# 0  None      None  2020-06-23 04:35:56  2020-06-23 04:35:56       None  None
# 1  None      None  2020-06-23 04:35:56  2020-06-23 04:35:56       None  None
# 2  None      None  2020-06-23 04:35:56  2020-06-23 04:35:56       None  None
# 3  None      None  2020-06-23 04:35:56  2020-06-23 04:35:56       None  None
# 4  None      None  2020-06-23 04:35:56  2020-06-23 04:35:56       None  None
#
#   kall_id        dok_id dokumentformat  \
# 0    None  sfs-2020-537           None
# 1    None  sfs-2020-527           None
# 2    None  sfs-2020-526           None
# 3    None  sfs-2020-521           None
# 4    None  sfs-2020-516           None
#
#                                 dokument_url_text  \
# 0  //data.riksdagen.se/dokument/sfs-2020-537.text
# 1  //data.riksdagen.se/dokument/sfs-2020-527.text
# 2  //data.riksdagen.se/dokument/sfs-2020-526.text
# 3  //data.riksdagen.se/dokument/sfs-2020-521.text
# 4  //data.riksdagen.se/dokument/sfs-2020-516.text
#
#                                 dokument_url_html inlamnad motionstid  \
# 0  //data.riksdagen.se/dokument/sfs-2020-537.html     None       None
# 1  //data.riksdagen.se/dokument/sfs-2020-527.html     None       None
# 2  //data.riksdagen.se/dokument/sfs-2020-526.html     None       None
# 3  //data.riksdagen.se/dokument/sfs-2020-521.html     None       None
# 4  //data.riksdagen.se/dokument/sfs-2020-516.html     None       None
#
#   tilldelat  lang   url relurl  \
# 0      None  None  None   None
# 1      None  None  None   None
# 2      None  None  None   None
# 3      None  None  None   None
# 4      None  None  None   None
#
#                                                titel    rm  \
# 0  Lag (2020:537) om restriktioner vid en riksrev...  2020
# 1  Förordning (2020:527) om tillfälliga smittskyd...  2020
# 2  Lag (2020:526) om tillfälliga smittskyddsåtgär...  2020
# 3  Förordning (2020:521) om konto- och värdefacks...  2020
# 4  Förordning (2020:516) med kompletterande bestä...  2020
#
#                       organ relaterat_id doktyp  typ subtyp beteckning  \
# 0  Justitiedepartementet L6         None    sfs  sfs   sfst   2020:537
# 1       Socialdepartementet         None    sfs  sfs   sfst   2020:527
# 2       Socialdepartementet         None    sfs  sfs   sfst   2020:526
# 3       Finansdepartementet         None    sfs  sfs   sfst   2020:521
# 4      Utrikesdepartementet         None    sfs  sfs   sfst   2020:516
#
#   tempbeteckning nummer status score  \
# 0           None    537   None   350
# 1           None    527   None   220
# 2           None    526   None   350
# 3           None    521   None   220
# 4           None    516   None   220
#
#                                              sokdata summary  \
# 0  {'titel': 'Lag (2020:537) om restriktioner vid...    None
# 1  {'titel': 'Förordning (2020:527) om tillfällig...    None
# 2  {'titel': 'Lag (2020:526) om tillfälliga smitt...    None
# 3  {'titel': 'Förordning (2020:521) om konto- och...    None
# 4  {'titel': 'Förordning (2020:516) med komplette...    None
#
#                                          notisrubrik notis dokintressent  \
# 0  Lag (2020:537) om restriktioner vid en riksrev...  None          None
# 1  Förordning (2020:527) om tillfälliga smittskyd...  None          None
# 2  Lag (2020:526) om tillfälliga smittskyddsåtgär...  None          None
# 3  Förordning (2020:521) om konto- och värdefacks...  None          None
# 4  Förordning (2020:516) med kompletterande bestä...  None          None
#
#   filbilaga avdelning struktur debattgrupp debattdag beslutsdag beredningsdag  \
# 0      None  dokument     None        None      None       None          None
# 1      None  dokument     None        None      None       None          None
# 2      None  dokument     None        None      None       None          None
# 3      None  dokument     None        None      None       None          None
# 4      None  dokument     None        None      None       None          None
#
#   justeringsdag beslutad debattsekunder ardometyp reservationer debatt  \
# 0          None     None           None      None          None   None
# 1          None     None           None      None          None   None
# 2          None     None           None      None          None   None
# 3          None     None           None      None          None   None
# 4          None     None           None      None          None   None
#
#                    debattnamn                dokumentnamn
# 0  Svensk författningssamling  Svensk författningssamling
# 1  Svensk författningssamling  Svensk författningssamling
# 2  Svensk författningssamling  Svensk författningssamling
# 3  Svensk författningssamling  Svensk författningssamling
# 4  Svensk författningssamling  Svensk författningssamling

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10480 entries, 0 to 19
# Data columns (total 57 columns):
# traff                10480 non-null object
# domain               10480 non-null object
# database             10480 non-null object
# datum                10480 non-null object
# id                   10480 non-null object
# rdrest               0 non-null object
# slutdatum            0 non-null object
# rddata               0 non-null object
# plats                0 non-null object
# klockslag            0 non-null object
# publicerad           10480 non-null object
# systemdatum          10480 non-null object
# undertitel           5327 non-null object
# kalla                5 non-null object
# kall_id              5 non-null object
# dok_id               10480 non-null object
# dokumentformat       0 non-null object
# dokument_url_text    10480 non-null object
# dokument_url_html    10480 non-null object
# inlamnad             0 non-null object
# motionstid           0 non-null object
# tilldelat            0 non-null object
# lang                 0 non-null object
# url                  0 non-null object
# relurl               0 non-null object
# titel                10480 non-null object
# rm                   10480 non-null object
# organ                10464 non-null object
# relaterat_id         0 non-null object
# doktyp               10480 non-null object
# typ                  10480 non-null object
# subtyp               10480 non-null object
# beteckning           10475 non-null object
# tempbeteckning       5 non-null object
# nummer               10480 non-null object
# status               5 non-null object
# score                10480 non-null object
# sokdata              10480 non-null object
# summary              5 non-null object
# notisrubrik          10480 non-null object
# notis                5 non-null object
# dokintressent        0 non-null object
# filbilaga            5 non-null object
# avdelning            10480 non-null object
# struktur             0 non-null object
# debattgrupp          0 non-null object
# debattdag            0 non-null object
# beslutsdag           0 non-null object
# beredningsdag        0 non-null object
# justeringsdag        0 non-null object
# beslutad             0 non-null object
# debattsekunder       0 non-null object
# ardometyp            0 non-null object
# reservationer        0 non-null object
# debatt               0 non-null object
# debattnamn           10480 non-null object
# dokumentnamn         10480 non-null object
# dtypes: object(57)
# memory usage: 4.6+ MB

# %%
dftot[['nummer','titel','publicerad','beslutad','summary']]
# Out:
#    nummer                                              titel  \
# 0     537  Lag (2020:537) om restriktioner vid en riksrev...
# 1     527  Förordning (2020:527) om tillfälliga smittskyd...
# 2     526  Lag (2020:526) om tillfälliga smittskyddsåtgär...
# 3     521  Förordning (2020:521) om konto- och värdefacks...
# 4     516  Förordning (2020:516) med kompletterande bestä...
# ..    ...                                                ...
# 15    155  Kungörelse (1942:155) angående förbud mot \nfö...
# 16    158  Kungl. Maj:ts Kungörelse (1942:158)\nangående ...
# 17     92  Kungl. Maj:ts förordning (1942:92)\nom rätt at...
# 18    118  Lag (1942:118) om anordnande av högmässogudstj...
# 19     87  Lag (1942:87) med särskilda bestämmelser \nang...
#
#              publicerad beslutad summary
# 0   2020-06-23 04:35:56     None    None
# 1   2020-06-23 04:35:56     None    None
# 2   2020-06-23 04:35:56     None    None
# 3   2020-06-23 04:35:56     None    None
# 4   2020-06-23 04:35:56     None    None
# ..                  ...      ...     ...
# 15  2016-02-11 15:25:55     None    None
# 16  2016-02-11 15:26:14     None    None
# 17  2016-02-11 15:26:07     None    None
# 18  2016-02-11 15:26:31     None    None
# 19  2016-02-11 15:24:54     None    None
#
# [10480 rows x 5 columns]
