# %% [markdown]
# ## Kulturnav - personer

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 
pd.set_option("display.max.columns", None) 
urlbase = "https://kulturnav.org/api/search/entityType:Person?start=" 

dftot = pd.DataFrame()
for i in range(1,300000,20):
    url = urlbase + str(i)
    if ((i-1) % 1000) == 0:
       print('*', end='', flush=True)
    r = http.request('GET', url)
    try:
        data = json.loads(r.data)
        dftot = dftot.append(pd.DataFrame(data),sort=False)
    except:
        print("\tError in i=",i)
# Out:
# *********************************************************************************************************

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 19
# Data columns (total 13 columns):
# uuid                   100000 non-null object
# entityType             100000 non-null object
# acl                    100000 non-null object
# currentVersion         100000 non-null bool
# createdAt              100000 non-null object
# createdBy              100000 non-null object
# inline                 100000 non-null bool
# caption                100000 non-null object
# properties             100000 non-null object
# entityTypeName         100000 non-null object
# entityTypeHierarchy    100000 non-null object
# updatedAt              95000 non-null object
# updatedBy              95000 non-null object
# dtypes: bool(2), object(11)
# memory usage: 9.3+ MB

# %%
dftot
# Out:
#                                     uuid entityType  \
# 0   c606934d-b85a-4824-9637-cf0e8fc1c495     Person
# 1   653a04dd-ee17-42a2-badb-2901ceb20420     Person
# 2   f9683a39-7641-4155-85e6-f051e09e8f67     Person
# 3   900f2922-7e78-42a7-9b89-8f57505bee6a     Person
# 4   c452c4fe-d94c-410b-9caa-ff541335e749     Person
# ..                                   ...        ...
# 15  08d42da0-25d1-45f1-ad2e-923133b07a93     Person
# 16  c690b94d-5666-4756-9a15-bf5c9fa06f80     Person
# 17  c9d1d01e-815a-4bf2-9c0c-952319fc3f76     Person
# 18  f7a91513-6314-46aa-84da-1f454127eb52     Person
# 19  fae9a387-9c2b-4a8d-b4e3-1a71d466b5d8     Person
#
#                                             acl  currentVersion  \
# 0   4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
# 1   4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
# 2   4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
# 3   4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
# 4   4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
# ..                                          ...             ...
# 15  4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
# 16  4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
# 17  4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
# 18  4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
# 19  4c1319c2-a30a-43e7-a3d5-05038935dcfb_SHARED            True
#
#                   createdAt                             createdBy  inline  \
# 0   Jan 19, 2016 2:41:09 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 1   Jun 11, 2013 4:18:36 PM                                  root   False
# 2   Jun 11, 2013 4:09:03 PM                                  root   False
# 3   Jun 11, 2013 4:19:38 PM                                  root   False
# 4   Jun 11, 2013 4:04:38 PM                                  root   False
# ..                      ...                                   ...     ...
# 15  Jun 11, 2013 3:06:15 PM                                  root   False
# 16  Jun 11, 2013 4:13:57 PM                                  root   False
# 17  Jun 11, 2013 4:13:15 PM                                  root   False
# 18  Jun 11, 2013 3:25:19 PM                                  root   False
# 19  Jun 11, 2013 3:01:05 PM                                  root   False
#
#                                               caption  \
# 0                                                  {}
# 1                                          {'sv': ''}
# 2                                          {'sv': ''}
# 3            {'sv': '"Irma" (Irmengard) von Hallwyl'}
# 4    {'sv': '"Johnny" (John August Emanuel) Roosval'}
# ..                                                ...
# 15  {'sv': '(Charles) Édouard Boutibonne (1816 - 1...
# 16  {'sv': '(Christian Albin) Waldemar Bülow (1864...
# 17   {'sv': '(Christina) Matilda Staël von Holstein'}
# 18  {'sv': '(Claes Walther) Harry von Eckermann (1...
# 19  {'sv': '(Conrad) Victor Ankarcrona (1823 - 191...
#
#                                            properties  \
# 0   {'entity.dataset': [{'uuid': 'deecb7d7-8a3f-46...
# 1   {'entity.dataset': [{'uuid': '59978ea2-2dc8-47...
# 2   {'entity.alternativeName': [{'uuid': '21f6ccb1...
# 3   {'entity.alternativeName': [{'uuid': '4c27911c...
# 4   {'entity.dataset': [{'uuid': '65d1ad7f-cf09-4c...
# ..                                                ...
# 15  {'entity.dataset': [{'uuid': '14a89cc3-c43e-4c...
# 16  {'entity.alternativeName': [{'uuid': '469cee78...
# 17  {'entity.alternativeName': [{'uuid': '9dc14680...
# 18  {'entity.dataset': [{'uuid': '1232b981-6421-40...
# 19  {'entity.dataset': [{'uuid': '59b09bdc-8857-4f...
#
#                                        entityTypeName entityTypeHierarchy  \
# 0   {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
# 1   {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
# 2   {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
# 3   {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
# 4   {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
# ..                                                ...                 ...
# 15  {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
# 16  {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
# 17  {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
# 18  {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
# 19  {'nn': 'Person', 'no': 'Person', 'sv': 'Person...     [Agent, Person]
#
#                   updatedAt                             updatedBy
# 0                       NaN                                   NaN
# 1   Jan 19, 2016 2:41:15 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 2   Jan 19, 2016 2:40:34 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 3   Jan 19, 2016 2:40:36 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 4   Mar 22, 2016 8:32:29 PM                                  root
# ..                      ...                                   ...
# 15  Jan 19, 2016 2:07:43 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 16  Jan 19, 2016 2:31:27 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 17  Jan 19, 2016 2:40:38 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 18  Jan 19, 2016 2:38:05 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 19  Jan 19, 2016 2:04:35 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
#
# [100 rows x 13 columns]
