# %% [markdown]
# ## Kulturnav - concept

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 
pd.set_option("display.max.columns", None) 
urlbase = "https://kulturnav.org/api/search/entityType:Concept?start=" 

dftot = pd.DataFrame()
for i in range(1,400000,20):
    url = urlbase + str(i)
    if ((i-1) % 1000) == 0:
       print('*', end='', flush=True)
    r = http.request('GET', url)
    try:
        data = json.loads(r.data)
        dftot = dftot.append(pd.DataFrame(data),sort=False)
    except:
        print("\tError in i=",i)
# Out:
# *********************************************************************************************************************

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 19
# Data columns (total 14 columns):
# uuid                   100000 non-null object
# entityType             100000 non-null object
# acl                    100000 non-null object
# currentVersion         100000 non-null bool
# createdAt              100000 non-null object
# createdBy              100000 non-null object
# updatedAt              100000 non-null object
# updatedBy              100000 non-null object
# savedSource            100000 non-null object
# inline                 100000 non-null bool
# caption                100000 non-null object
# properties             100000 non-null object
# entityTypeName         100000 non-null object
# entityTypeHierarchy    100000 non-null object
# dtypes: bool(2), object(12)
# memory usage: 10.1+ MB

# %%
dftot
# Out:
#                                     uuid entityType  \
# 0   61048591-aad3-4dae-81d2-e13e98768eaa    Concept
# 1   a97217d3-55f6-46bf-a751-8f07197a286d    Concept
# 2   eb651942-696b-41e0-a599-73cf4b225604    Concept
# 3   596c595d-614c-4d79-92fe-7fdd5ddf5fc5    Concept
# 4   92b01fc3-7bd2-4df2-ac8a-ff7e175f081e    Concept
# ..                                   ...        ...
# 15  62c0d3f8-3c3d-4f63-af52-57cbee606f2e    Concept
# 16  6a4eac4e-808c-4025-ba24-a8439fecbc29    Concept
# 17  bff95dcc-2f64-46e5-aca2-d6625d703726    Concept
# 18  5062ff14-87b8-4b4f-92c0-2b901cc3ae6c    Concept
# 19  3dea073f-a74c-4502-b3f1-b4d6b8ddc34d    Concept
#
#                                             acl  currentVersion  \
# 0   031eebb4-74c1-4079-a219-566e4cd5d789_SHARED            True
# 1   273d4a24-d970-4d4c-bed5-3e82e1054c5f_SHARED            True
# 2   273d4a24-d970-4d4c-bed5-3e82e1054c5f_SHARED            True
# 3   273d4a24-d970-4d4c-bed5-3e82e1054c5f_SHARED            True
# 4   273d4a24-d970-4d4c-bed5-3e82e1054c5f_SHARED            True
# ..                                          ...             ...
# 15  031eebb4-74c1-4079-a219-566e4cd5d789_SHARED            True
# 16  031eebb4-74c1-4079-a219-566e4cd5d789_SHARED            True
# 17  031eebb4-74c1-4079-a219-566e4cd5d789_SHARED            True
# 18  031eebb4-74c1-4079-a219-566e4cd5d789_SHARED            True
# 19  031eebb4-74c1-4079-a219-566e4cd5d789_SHARED            True
#
#                    createdAt                             createdBy  \
# 0    Jan 29, 2019 8:41:53 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 1   Apr 24, 2020 11:08:37 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 2   Apr 24, 2020 12:09:12 PM  5bffda4b-c485-4819-95c7-bc04d091c500
# 3   Apr 24, 2020 10:52:56 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 4   Apr 24, 2020 12:54:20 PM  5bffda4b-c485-4819-95c7-bc04d091c500
# ..                       ...                                   ...
# 15   Oct 5, 2018 10:37:50 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 16   Oct 5, 2018 10:41:25 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 17  Oct 10, 2018 12:07:56 PM  5bffda4b-c485-4819-95c7-bc04d091c500
# 18   Feb 15, 2019 2:44:11 PM  5bffda4b-c485-4819-95c7-bc04d091c500
# 19  Oct 12, 2018 11:25:27 AM  5bffda4b-c485-4819-95c7-bc04d091c500
#
#                   updatedAt                             updatedBy  \
# 0   Jan 30, 2020 2:48:36 PM  a3d5661e-4115-4c79-b8f6-c47ea09c89b3
# 1   Jun 8, 2020 11:43:50 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 2   Jun 8, 2020 11:43:52 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 3   Jun 8, 2020 11:43:54 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 4   Jun 8, 2020 11:43:54 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# ..                      ...                                   ...
# 15  Jun 8, 2020 10:35:54 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 16  Jun 8, 2020 10:35:55 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 17  Jun 8, 2020 10:36:00 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 18  Jun 8, 2020 11:03:16 AM  5bffda4b-c485-4819-95c7-bc04d091c500
# 19  Jun 8, 2020 10:36:05 AM  5bffda4b-c485-4819-95c7-bc04d091c500
#
#          savedSource  inline  \
# 0       BATCH_UPDATE   False
# 1       BATCH_UPDATE   False
# 2       BATCH_UPDATE   False
# 3       BATCH_UPDATE   False
# 4       BATCH_UPDATE   False
# ..               ...     ...
# 15      BATCH_UPDATE   False
# 16      BATCH_UPDATE   False
# 17  REFLEXIVE_UPDATE   False
# 18      BATCH_UPDATE   False
# 19      BATCH_UPDATE   False
#
#                                               caption  \
# 0              {'no': '(Aggregat etter oppstilling)'}
# 1   {'no': '(Begrep fra Forskrift om elsertifikate...
# 2   {'no': '(Begrep fra Forskrift om energimerking...
# 3   {'no': '(Begrep fra Forskrift om internkontrol...
# 4   {'no': '(Begrep fra Forskrift om kraftrasjoner...
# ..                                                ...
# 15                 {'no': '(Bro etter type ferdsel)'}
# 16                {'no': '(Bro etter type material)'}
# 17                      {'no': '(Bygg etter formål)'}
# 18  {'no': '(Bygg- og anleggsbransjen etter grad a...
# 19                      {'no': '(Bygning etter del)'}
#
#                                            properties  \
# 0   {'concept.broader': [{'uuid': '58cbefca-9346-4...
# 1   {'concept.broader': [{'uuid': '11296b81-443c-4...
# 2   {'concept.broader': [{'uuid': '7dc57a47-2329-4...
# 3   {'concept.broader': [{'uuid': '0e535805-dfd2-4...
# 4   {'concept.broader': [{'uuid': '0d48f26c-d239-4...
# ..                                                ...
# 15  {'concept.broader': [{'uuid': '839b3780-38b2-4...
# 16  {'concept.broader': [{'uuid': 'd6187fd7-bfe3-4...
# 17  {'concept.broader': [{'uuid': 'aee4dde7-bbb6-4...
# 18  {'concept.broader': [{'uuid': '4bf9cdb6-f6fd-4...
# 19  {'concept.broader': [{'uuid': '843f25d4-dc5d-4...
#
#                                        entityTypeName entityTypeHierarchy
# 0   {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
# 1   {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
# 2   {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
# 3   {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
# 4   {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
# ..                                                ...                 ...
# 15  {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
# 16  {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
# 17  {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
# 18  {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
# 19  {'nn': 'Term', 'no': 'Term', 'sv': 'Term', 'fi...           [Concept]
#
# [100000 rows x 14 columns]
