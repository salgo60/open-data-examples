# %% [markdown]
# **Work in progress**
#
#
# # Nobel API 2.1 - check Wikidata and Nobel API
#
# The purpose of this Notebook is to have Nobelprize winners in Wikidata in synch with the prizewinners at Nobelprize... lesson learned is that we also find vandalization in Wikidata....
#
#
# * This [Jupyter Notebook](https://github.com/salgo60/open-data-examples/blob/master/Nobel%20API_2_1.ipynb)  using API 2.1 [api.nobelprize.org/2.1/laureates](https://api.nobelprize.org/2.1/laureates)
#   * old [Notebook](https://github.com/salgo60/open-data-examples/blob/master/Nobel%20API.ipynb)
#
#
#   * Wikidata property [Property:P8024](https://www.wikidata.org/wiki/Property:P8024)
#   * [Developer zone nobelprize.org](https://www.nobelprize.org/about/developer-zone-2/)
#       * API 2.1 [api.nobelprize.org/2.1/laureates](https://api.nobelprize.org/2.1/laureates)
#   * [video](https://youtu.be/Iu1JtefueM8) explaining what we do
#
# #### Misc
# Version history
# * 0.1 use API 2.1 --> Nobel API also includes Wikidata Q numbers
# ##### See also
# * Kaggle [nobelfoundation/nobel-laureates](https://www.kaggle.com/nobelfoundation/nobel-laureates) and my [Kaggle Notebook](https://www.kaggle.com/magnusslg/wikidata-nobelprize-synch)
# * [Wikidata mismatchfinder](https://github.com/wmde/wikidata-mismatch-finder/issues/57) about how we should work with mismatches with e.g. Nobelprize
#
# #### Other sources we sync
# * Famous people on Uppsala old cemetery [Kulturpersoner Uppsalakyrkogård](https://github.com/salgo60/open-data-examples/blob/master/Check%20WD%20kulturpersoner%20uppsalakyrkogardar.ipynb)
# * Swedish Literature Bank - [Litteraturbanken](https://github.com/salgo60/open-data-examples/blob/master/Litteraturbanken%20Author.ipynb)
#   * WD property [P5101](https://www.wikidata.org/wiki/Property_talk:P5101) [P5123](https://www.wikidata.org/wiki/Property_talk:P5123)
# * [Nobelprize.org](https://github.com/salgo60/open-data-examples/blob/master/Nobel%20API.ipynb)
#   * WD [property 8024](https://www.wikidata.org/wiki/Property:P8024)
# * The Swedish National Archive [SBL](https://github.com/salgo60/open-data-examples/blob/master/SBL.ipynb)
#   * WD [property 3217](https://www.wikidata.org/wiki/Property:P3217)
# * The Biographical Dictionary of Swedish Women [SKBL](https://github.com/salgo60/open-data-examples/blob/master/Svenskt%20Kvinnobiografiskt%20lexikon%20part%203.ipynb)
#   * WD [property 4963](https://www.wikidata.org/wiki/Property:P4963)
# * Swedish Academy - [Svenska Akademien](https://github.com/salgo60/open-data-examples/blob/master/Svenska%20Akademien.ipynb)
#   * WD [property 5325](https://www.wikidata.org/wiki/Property:P5325)

# %%
from datetime import datetime
start_time = datetime.now()
print("Last run: ", datetime.now())
# Out:
# Last run:  2021-08-10 08:10:33.037290

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 

url ="https://api.nobelprize.org/2.1/laureates?offset=0&limit=1500"
dftot = pd.DataFrame()
r = http.request('GET', url)
data = json.loads(r.data)
dftot = dftot.append(pd.DataFrame(data["laureates"]),sort=False)

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955 entries, 0 to 954
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               955 non-null    object
#  1   knownName        930 non-null    object
#  2   givenName        930 non-null    object
#  3   familyName       928 non-null    object
#  4   fullName         930 non-null    object
#  5   fileName         955 non-null    object
#  6   gender           930 non-null    object
#  7   birth            929 non-null    object
#  8   wikipedia        955 non-null    object
#  9   wikidata         955 non-null    object
#  10  sameAs           955 non-null    object
#  11  links            955 non-null    object
#  12  nobelPrizes      955 non-null    object
#  13  death            639 non-null    object
#  14  orgName          25 non-null     object
#  15  nativeName       24 non-null     object
#  16  acronym          11 non-null     object
#  17  founded          24 non-null     object
#  18  penName          11 non-null     object
#  19  birthCountry     1 non-null      object
#  20  birthCountryNow  1 non-null      object
#  21  birthContinent   1 non-null      object
# dtypes: object(22)
# memory usage: 164.3+ KB

# %%
dftot["id"] = dftot["id"].astype("int")

dftot.sort_values(by=['id'], ascending=[True], inplace=True)
dftot.tail(4)
# Out:
#       id                                          knownName  \
# 559  993       {'en': 'Louise Glück', 'se': 'Louise Glück'}
# 946  994                                                NaN
# 680  995  {'en': 'Paul R. Milgrom', 'se': 'Paul R. Milgr...
# 741  996  {'en': 'Robert B. Wilson', 'se': 'Robert B. Wi...
#
#                             givenName                          familyName  \
# 559  {'en': 'Louise', 'se': 'Louise'}      {'en': 'Glück', 'se': 'Glück'}
# 946                               NaN                                 NaN
# 680      {'en': 'Paul', 'se': 'Paul'}  {'en': 'Milgrom', 'se': 'Milgrom'}
# 741  {'en': 'Robert', 'se': 'Robert'}    {'en': 'Wilson', 'se': 'Wilson'}
#
#                                               fullName fileName  gender  \
# 559       {'en': 'Louise Glück', 'se': 'Louise Glück'}    gluck  female
# 946                                                NaN      wfp     NaN
# 680  {'en': 'Paul R. Milgrom', 'se': 'Paul R. Milgr...  milgrom    male
# 741  {'en': 'Robert B. Wilson', 'se': 'Robert B. Wi...   wilson    male
#
#                                                  birth  \
# 559  {'date': '1943-04-22', 'place': {'city': {'en'...
# 946                                                NaN
# 680  {'date': '1948-04-20', 'place': {'city': {'en'...
# 741  {'date': '1937-05-16', 'place': {'city': {'en'...
#
#                                              wikipedia  \
# 559  {'slug': 'Louise_Glück', 'english': 'https://e...
# 946  {'slug': 'World_Food_Programme', 'english': 'h...
# 680  {'slug': 'Paul_Milgrom', 'english': 'https://e...
# 741  {'slug': 'Robert_B._Wilson', 'english': 'https...
#
#                                               wikidata  ...  \
# 559  {'id': 'Q2344210', 'url': 'https://www.wikidat...  ...
# 946  {'id': 'Q204344', 'url': 'https://www.wikidata...  ...
# 680  {'id': 'Q1359990', 'url': 'https://www.wikidat...  ...
# 741  {'id': 'Q377265', 'url': 'https://www.wikidata...  ...
#
#                                            nobelPrizes death  \
# 559  [{'awardYear': '2020', 'category': {'en': 'Lit...   NaN
# 946  [{'awardYear': '2020', 'category': {'en': 'Pea...   NaN
# 680  [{'awardYear': '2020', 'category': {'en': 'Eco...   NaN
# 741  [{'awardYear': '2020', 'category': {'en': 'Eco...   NaN
#
#                                                orgName nativeName acronym  \
# 559                                                NaN        NaN     NaN
# 946  {'en': 'World Food Programme', 'no': 'Verdens ...        NaN     WFP
# 680                                                NaN        NaN     NaN
# 741                                                NaN        NaN     NaN
#
#                                                founded penName birthCountry  \
# 559                                                NaN     NaN          NaN
# 946  {'date': '1961-00-00', 'place': {'locationStri...     NaN          NaN
# 680                                                NaN     NaN          NaN
# 741                                                NaN     NaN          NaN
#
#     birthCountryNow birthContinent
# 559             NaN            NaN
# 946             NaN            NaN
# 680             NaN            NaN
# 741             NaN            NaN
#
# [4 rows x 22 columns]

# %%
#Test flatten 
#from pandas.json_normalize import json_normalize
#from pandas.io.json.normalize import nested_to_record
from pandas import json_normalize
#dftotPrize = json_normalize(data=data['laureates'], record_path='nobelPrizes', 
#                            meta=['id', 'filename','gender', 'wikidata'],errors='ignore') 
dftotPrize = json_normalize(data=data["laureates"])
dftotPrize.shape
# Out:
# (955, 100)

# %%
dftotPrize.sample(5)
# Out:
#       id  fileName gender                                             sameAs  \
# 23    26  einstein   male  [https://www.wikidata.org/wiki/Q937, https://e...
# 802  367     ochoa   male  [https://www.wikidata.org/wiki/Q233957, https:...
# 798  532  macbride   male  [https://www.wikidata.org/wiki/Q244395, https:...
# 725  949    thaler   male  [https://www.wikidata.org/wiki/Q371212, https:...
# 873  274      cech   male  [https://www.wikidata.org/wiki/Q135180, https:...
#
#                                                  links  \
# 23   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 802  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 798  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 725  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 873  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                            nobelPrizes       knownName.en  \
# 23   [{'awardYear': '1921', 'category': {'en': 'Phy...    Albert Einstein
# 802  [{'awardYear': '1959', 'category': {'en': 'Phy...       Severo Ochoa
# 798  [{'awardYear': '1974', 'category': {'en': 'Pea...      Seán MacBride
# 725  [{'awardYear': '2017', 'category': {'en': 'Eco...  Richard H. Thaler
# 873  [{'awardYear': '1989', 'category': {'en': 'Che...     Thomas R. Cech
#
#           knownName.se givenName.en givenName.se  ... birthCountry.no  \
# 23     Albert Einstein       Albert       Albert  ...             NaN
# 802       Severo Ochoa       Severo       Severo  ...             NaN
# 798      Seán MacBride         Seán         Seán  ...             NaN
# 725  Richard H. Thaler   Richard H.   Richard H.  ...             NaN
# 873     Thomas R. Cech    Thomas R.    Thomas R.  ...             NaN
#
#     birthCountry.se birthCountryNow.en birthCountryNow.no birthCountryNow.se  \
# 23              NaN                NaN                NaN                NaN
# 802             NaN                NaN                NaN                NaN
# 798             NaN                NaN                NaN                NaN
# 725             NaN                NaN                NaN                NaN
# 873             NaN                NaN                NaN                NaN
#
#     birthContinent.en knownName.no givenName.no familyName.no fullName.no
# 23                NaN          NaN          NaN           NaN         NaN
# 802               NaN          NaN          NaN           NaN         NaN
# 798               NaN          NaN          NaN           NaN         NaN
# 725               NaN          NaN          NaN           NaN         NaN
# 873               NaN          NaN          NaN           NaN         NaN
#
# [5 rows x 100 columns]

# %%
dftotPrize["penName"].value_counts()
# Out:
# (pen-name of Odysseus Alepoudhelis)             1
# (pen-name of Jacques Anatole Thibault)          1
# (pen-name of Rejment)                           1
# (pen-name of Neftalí Ricardo Reyes Basoalto)    1
# (pen-name of Guan Moye)                         1
# (pen-name of René François Armand Prudhomme)    1
# (pen-name of Pearl Walsh, née Sydenstricker)    1
# (pen-name of Lucila Godoy y Alcayaga)           1
# (pen-name of Grazia Madesani, née Deledda)      1
# (pen-name of Alexis Léger)                      1
# (pen-name of Giorgos Seferiadis)                1
# Name: penName, dtype: int64

# %%
dftotPrize["birth.place.countryNow.en"].value_counts()
# Out:
# USA               279
# United Kingdom     87
# Germany            82
# France             57
# Sweden             29
#                  ...
# Cyprus              1
# Taiwan              1
# Bulgaria            1
# Slovakia            1
# Brazil              1
# Name: birth.place.countryNow.en, Length: 82, dtype: int64

# %%
dftotPrize.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955 entries, 0 to 954
# Data columns (total 100 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               955 non-null    object
#  1   fileName                         955 non-null    object
#  2   gender                           930 non-null    object
#  3   sameAs                           955 non-null    object
#  4   links                            955 non-null    object
#  5   nobelPrizes                      955 non-null    object
#  6   knownName.en                     930 non-null    object
#  7   knownName.se                     930 non-null    object
#  8   givenName.en                     930 non-null    object
#  9   givenName.se                     930 non-null    object
#  10  familyName.en                    928 non-null    object
#  11  familyName.se                    928 non-null    object
#  12  fullName.en                      930 non-null    object
#  13  fullName.se                      930 non-null    object
#  14  birth.date                       929 non-null    object
#  15  birth.place.city.en              928 non-null    object
#  16  birth.place.city.no              928 non-null    object
#  17  birth.place.city.se              928 non-null    object
#  18  birth.place.country.en           929 non-null    object
#  19  birth.place.country.no           929 non-null    object
#  20  birth.place.country.se           929 non-null    object
#  21  birth.place.cityNow.en           928 non-null    object
#  22  birth.place.cityNow.no           928 non-null    object
#  23  birth.place.cityNow.se           928 non-null    object
#  24  birth.place.cityNow.sameAs       911 non-null    object
#  25  birth.place.countryNow.en        929 non-null    object
#  26  birth.place.countryNow.no        929 non-null    object
#  27  birth.place.countryNow.se        929 non-null    object
#  28  birth.place.countryNow.sameAs    924 non-null    object
#  29  birth.place.continent.en         929 non-null    object
#  30  birth.place.continent.no         929 non-null    object
#  31  birth.place.continent.se         929 non-null    object
#  32  birth.place.locationString.en    929 non-null    object
#  33  birth.place.locationString.no    929 non-null    object
#  34  birth.place.locationString.se    929 non-null    object
#  35  wikipedia.slug                   955 non-null    object
#  36  wikipedia.english                955 non-null    object
#  37  wikidata.id                      955 non-null    object
#  38  wikidata.url                     955 non-null    object
#  39  death.date                       639 non-null    object
#  40  death.place.city.en              621 non-null    object
#  41  death.place.city.no              621 non-null    object
#  42  death.place.city.se              621 non-null    object
#  43  death.place.country.en           627 non-null    object
#  44  death.place.country.no           627 non-null    object
#  45  death.place.country.se           627 non-null    object
#  46  death.place.country.sameAs       587 non-null    object
#  47  death.place.cityNow.en           621 non-null    object
#  48  death.place.cityNow.no           621 non-null    object
#  49  death.place.cityNow.se           621 non-null    object
#  50  death.place.cityNow.sameAs       610 non-null    object
#  51  death.place.countryNow.en        627 non-null    object
#  52  death.place.countryNow.no        627 non-null    object
#  53  death.place.countryNow.se        627 non-null    object
#  54  death.place.countryNow.sameAs    624 non-null    object
#  55  death.place.continent.en         627 non-null    object
#  56  death.place.continent.no         627 non-null    object
#  57  death.place.continent.se         627 non-null    object
#  58  death.place.locationString.en    639 non-null    object
#  59  death.place.locationString.no    639 non-null    object
#  60  death.place.locationString.se    639 non-null    object
#  61  nativeName                       24 non-null     object
#  62  acronym                          11 non-null     object
#  63  orgName.en                       25 non-null     object
#  64  orgName.no                       21 non-null     object
#  65  orgName.se                       25 non-null     object
#  66  founded.date                     24 non-null     object
#  67  founded.place.city.en            19 non-null     object
#  68  founded.place.city.no            19 non-null     object
#  69  founded.place.city.se            19 non-null     object
#  70  founded.place.country.en         21 non-null     object
#  71  founded.place.country.no         21 non-null     object
#  72  founded.place.country.se         21 non-null     object
#  73  founded.place.country.sameAs     21 non-null     object
#  74  founded.place.cityNow.en         19 non-null     object
#  75  founded.place.cityNow.no         19 non-null     object
#  76  founded.place.cityNow.se         19 non-null     object
#  77  founded.place.cityNow.sameAs     19 non-null     object
#  78  founded.place.countryNow.en      21 non-null     object
#  79  founded.place.countryNow.no      21 non-null     object
#  80  founded.place.countryNow.se      21 non-null     object
#  81  founded.place.countryNow.sameAs  21 non-null     object
#  82  founded.place.continent.en       21 non-null     object
#  83  founded.place.continent.no       21 non-null     object
#  84  founded.place.continent.se       21 non-null     object
#  85  founded.place.locationString.en  24 non-null     object
#  86  founded.place.locationString.no  24 non-null     object
#  87  founded.place.locationString.se  24 non-null     object
#  88  penName                          11 non-null     object
#  89  birthCountry.en                  1 non-null      object
#  90  birthCountry.no                  1 non-null      object
#  91  birthCountry.se                  1 non-null      object
#  92  birthCountryNow.en               1 non-null      object
#  93  birthCountryNow.no               1 non-null      object
#  94  birthCountryNow.se               1 non-null      object
#  95  birthContinent.en                1 non-null      object
#  96  knownName.no                     4 non-null      object
#  97  givenName.no                     3 non-null      object
#  98  familyName.no                    3 non-null      object
#  99  fullName.no                      3 non-null      object
# dtypes: object(100)
# memory usage: 746.2+ KB

# %%
#dftotPrize["death.place.country.sameAs"].value_counts()

# %%
dftotPrize.sample(4)
# Out:
#       id fileName  gender                                             sameAs  \
# 213  293  behring    male  [https://www.wikidata.org/wiki/Q76425, https:/...
# 252  180    aston    male  [https://www.wikidata.org/wiki/Q102291, https:...
# 683  610     buck  female  [https://www.wikidata.org/wiki/Q80900, https:/...
# 198  447    krebs    male  [https://www.wikidata.org/wiki/Q109731, https:...
#
#                                                  links  \
# 213  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 252  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 683  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 198  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                            nobelPrizes      knownName.en  \
# 213  [{'awardYear': '1901', 'category': {'en': 'Phy...  Emil von Behring
# 252  [{'awardYear': '1922', 'category': {'en': 'Che...  Francis W. Aston
# 683  [{'awardYear': '1938', 'category': {'en': 'Lit...        Pearl Buck
# 198  [{'awardYear': '1992', 'category': {'en': 'Phy...    Edwin G. Krebs
#
#          knownName.se givenName.en givenName.se  ... birthCountry.no  \
# 213  Emil von Behring         Emil         Emil  ...             NaN
# 252  Francis W. Aston   Francis W.   Francis W.  ...             NaN
# 683        Pearl Buck        Pearl        Pearl  ...             NaN
# 198    Edwin G. Krebs     Edwin G.     Edwin G.  ...             NaN
#
#     birthCountry.se birthCountryNow.en birthCountryNow.no birthCountryNow.se  \
# 213             NaN                NaN                NaN                NaN
# 252             NaN                NaN                NaN                NaN
# 683             NaN                NaN                NaN                NaN
# 198             NaN                NaN                NaN                NaN
#
#     birthContinent.en knownName.no givenName.no familyName.no fullName.no
# 213               NaN          NaN          NaN           NaN         NaN
# 252               NaN          NaN          NaN           NaN         NaN
# 683               NaN          NaN          NaN           NaN         NaN
# 198               NaN          NaN          NaN           NaN         NaN
#
# [4 rows x 100 columns]

# %% [markdown]
# ## Check Wikidata matches

# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

query = """SELECT ?item ?itemLabel ?NobelAPI ?death WHERE {
  # ?item wdt:P8024 ?NobelAPI.
  OPTIONAL {?item wdt:P570 ?death}
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
} order by xsd:integer(?NobelAPI)"""


def get_sparql_dataframe(endpoint_url, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    user_agent = "salgo60/%s.%s" % (sys.version_info[0], sys.version_info[1])
 
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']
    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

WDNobel = get_sparql_dataframe(endpoint_url, query)

# %%
WDNobel["NobelAPI"] = WDNobel["NobelAPI"].astype("int")
WDNobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item       975 non-null    object
#  1   itemLabel  975 non-null    object
#  2   NobelAPI   975 non-null    int64
#  3   death      660 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 30.6+ KB

# %% [markdown]
# ### Compare WD <-> Nobel

# %%
WDNobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item       975 non-null    object
#  1   itemLabel  975 non-null    object
#  2   NobelAPI   975 non-null    int64
#  3   death      660 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 30.6+ KB

# %%
dftotPrize["id"] = dftotPrize["id"].astype("int")

#dftotPrize.info()

# %%
dfmerge = pd.merge(WDNobel, dftotPrize,how='outer', left_on="NobelAPI",right_on="id",indicator=True)
dfmerge['_merge'] = dfmerge['_merge'].str.replace('left_only','WD_only').str.replace('right_only','Nobel_only')
dfmerge.rename(columns={"_merge": "WD_Nobel"},inplace = True)    
#dfmerge[-10:]

# %%
dfmerge[dfmerge["WD_Nobel"]!="both"]
# Out:
# Empty DataFrame
# Columns: [item, itemLabel, NobelAPI, death, id, fileName, gender, sameAs, links, nobelPrizes, knownName.en, knownName.se, givenName.en, givenName.se, familyName.en, familyName.se, fullName.en, fullName.se, birth.date, birth.place.city.en, birth.place.city.no, birth.place.city.se, birth.place.country.en, birth.place.country.no, birth.place.country.se, birth.place.cityNow.en, birth.place.cityNow.no, birth.place.cityNow.se, birth.place.cityNow.sameAs, birth.place.countryNow.en, birth.place.countryNow.no, birth.place.countryNow.se, birth.place.countryNow.sameAs, birth.place.continent.en, birth.place.continent.no, birth.place.continent.se, birth.place.locationString.en, birth.place.locationString.no, birth.place.locationString.se, wikipedia.slug, wikipedia.english, wikidata.id, wikidata.url, death.date, death.place.city.en, death.place.city.no, death.place.city.se, death.place.country.en, death.place.country.no, death.place.country.se, death.place.country.sameAs, death.place.cityNow.en, death.place.cityNow.no, death.place.cityNow.se, death.place.cityNow.sameAs, death.place.countryNow.en, death.place.countryNow.no, death.place.countryNow.se, death.place.countryNow.sameAs, death.place.continent.en, death.place.continent.no, death.place.continent.se, death.place.locationString.en, death.place.locationString.no, death.place.locationString.se, nativeName, acronym, orgName.en, orgName.no, orgName.se, founded.date, founded.place.city.en, founded.place.city.no, founded.place.city.se, founded.place.country.en, founded.place.country.no, founded.place.country.se, founded.place.country.sameAs, founded.place.cityNow.en, founded.place.cityNow.no, founded.place.cityNow.se, founded.place.cityNow.sameAs, founded.place.countryNow.en, founded.place.countryNow.no, founded.place.countryNow.se, founded.place.countryNow.sameAs, founded.place.continent.en, founded.place.continent.no, founded.place.continent.se, founded.place.locationString.en, founded.place.locationString.no, founded.place.locationString.se, penName, birthCountry.en, birthCountry.no, birthCountry.se, birthCountryNow.en, birthCountryNow.no, birthCountryNow.se, birthContinent.en, ...]
# Index: []
#
# [0 rows x 105 columns]

# %%
WDNobel['wikidata'] = WDNobel['item'].str.replace('http://www.wikidata.org/entity/','')
# Out:
# <ipython-input-18-0e6ca1d6257f>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   WDNobel['wikidata'] = WDNobel['item'].str.replace('http://www.wikidata.org/entity/','')

# %%
WDNobel.head()
# Out:
#                                     item        itemLabel  NobelAPI  \
# 0  http://www.wikidata.org/entity/Q35149  Wilhelm Röntgen         1
# 1  http://www.wikidata.org/entity/Q41688  Hendrik Lorentz         2
# 2  http://www.wikidata.org/entity/Q79000    Pieter Zeeman         3
# 3  http://www.wikidata.org/entity/Q41269  Henri Becquerel         4
# 4  http://www.wikidata.org/entity/Q37463     Pierre Curie         5
#
#                   death wikidata
# 0  1923-02-10T00:00:00Z   Q35149
# 1  1928-02-04T00:00:00Z   Q41688
# 2  1943-10-09T00:00:00Z   Q79000
# 3  1908-08-25T00:00:00Z   Q41269
# 4  1906-04-19T00:00:00Z   Q37463

# %%
#Merge on the Wikidata Qnumber at NobelTot  
dfmergeWD = pd.merge(WDNobel, dftotPrize,how='outer', left_on="wikidata",right_on="wikidata.id",indicator=True)
dfmergeWD['_merge'] = dfmergeWD['_merge'].str.replace('left_only','WD_only').str.replace('right_only','Nobel_only')
dfmergeWD.rename(columns={"_merge": "WD_Nobel"},inplace = True)    
dfmergeWD["WD_Nobel"].value_counts()
# Out:
# both          974
# Nobel_only      2
# WD_only         1
# Name: WD_Nobel, dtype: int64

# %%
dfmergeWD[dfmergeWD["WD_Nobel"]!="both"]
# Out:
#                                       item                     itemLabel  \
# 826  http://www.wikidata.org/entity/Q42037  Jean-Marie Gustave Le Clézio
# 975                                    NaN                           NaN
# 976                                    NaN                           NaN
#
#      NobelAPI death wikidata     id          fileName gender  \
# 826     832.0  None   Q42037    NaN               NaN    NaN
# 975       NaN   NaN      NaN  832.0            clezio   male
# 976       NaN   NaN      NaN  523.0  red-cross-league    NaN
#
#                                                 sameAs  \
# 826                                                NaN
# 975  [https://www.wikidata.org/wiki/Q7884119, https...
# 976  [https://www.wikidata.org/wiki/Q1069175, https...
#
#                                                  links  ... birthCountry.se  \
# 826                                                NaN  ...             NaN
# 975  [{'rel': 'laureate', 'href': 'https://api.nobe...  ...             NaN
# 976  [{'rel': 'laureate', 'href': 'https://api.nobe...  ...             NaN
#
#     birthCountryNow.en birthCountryNow.no birthCountryNow.se  \
# 826                NaN                NaN                NaN
# 975                NaN                NaN                NaN
# 976                NaN                NaN                NaN
#
#     birthContinent.en knownName.no givenName.no familyName.no fullName.no  \
# 826               NaN          NaN          NaN           NaN         NaN
# 975               NaN          NaN          NaN           NaN         NaN
# 976               NaN          NaN          NaN           NaN         NaN
#
#        WD_Nobel
# 826     WD_only
# 975  Nobel_only
# 976  Nobel_only
#
# [3 rows x 106 columns]

# %% [markdown]
# #### Check that Wikidata and api.nobelprize.org is in synch

# %%
dfmerge["WD_Nobel"].value_counts()
# Out:
# both    975
# Name: WD_Nobel, dtype: int64

# %%
Nobelonly = dfmerge[dfmerge["WD_Nobel"]=="Nobel_only"].copy() 

from IPython.display import HTML
Nobelonly["Nobel"] = "<a href='https://api.nobelprize.org/v1/laureate.json?id=" + Nobelonly["id"] + "'>link</a>"
Nobelonly["Nobelhtml"] = "<a href='https://www.nobelprize.org/laureate/" + Nobelonly["id"] + "'>html</a>"
pd.set_option("display.max.columns", None) 
HTML(Nobelonly.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item</th>
#       <th>itemLabel</th>
#       <th>NobelAPI</th>
#       <th>death</th>
#       <th>id</th>
#       <th>fileName</th>
#       <th>gender</th>
#       <th>sameAs</th>
#       <th>links</th>
#       <th>nobelPrizes</th>
#       <th>knownName.en</th>
#       <th>knownName.se</th>
#       <th>givenName.en</th>
#       <th>givenName.se</th>
#       <th>familyName.en</th>
#       <th>familyName.se</th>
#       <th>fullName.en</th>
#       <th>fullName.se</th>
#       <th>birth.date</th>
#       <th>birth.place.city.en</th>
#       <th>birth.place.city.no</th>
#       <th>birth.place.city.se</th>
#       <th>birth.place.country.en</th>
#       <th>birth.place.country.no</th>
#       <th>birth.place.country.se</th>
#       <th>birth.place.cityNow.en</th>
#       <th>birth.place.cityNow.no</th>
#       <th>birth.place.cityNow.se</th>
#       <th>birth.place.cityNow.sameAs</th>
#       <th>birth.place.countryNow.en</th>
#       <th>birth.place.countryNow.no</th>
#       <th>birth.place.countryNow.se</th>
#       <th>birth.place.countryNow.sameAs</th>
#       <th>birth.place.continent.en</th>
#       <th>birth.place.continent.no</th>
#       <th>birth.place.continent.se</th>
#       <th>birth.place.locationString.en</th>
#       <th>birth.place.locationString.no</th>
#       <th>birth.place.locationString.se</th>
#       <th>wikipedia.slug</th>
#       <th>wikipedia.english</th>
#       <th>wikidata.id</th>
#       <th>wikidata.url</th>
#       <th>death.date</th>
#       <th>death.place.city.en</th>
#       <th>death.place.city.no</th>
#       <th>death.place.city.se</th>
#       <th>death.place.country.en</th>
#       <th>death.place.country.no</th>
#       <th>death.place.country.se</th>
#       <th>death.place.country.sameAs</th>
#       <th>death.place.cityNow.en</th>
#       <th>death.place.cityNow.no</th>
#       <th>death.place.cityNow.se</th>
#       <th>death.place.cityNow.sameAs</th>
#       <th>death.place.countryNow.en</th>
#       <th>death.place.countryNow.no</th>
#       <th>death.place.countryNow.se</th>
#       <th>death.place.countryNow.sameAs</th>
#       <th>death.place.continent.en</th>
#       <th>death.place.continent.no</th>
#       <th>death.place.continent.se</th>
#       <th>death.place.locationString.en</th>
#       <th>death.place.locationString.no</th>
#       <th>death.place.locationString.se</th>
#       <th>nativeName</th>
#       <th>acronym</th>
#       <th>orgName.en</th>
#       <th>orgName.no</th>
#       <th>orgName.se</th>
#       <th>founded.date</th>
#       <th>founded.place.city.en</th>
#       <th>founded.place.city.no</th>
#       <th>founded.place.city.se</th>
#       <th>founded.place.country.en</th>
#       <th>founded.place.country.no</th>
#       <th>founded.place.country.se</th>
#       <th>founded.place.country.sameAs</th>
#       <th>founded.place.cityNow.en</th>
#       <th>founded.place.cityNow.no</th>
#       <th>founded.place.cityNow.se</th>
#       <th>founded.place.cityNow.sameAs</th>
#       <th>founded.place.countryNow.en</th>
#       <th>founded.place.countryNow.no</th>
#       <th>founded.place.countryNow.se</th>
#       <th>founded.place.countryNow.sameAs</th>
#       <th>founded.place.continent.en</th>
#       <th>founded.place.continent.no</th>
#       <th>founded.place.continent.se</th>
#       <th>founded.place.locationString.en</th>
#       <th>founded.place.locationString.no</th>
#       <th>founded.place.locationString.se</th>
#       <th>penName</th>
#       <th>birthCountry.en</th>
#       <th>birthCountry.no</th>
#       <th>birthCountry.se</th>
#       <th>birthCountryNow.en</th>
#       <th>birthCountryNow.no</th>
#       <th>birthCountryNow.se</th>
#       <th>birthContinent.en</th>
#       <th>knownName.no</th>
#       <th>givenName.no</th>
#       <th>familyName.no</th>
#       <th>fullName.no</th>
#       <th>WD_Nobel</th>
#       <th>Nobel</th>
#       <th>Nobelhtml</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
dfmerge.to_csv("Nobel_dfmerge_2_1.csv")
Nobelonly.to_csv("Nobel_only.csv")

# %%
WDonly = dfmerge[dfmerge["WD_Nobel"]=="WD_only"].copy() 
WDonly
# Out:
# Empty DataFrame
# Columns: [item, itemLabel, NobelAPI, death, id, fileName, gender, sameAs, links, nobelPrizes, knownName.en, knownName.se, givenName.en, givenName.se, familyName.en, familyName.se, fullName.en, fullName.se, birth.date, birth.place.city.en, birth.place.city.no, birth.place.city.se, birth.place.country.en, birth.place.country.no, birth.place.country.se, birth.place.cityNow.en, birth.place.cityNow.no, birth.place.cityNow.se, birth.place.cityNow.sameAs, birth.place.countryNow.en, birth.place.countryNow.no, birth.place.countryNow.se, birth.place.countryNow.sameAs, birth.place.continent.en, birth.place.continent.no, birth.place.continent.se, birth.place.locationString.en, birth.place.locationString.no, birth.place.locationString.se, wikipedia.slug, wikipedia.english, wikidata.id, wikidata.url, death.date, death.place.city.en, death.place.city.no, death.place.city.se, death.place.country.en, death.place.country.no, death.place.country.se, death.place.country.sameAs, death.place.cityNow.en, death.place.cityNow.no, death.place.cityNow.se, death.place.cityNow.sameAs, death.place.countryNow.en, death.place.countryNow.no, death.place.countryNow.se, death.place.countryNow.sameAs, death.place.continent.en, death.place.continent.no, death.place.continent.se, death.place.locationString.en, death.place.locationString.no, death.place.locationString.se, nativeName, acronym, orgName.en, orgName.no, orgName.se, founded.date, founded.place.city.en, founded.place.city.no, founded.place.city.se, founded.place.country.en, founded.place.country.no, founded.place.country.se, founded.place.country.sameAs, founded.place.cityNow.en, founded.place.cityNow.no, founded.place.cityNow.se, founded.place.cityNow.sameAs, founded.place.countryNow.en, founded.place.countryNow.no, founded.place.countryNow.se, founded.place.countryNow.sameAs, founded.place.continent.en, founded.place.continent.no, founded.place.continent.se, founded.place.locationString.en, founded.place.locationString.no, founded.place.locationString.se, penName, birthCountry.en, birthCountry.no, birthCountry.se, birthCountryNow.en, birthCountryNow.no, birthCountryNow.se, birthContinent.en, ...]
# Index: []

# %%
print("End run: ", datetime.now())
# Out:
# End run:  2021-08-10 08:10:43.730654

# %%
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Time elapsed (hh:mm:ss.ms) 0:00:10.698442

# %%
for l, r in dfmerge.iterrows():
    #print (l,r["nobelPrizes"][0]["awardYear"],r["nobelPrizes"][0]["category"]["en"])
    dfmerge.at[l,"awardYear"] = r["nobelPrizes"][0]["awardYear"]
    dfmerge.at[l,"category"]= r["nobelPrizes"][0]["category"]["en"]

# %% [markdown]
# ### Death date
# Wikipedia is known of it fast process nof updating death dates. This is a small check of diff as the Nobel Data
# is not updated so often and also we have seen problem with dates missing calendars they use ...
#
# * WDNobel has death
# * Nobel API has death.date

# %%
# Find when Nobel has not death date and Wikidata has   
dfmerge[dfmerge["death.date"].isnull()].head(3) # has no value
# Out:
#                                       item       itemLabel  NobelAPI death  \
# 68  http://www.wikidata.org/entity/Q181369  Chen-ning Yang        68  None
# 69  http://www.wikidata.org/entity/Q183679   Tsung-Dao Lee        69  None
# 94   http://www.wikidata.org/entity/Q82563     Leon Cooper        95  None
#
#     id fileName gender                                             sameAs  \
# 68  68     yang   male  [https://www.wikidata.org/wiki/Q181369, https:...
# 69  69      lee   male  [https://www.wikidata.org/wiki/Q183679, https:...
# 94  95   cooper   male  [https://www.wikidata.org/wiki/Q82563, https:/...
#
#                                                 links  \
# 68  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 69  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 94  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                           nobelPrizes    knownName.en  \
# 68  [{'awardYear': '1957', 'category': {'en': 'Phy...  Chen Ning Yang
# 69  [{'awardYear': '1957', 'category': {'en': 'Phy...   Tsung-Dao Lee
# 94  [{'awardYear': '1972', 'category': {'en': 'Phy...  Leon N. Cooper
#
#       knownName.se givenName.en givenName.se familyName.en familyName.se  \
# 68  Chen Ning Yang    Chen Ning    Chen Ning          Yang          Yang
# 69   Tsung-Dao Lee    Tsung-Dao    Tsung-Dao           Lee           Lee
# 94  Leon N. Cooper      Leon N.      Leon N.        Cooper        Cooper
#
#              fullName.en           fullName.se  birth.date  \
# 68        Chen Ning Yang        Chen Ning Yang  1922-09-22
# 69  Tsung-Dao (T.D.) Lee  Tsung-Dao (T.D.) Lee  1926-11-24
# 94      Leon Neil Cooper      Leon Neil Cooper  1930-02-28
#
#    birth.place.city.en birth.place.city.no birth.place.city.se  \
# 68       Hofei, Anhwei       Hofei, Anhwei       Hofei, Anhwei
# 69            Shanghai            Shanghai            Shanghai
# 94        New York, NY        New York, NY        New York, NY
#
#    birth.place.country.en birth.place.country.no birth.place.country.se  \
# 68                  China                   Kina                   Kina
# 69                  China                   Kina                   Kina
# 94                    USA                    USA                    USA
#
#    birth.place.cityNow.en birth.place.cityNow.no birth.place.cityNow.se  \
# 68          Hofei, Anhwei          Hofei, Anhwei          Hofei, Anhwei
# 69               Shanghai               Shanghai               Shanghai
# 94           New York, NY           New York, NY           New York, NY
#
#                            birth.place.cityNow.sameAs  \
# 68  [https://www.wikidata.org/wiki/Q185684, https:...
# 69  [https://www.wikidata.org/wiki/Q8686, https://...
# 94  [https://www.wikidata.org/wiki/Q60, https://ww...
#
#    birth.place.countryNow.en birth.place.countryNow.no  \
# 68                     China                      Kina
# 69                     China                      Kina
# 94                       USA                       USA
#
#    birth.place.countryNow.se         birth.place.countryNow.sameAs  \
# 68                      Kina  [https://www.wikidata.org/wiki/Q148]
# 69                      Kina  [https://www.wikidata.org/wiki/Q148]
# 94                       USA   [https://www.wikidata.org/wiki/Q30]
#
#    birth.place.continent.en birth.place.continent.no birth.place.continent.se  \
# 68                     Asia                     Asia                    Asien
# 69                     Asia                     Asia                    Asien
# 94            North America             Nord-Amerika              Nordamerika
#
#    birth.place.locationString.en birth.place.locationString.no  \
# 68          Hofei, Anhwei, China           Hofei, Anhwei, Kina
# 69               Shanghai, China                Shanghai, Kina
# 94             New York, NY, USA             New York, NY, USA
#
#    birth.place.locationString.se  wikipedia.slug  \
# 68           Hofei, Anhwei, Kina  Chen_Ning_Yang
# 69                Shanghai, Kina   Tsung-Dao_Lee
# 94             New York, NY, USA     Leon_Cooper
#
#                                wikipedia.english wikidata.id  \
# 68  https://en.wikipedia.org/wiki/Chen_Ning_Yang     Q181369
# 69   https://en.wikipedia.org/wiki/Tsung-Dao_Lee     Q183679
# 94     https://en.wikipedia.org/wiki/Leon_Cooper      Q82563
#
#                              wikidata.url death.date death.place.city.en  \
# 68  https://www.wikidata.org/wiki/Q181369        NaN                 NaN
# 69  https://www.wikidata.org/wiki/Q183679        NaN                 NaN
# 94   https://www.wikidata.org/wiki/Q82563        NaN                 NaN
#
#    death.place.city.no death.place.city.se death.place.country.en  \
# 68                 NaN                 NaN                    NaN
# 69                 NaN                 NaN                    NaN
# 94                 NaN                 NaN                    NaN
#
#    death.place.country.no death.place.country.se death.place.country.sameAs  \
# 68                    NaN                    NaN                        NaN
# 69                    NaN                    NaN                        NaN
# 94                    NaN                    NaN                        NaN
#
#    death.place.cityNow.en death.place.cityNow.no death.place.cityNow.se  \
# 68                    NaN                    NaN                    NaN
# 69                    NaN                    NaN                    NaN
# 94                    NaN                    NaN                    NaN
#
#    death.place.cityNow.sameAs death.place.countryNow.en  \
# 68                        NaN                       NaN
# 69                        NaN                       NaN
# 94                        NaN                       NaN
#
#    death.place.countryNow.no death.place.countryNow.se  \
# 68                       NaN                       NaN
# 69                       NaN                       NaN
# 94                       NaN                       NaN
#
#    death.place.countryNow.sameAs death.place.continent.en  \
# 68                           NaN                      NaN
# 69                           NaN                      NaN
# 94                           NaN                      NaN
#
#    death.place.continent.no death.place.continent.se  \
# 68                      NaN                      NaN
# 69                      NaN                      NaN
# 94                      NaN                      NaN
#
#    death.place.locationString.en death.place.locationString.no  \
# 68                           NaN                           NaN
# 69                           NaN                           NaN
# 94                           NaN                           NaN
#
#    death.place.locationString.se nativeName acronym orgName.en orgName.no  \
# 68                           NaN        NaN     NaN        NaN        NaN
# 69                           NaN        NaN     NaN        NaN        NaN
# 94                           NaN        NaN     NaN        NaN        NaN
#
#    orgName.se founded.date founded.place.city.en founded.place.city.no  \
# 68        NaN          NaN                   NaN                   NaN
# 69        NaN          NaN                   NaN                   NaN
# 94        NaN          NaN                   NaN                   NaN
#
#    founded.place.city.se founded.place.country.en founded.place.country.no  \
# 68                   NaN                      NaN                      NaN
# 69                   NaN                      NaN                      NaN
# 94                   NaN                      NaN                      NaN
#
#    founded.place.country.se founded.place.country.sameAs  \
# 68                      NaN                          NaN
# 69                      NaN                          NaN
# 94                      NaN                          NaN
#
#    founded.place.cityNow.en founded.place.cityNow.no founded.place.cityNow.se  \
# 68                      NaN                      NaN                      NaN
# 69                      NaN                      NaN                      NaN
# 94                      NaN                      NaN                      NaN
#
#    founded.place.cityNow.sameAs founded.place.countryNow.en  \
# 68                          NaN                         NaN
# 69                          NaN                         NaN
# 94                          NaN                         NaN
#
#    founded.place.countryNow.no founded.place.countryNow.se  \
# 68                         NaN                         NaN
# 69                         NaN                         NaN
# 94                         NaN                         NaN
#
#    founded.place.countryNow.sameAs founded.place.continent.en  \
# 68                             NaN                        NaN
# 69                             NaN                        NaN
# 94                             NaN                        NaN
#
#    founded.place.continent.no founded.place.continent.se  \
# 68                        NaN                        NaN
# 69                        NaN                        NaN
# 94                        NaN                        NaN
#
#    founded.place.locationString.en founded.place.locationString.no  \
# 68                             NaN                             NaN
# 69                             NaN                             NaN
# 94                             NaN                             NaN
#
#    founded.place.locationString.se penName birthCountry.en birthCountry.no  \
# 68                             NaN     NaN             NaN             NaN
# 69                             NaN     NaN             NaN             NaN
# 94                             NaN     NaN             NaN             NaN
#
#    birthCountry.se birthCountryNow.en birthCountryNow.no birthCountryNow.se  \
# 68             NaN                NaN                NaN                NaN
# 69             NaN                NaN                NaN                NaN
# 94             NaN                NaN                NaN                NaN
#
#    birthContinent.en knownName.no givenName.no familyName.no fullName.no  \
# 68               NaN          NaN          NaN           NaN         NaN
# 69               NaN          NaN          NaN           NaN         NaN
# 94               NaN          NaN          NaN           NaN         NaN
#
#    WD_Nobel awardYear category  \
# 68     both      1957  Physics
# 69     both      1957  Physics
# 94     both      1972  Physics
#
#                                              linkjson  \
# 68  <a href='https://api.nobelprize.org/v1/laureat...
# 69  <a href='https://api.nobelprize.org/v1/laureat...
# 94  <a href='https://api.nobelprize.org/v1/laureat...
#
#                                              linkhtml  \
# 68  <a href='https://www.nobelprize.org/laureate/6...
# 69  <a href='https://www.nobelprize.org/laureate/6...
# 94  <a href='https://www.nobelprize.org/laureate/9...
#
#                                                    wd
# 68  <a href='http://www.wikidata.org/entity/Q18136...
# 69  <a href='http://www.wikidata.org/entity/Q18367...
# 94  <a href='http://www.wikidata.org/entity/Q82563...

# %%
dfmerge[dfmerge["death"].isnull()].head(3)# Wikidata has no value
# Out:
#                                       item       itemLabel  NobelAPI death  \
# 68  http://www.wikidata.org/entity/Q181369  Chen-ning Yang        68  None
# 69  http://www.wikidata.org/entity/Q183679   Tsung-Dao Lee        69  None
# 94   http://www.wikidata.org/entity/Q82563     Leon Cooper        95  None
#
#     id fileName gender                                             sameAs  \
# 68  68     yang   male  [https://www.wikidata.org/wiki/Q181369, https:...
# 69  69      lee   male  [https://www.wikidata.org/wiki/Q183679, https:...
# 94  95   cooper   male  [https://www.wikidata.org/wiki/Q82563, https:/...
#
#                                                 links  \
# 68  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 69  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 94  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                           nobelPrizes    knownName.en  \
# 68  [{'awardYear': '1957', 'category': {'en': 'Phy...  Chen Ning Yang
# 69  [{'awardYear': '1957', 'category': {'en': 'Phy...   Tsung-Dao Lee
# 94  [{'awardYear': '1972', 'category': {'en': 'Phy...  Leon N. Cooper
#
#       knownName.se givenName.en givenName.se familyName.en familyName.se  \
# 68  Chen Ning Yang    Chen Ning    Chen Ning          Yang          Yang
# 69   Tsung-Dao Lee    Tsung-Dao    Tsung-Dao           Lee           Lee
# 94  Leon N. Cooper      Leon N.      Leon N.        Cooper        Cooper
#
#              fullName.en           fullName.se  birth.date  \
# 68        Chen Ning Yang        Chen Ning Yang  1922-09-22
# 69  Tsung-Dao (T.D.) Lee  Tsung-Dao (T.D.) Lee  1926-11-24
# 94      Leon Neil Cooper      Leon Neil Cooper  1930-02-28
#
#    birth.place.city.en birth.place.city.no birth.place.city.se  \
# 68       Hofei, Anhwei       Hofei, Anhwei       Hofei, Anhwei
# 69            Shanghai            Shanghai            Shanghai
# 94        New York, NY        New York, NY        New York, NY
#
#    birth.place.country.en birth.place.country.no birth.place.country.se  \
# 68                  China                   Kina                   Kina
# 69                  China                   Kina                   Kina
# 94                    USA                    USA                    USA
#
#    birth.place.cityNow.en birth.place.cityNow.no birth.place.cityNow.se  \
# 68          Hofei, Anhwei          Hofei, Anhwei          Hofei, Anhwei
# 69               Shanghai               Shanghai               Shanghai
# 94           New York, NY           New York, NY           New York, NY
#
#                            birth.place.cityNow.sameAs  \
# 68  [https://www.wikidata.org/wiki/Q185684, https:...
# 69  [https://www.wikidata.org/wiki/Q8686, https://...
# 94  [https://www.wikidata.org/wiki/Q60, https://ww...
#
#    birth.place.countryNow.en birth.place.countryNow.no  \
# 68                     China                      Kina
# 69                     China                      Kina
# 94                       USA                       USA
#
#    birth.place.countryNow.se         birth.place.countryNow.sameAs  \
# 68                      Kina  [https://www.wikidata.org/wiki/Q148]
# 69                      Kina  [https://www.wikidata.org/wiki/Q148]
# 94                       USA   [https://www.wikidata.org/wiki/Q30]
#
#    birth.place.continent.en birth.place.continent.no birth.place.continent.se  \
# 68                     Asia                     Asia                    Asien
# 69                     Asia                     Asia                    Asien
# 94            North America             Nord-Amerika              Nordamerika
#
#    birth.place.locationString.en birth.place.locationString.no  \
# 68          Hofei, Anhwei, China           Hofei, Anhwei, Kina
# 69               Shanghai, China                Shanghai, Kina
# 94             New York, NY, USA             New York, NY, USA
#
#    birth.place.locationString.se  wikipedia.slug  \
# 68           Hofei, Anhwei, Kina  Chen_Ning_Yang
# 69                Shanghai, Kina   Tsung-Dao_Lee
# 94             New York, NY, USA     Leon_Cooper
#
#                                wikipedia.english wikidata.id  \
# 68  https://en.wikipedia.org/wiki/Chen_Ning_Yang     Q181369
# 69   https://en.wikipedia.org/wiki/Tsung-Dao_Lee     Q183679
# 94     https://en.wikipedia.org/wiki/Leon_Cooper      Q82563
#
#                              wikidata.url death.date death.place.city.en  \
# 68  https://www.wikidata.org/wiki/Q181369        NaN                 NaN
# 69  https://www.wikidata.org/wiki/Q183679        NaN                 NaN
# 94   https://www.wikidata.org/wiki/Q82563        NaN                 NaN
#
#    death.place.city.no death.place.city.se death.place.country.en  \
# 68                 NaN                 NaN                    NaN
# 69                 NaN                 NaN                    NaN
# 94                 NaN                 NaN                    NaN
#
#    death.place.country.no death.place.country.se death.place.country.sameAs  \
# 68                    NaN                    NaN                        NaN
# 69                    NaN                    NaN                        NaN
# 94                    NaN                    NaN                        NaN
#
#    death.place.cityNow.en death.place.cityNow.no death.place.cityNow.se  \
# 68                    NaN                    NaN                    NaN
# 69                    NaN                    NaN                    NaN
# 94                    NaN                    NaN                    NaN
#
#    death.place.cityNow.sameAs death.place.countryNow.en  \
# 68                        NaN                       NaN
# 69                        NaN                       NaN
# 94                        NaN                       NaN
#
#    death.place.countryNow.no death.place.countryNow.se  \
# 68                       NaN                       NaN
# 69                       NaN                       NaN
# 94                       NaN                       NaN
#
#    death.place.countryNow.sameAs death.place.continent.en  \
# 68                           NaN                      NaN
# 69                           NaN                      NaN
# 94                           NaN                      NaN
#
#    death.place.continent.no death.place.continent.se  \
# 68                      NaN                      NaN
# 69                      NaN                      NaN
# 94                      NaN                      NaN
#
#    death.place.locationString.en death.place.locationString.no  \
# 68                           NaN                           NaN
# 69                           NaN                           NaN
# 94                           NaN                           NaN
#
#    death.place.locationString.se nativeName acronym orgName.en orgName.no  \
# 68                           NaN        NaN     NaN        NaN        NaN
# 69                           NaN        NaN     NaN        NaN        NaN
# 94                           NaN        NaN     NaN        NaN        NaN
#
#    orgName.se founded.date founded.place.city.en founded.place.city.no  \
# 68        NaN          NaN                   NaN                   NaN
# 69        NaN          NaN                   NaN                   NaN
# 94        NaN          NaN                   NaN                   NaN
#
#    founded.place.city.se founded.place.country.en founded.place.country.no  \
# 68                   NaN                      NaN                      NaN
# 69                   NaN                      NaN                      NaN
# 94                   NaN                      NaN                      NaN
#
#    founded.place.country.se founded.place.country.sameAs  \
# 68                      NaN                          NaN
# 69                      NaN                          NaN
# 94                      NaN                          NaN
#
#    founded.place.cityNow.en founded.place.cityNow.no founded.place.cityNow.se  \
# 68                      NaN                      NaN                      NaN
# 69                      NaN                      NaN                      NaN
# 94                      NaN                      NaN                      NaN
#
#    founded.place.cityNow.sameAs founded.place.countryNow.en  \
# 68                          NaN                         NaN
# 69                          NaN                         NaN
# 94                          NaN                         NaN
#
#    founded.place.countryNow.no founded.place.countryNow.se  \
# 68                         NaN                         NaN
# 69                         NaN                         NaN
# 94                         NaN                         NaN
#
#    founded.place.countryNow.sameAs founded.place.continent.en  \
# 68                             NaN                        NaN
# 69                             NaN                        NaN
# 94                             NaN                        NaN
#
#    founded.place.continent.no founded.place.continent.se  \
# 68                        NaN                        NaN
# 69                        NaN                        NaN
# 94                        NaN                        NaN
#
#    founded.place.locationString.en founded.place.locationString.no  \
# 68                             NaN                             NaN
# 69                             NaN                             NaN
# 94                             NaN                             NaN
#
#    founded.place.locationString.se penName birthCountry.en birthCountry.no  \
# 68                             NaN     NaN             NaN             NaN
# 69                             NaN     NaN             NaN             NaN
# 94                             NaN     NaN             NaN             NaN
#
#    birthCountry.se birthCountryNow.en birthCountryNow.no birthCountryNow.se  \
# 68             NaN                NaN                NaN                NaN
# 69             NaN                NaN                NaN                NaN
# 94             NaN                NaN                NaN                NaN
#
#    birthContinent.en knownName.no givenName.no familyName.no fullName.no  \
# 68               NaN          NaN          NaN           NaN         NaN
# 69               NaN          NaN          NaN           NaN         NaN
# 94               NaN          NaN          NaN           NaN         NaN
#
#    WD_Nobel awardYear category  \
# 68     both      1957  Physics
# 69     both      1957  Physics
# 94     both      1972  Physics
#
#                                              linkjson  \
# 68  <a href='https://api.nobelprize.org/v1/laureat...
# 69  <a href='https://api.nobelprize.org/v1/laureat...
# 94  <a href='https://api.nobelprize.org/v1/laureat...
#
#                                              linkhtml  \
# 68  <a href='https://www.nobelprize.org/laureate/6...
# 69  <a href='https://www.nobelprize.org/laureate/6...
# 94  <a href='https://www.nobelprize.org/laureate/9...
#
#                                                    wd
# 68  <a href='http://www.wikidata.org/entity/Q18136...
# 69  <a href='http://www.wikidata.org/entity/Q18367...
# 94  <a href='http://www.wikidata.org/entity/Q82563...

# %%
#### DIFF  Nobel data and Wikidata ####

# %%
dfmerge[ dfmerge["death.date"].isnull() & (~dfmerge["death"].isnull())]# Wikidata death has value and Nobel not
# Out:
#                                        item             itemLabel  NobelAPI  \
# 841  http://www.wikidata.org/entity/Q232062  Oliver E. Williamson       847
#
#                     death   id    fileName gender  \
# 841  2020-05-21T00:00:00Z  847  williamson   male
#
#                                                 sameAs  \
# 841  [https://www.wikidata.org/wiki/Q232062, https:...
#
#                                                  links  \
# 841  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                            nobelPrizes          knownName.en  \
# 841  [{'awardYear': '2009', 'category': {'en': 'Eco...  Oliver E. Williamson
#
#              knownName.se givenName.en givenName.se familyName.en  \
# 841  Oliver E. Williamson    Oliver E.    Oliver E.    Williamson
#
#     familyName.se           fullName.en           fullName.se  birth.date  \
# 841    Williamson  Oliver E. Williamson  Oliver E. Williamson  1932-09-27
#
#     birth.place.city.en birth.place.city.no birth.place.city.se  \
# 841        Superior, WI        Superior, WI        Superior, WI
#
#     birth.place.country.en birth.place.country.no birth.place.country.se  \
# 841                    USA                    USA                    USA
#
#     birth.place.cityNow.en birth.place.cityNow.no birth.place.cityNow.se  \
# 841           Superior, WI           Superior, WI           Superior, WI
#
#                             birth.place.cityNow.sameAs  \
# 841  [https://www.wikidata.org/wiki/Q984577, https:...
#
#     birth.place.countryNow.en birth.place.countryNow.no  \
# 841                       USA                       USA
#
#     birth.place.countryNow.se        birth.place.countryNow.sameAs  \
# 841                       USA  [https://www.wikidata.org/wiki/Q30]
#
#     birth.place.continent.en birth.place.continent.no  \
# 841            North America             Nord-Amerika
#
#     birth.place.continent.se birth.place.locationString.en  \
# 841              Nordamerika             Superior, WI, USA
#
#     birth.place.locationString.no birth.place.locationString.se  \
# 841             Superior, WI, USA             Superior, WI, USA
#
#            wikipedia.slug                                  wikipedia.english  \
# 841  Oliver_E._Williamson  https://en.wikipedia.org/wiki/Oliver_E._Willia...
#
#     wikidata.id                           wikidata.url death.date  \
# 841     Q232062  https://www.wikidata.org/wiki/Q232062        NaN
#
#     death.place.city.en death.place.city.no death.place.city.se  \
# 841                 NaN                 NaN                 NaN
#
#     death.place.country.en death.place.country.no death.place.country.se  \
# 841                    NaN                    NaN                    NaN
#
#     death.place.country.sameAs death.place.cityNow.en death.place.cityNow.no  \
# 841                        NaN                    NaN                    NaN
#
#     death.place.cityNow.se death.place.cityNow.sameAs  \
# 841                    NaN                        NaN
#
#     death.place.countryNow.en death.place.countryNow.no  \
# 841                       NaN                       NaN
#
#     death.place.countryNow.se death.place.countryNow.sameAs  \
# 841                       NaN                           NaN
#
#     death.place.continent.en death.place.continent.no  \
# 841                      NaN                      NaN
#
#     death.place.continent.se death.place.locationString.en  \
# 841                      NaN                           NaN
#
#     death.place.locationString.no death.place.locationString.se nativeName  \
# 841                           NaN                           NaN        NaN
#
#     acronym orgName.en orgName.no orgName.se founded.date  \
# 841     NaN        NaN        NaN        NaN          NaN
#
#     founded.place.city.en founded.place.city.no founded.place.city.se  \
# 841                   NaN                   NaN                   NaN
#
#     founded.place.country.en founded.place.country.no  \
# 841                      NaN                      NaN
#
#     founded.place.country.se founded.place.country.sameAs  \
# 841                      NaN                          NaN
#
#     founded.place.cityNow.en founded.place.cityNow.no  \
# 841                      NaN                      NaN
#
#     founded.place.cityNow.se founded.place.cityNow.sameAs  \
# 841                      NaN                          NaN
#
#     founded.place.countryNow.en founded.place.countryNow.no  \
# 841                         NaN                         NaN
#
#     founded.place.countryNow.se founded.place.countryNow.sameAs  \
# 841                         NaN                             NaN
#
#     founded.place.continent.en founded.place.continent.no  \
# 841                        NaN                        NaN
#
#     founded.place.continent.se founded.place.locationString.en  \
# 841                        NaN                             NaN
#
#     founded.place.locationString.no founded.place.locationString.se penName  \
# 841                             NaN                             NaN     NaN
#
#     birthCountry.en birthCountry.no birthCountry.se birthCountryNow.en  \
# 841             NaN             NaN             NaN                NaN
#
#     birthCountryNow.no birthCountryNow.se birthContinent.en knownName.no  \
# 841                NaN                NaN               NaN          NaN
#
#     givenName.no familyName.no fullName.no WD_Nobel awardYear  \
# 841          NaN           NaN         NaN     both      2009
#
#               category                                           linkjson  \
# 841  Economic Sciences  <a href='https://api.nobelprize.org/v1/laureat...
#
#                                               linkhtml  \
# 841  <a href='https://www.nobelprize.org/laureate/8...
#
#                                                     wd
# 841  <a href='http://www.wikidata.org/entity/Q23206...

# %% [markdown]
# #### Check diff death ####
# This is just a check if WD has a death value and Nobelprize not

# %%
pd.options.mode.chained_assignment = None 
diffdeath = dfmerge[ dfmerge["death.date"].isnull() & (~dfmerge["death"].isnull())]# Wikidata death has value and Nobel not
   
diffdeath["linkWD"] = "<a href='" + dfmerge["item"].astype(str) + "'>Wikidata</a>"
diffdeath["linkNobel"] = "<a href='https://api.nobelprize.org/v1/laureate.json?id=" + dfmerge["NobelAPI"].astype(str) + "'>Nobel API</a>"

pd.set_option("display.max.columns", None) 
HTML(diffdeath[{'NobelAPI','wikidata.id','knownName.en','linkWD','death','linkNobel','death.date'}].to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>linkWD</th>
#       <th>NobelAPI</th>
#       <th>wikidata.id</th>
#       <th>knownName.en</th>
#       <th>death.date</th>
#       <th>death</th>
#       <th>linkNobel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>841</th>
#       <td><a href='http://www.wikidata.org/entity/Q232062'>Wikidata</a></td>
#       <td>847</td>
#       <td>Q232062</td>
#       <td>Oliver E. Williamson</td>
#       <td>NaN</td>
#       <td>2020-05-21T00:00:00Z</td>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=847'>Nobel API</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Lesson learned
# Its a delay when the html page is linked after the announcement --> we do this list below to check when its ready and we can add it to Wikidata and the WIkipedia article

# %%
pd.set_option("max_info_columns", 140)
#dfmerge.info()

# %%
# see task xxx we can create links JSOn and HTML using the ID
dfmerge["linkjson"] = "<a href='https://api.nobelprize.org/v1/laureate.json?id=" + dfmerge["id"].astype(str) + "'>json</a>"
dfmerge["linkhtml"] = "<a href='https://www.nobelprize.org/laureate/" + dfmerge["id"].astype(str) + "'>html</a>"
dfmerge["wd"] = "<a href='" + dfmerge["item"].astype(str) + "'>Wikidata</a>"

pd.set_option("display.max.columns", None) 
HTML(dfmerge[{'wd','knownName.en','awardYear','category','linkjson','linkhtml'}].tail(15).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>linkjson</th>
#       <th>linkhtml</th>
#       <th>awardYear</th>
#       <th>knownName.en</th>
#       <th>category</th>
#       <th>wd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>960</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=982'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/982'>html</a></td>
#       <td>2019</td>
#       <td>Abhijit Banerjee</td>
#       <td>Economic Sciences</td>
#       <td><a href='http://www.wikidata.org/entity/Q320578'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>961</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=983'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/983'>html</a></td>
#       <td>2019</td>
#       <td>Esther Duflo</td>
#       <td>Economic Sciences</td>
#       <td><a href='http://www.wikidata.org/entity/Q434509'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>962</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=984'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/984'>html</a></td>
#       <td>2019</td>
#       <td>Michael Kremer</td>
#       <td>Economic Sciences</td>
#       <td><a href='http://www.wikidata.org/entity/Q1635006'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>963</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=985'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/985'>html</a></td>
#       <td>2020</td>
#       <td>Harvey J. Alter</td>
#       <td>Physiology or Medicine</td>
#       <td><a href='http://www.wikidata.org/entity/Q5677307'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>964</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=986'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/986'>html</a></td>
#       <td>2020</td>
#       <td>Michael Houghton</td>
#       <td>Physiology or Medicine</td>
#       <td><a href='http://www.wikidata.org/entity/Q1927895'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>965</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=987'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/987'>html</a></td>
#       <td>2020</td>
#       <td>Charles M. Rice</td>
#       <td>Physiology or Medicine</td>
#       <td><a href='http://www.wikidata.org/entity/Q22669757'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>966</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=988'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/988'>html</a></td>
#       <td>2020</td>
#       <td>Roger Penrose</td>
#       <td>Physics</td>
#       <td><a href='http://www.wikidata.org/entity/Q193803'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>967</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=989'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/989'>html</a></td>
#       <td>2020</td>
#       <td>Reinhard Genzel</td>
#       <td>Physics</td>
#       <td><a href='http://www.wikidata.org/entity/Q65807'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>968</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=990'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/990'>html</a></td>
#       <td>2020</td>
#       <td>Andrea Ghez</td>
#       <td>Physics</td>
#       <td><a href='http://www.wikidata.org/entity/Q493956'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>969</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=991'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/991'>html</a></td>
#       <td>2020</td>
#       <td>Emmanuelle Charpentier</td>
#       <td>Chemistry</td>
#       <td><a href='http://www.wikidata.org/entity/Q17280087'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>970</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=992'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/992'>html</a></td>
#       <td>2020</td>
#       <td>Jennifer A. Doudna</td>
#       <td>Chemistry</td>
#       <td><a href='http://www.wikidata.org/entity/Q56068'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>971</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=993'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/993'>html</a></td>
#       <td>2020</td>
#       <td>Louise Glück</td>
#       <td>Literature</td>
#       <td><a href='http://www.wikidata.org/entity/Q2344210'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>972</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=994'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/994'>html</a></td>
#       <td>2020</td>
#       <td>NaN</td>
#       <td>Peace</td>
#       <td><a href='http://www.wikidata.org/entity/Q204344'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>973</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=995'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/995'>html</a></td>
#       <td>2020</td>
#       <td>Paul R. Milgrom</td>
#       <td>Economic Sciences</td>
#       <td><a href='http://www.wikidata.org/entity/Q1359990'>Wikidata</a></td>
#     </tr>
#     <tr>
#       <th>974</th>
#       <td><a href='https://api.nobelprize.org/v1/laureate.json?id=996'>json</a></td>
#       <td><a href='https://www.nobelprize.org/laureate/996'>html</a></td>
#       <td>2020</td>
#       <td>Robert B. Wilson</td>
#       <td>Economic Sciences</td>
#       <td><a href='http://www.wikidata.org/entity/Q377265'>Wikidata</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Status 20201009 :
# * Ok all has html pages
#
# Templates supporting Wikidata Property 8024 = Wikidata [Q91652187](https://www.wikidata.org/wiki/Q91652187)
# * ar:Wikipedia [قالب:جائزة_نوبل](https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D9%84%D8%A8:%D8%AC%D8%A7%D8%A6%D8%B2%D8%A9_%D9%86%D9%88%D8%A8%D9%84)
# * ca:wikipedia [Plantilla:Nobelprize](https://ca.wikipedia.org/wiki/Plantilla:Nobelprize)
# * en:Wikipedia [Template:Nobelprize](https://en.wikipedia.org/wiki/Template:Nobelprize)
# * ka:Wikipedia [თარგი:Nobelprize](https://ka.wikipedia.org/wiki/%E1%83%97%E1%83%90%E1%83%A0%E1%83%92%E1%83%98:Nobelprize)
# * nn:Wikipedia [Mal:Nobelprize](https://nn.wikipedia.org/wiki/Mal:Nobelprize)
# * pt:Wikipedia [Predefinição:Prémio Nobel](https://pt.wikipedia.org/wiki/Predefini%C3%A7%C3%A3o:Pr%C3%A9mio_Nobel)
# * sv:Wikipedia [Mall:Nobelprize](https://sv.wikipedia.org/wiki/Mall:Nobelprize)
# * sr:WIkipedia [Шаблон:Nobelprize](https://sr.wikipedia.org/wiki/%D0%A8%D0%B0%D0%B1%D0%BB%D0%BE%D0%BD:Nobelprize)

# %% [markdown]
# * Articles using [template](https://www.wikidata.org/wiki/Q91652187) and view statistics this year and during the [Nobel week](https://www.nobelprize.org/press/#/publication/5f1719e411aab40004a17f36/552bd85dccc8e20c00e7f979?&sh=false)  5-12 October 2020 on those articles see also [video](https://youtu.be/Iu1JtefueM8)
#   * ar:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573153) / not using
#     * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://ar.wikipedia.org/wiki/%25D8%25AA%25D8%25B5%25D9%2586%25D9%258A%25D9%2581:%25D9%2582%25D8%25A7%25D9%2584%25D8%25A8_%25D8%25AC%25D8%25A7%25D8%25A6%25D8%25B2%25D8%25A9_%25D9%2586%25D9%2588%25D8%25A8%25D9%2584_%25D9%258A%25D8%25B3%25D8%25AA%25D8%25B9%25D9%2585%25D9%2584_%25D8%25AE%25D8%25A7%25D8%25B5%25D8%25A9_%25D9%2588%25D9%258A%25D9%2583%25D9%258A_%25D8%25A8%25D9%258A%25D8%25A7%25D9%2586%25D8%25A7%25D8%25AA_P8024) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://ar.wikipedia.org/wiki/%25D8%25AA%25D8%25B5%25D9%2586%25D9%258A%25D9%2581:%25D9%2582%25D8%25A7%25D9%2584%25D8%25A8_%25D8%25AC%25D8%25A7%25D8%25A6%25D8%25B2%25D8%25A9_%25D9%2586%25D9%2588%25D8%25A8%25D9%2584_%25D9%258A%25D8%25B3%25D8%25AA%25D8%25B9%25D9%2585%25D9%2584_%25D8%25AE%25D8%25A7%25D8%25B5%25D8%25A9_%25D9%2588%25D9%258A%25D9%2583%25D9%258A_%25D8%25A8%25D9%258A%25D8%25A7%25D9%2586%25D8%25A7%25D8%25AA_P8024)
#   * ca:Wikipedia miss track category [Q91672712](https://www.wikidata.org/wiki/Q91672712#sitelinks-wikipedia)
#   * en:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573140) / [not using](https://petscan.wmflabs.org/?psid=17579263)
#     * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://en.wikipedia.org/wiki/Category:Nobelprize_template_using_Wikidata_property_P8024) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://en.wikipedia.org/wiki/Category:Nobelprize_template_using_Wikidata_property_P8024) as a [chart](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-10&subjectpage=0&subcategories=0&sort=views&direction=1&view=chart&target=https://en.wikipedia.org/wiki/Category:Nobelprize%20template%20using%20Wikidata%20property%20P8024)
#   * ka:Wikipedia miss track category [Q91672712](https://www.wikidata.org/wiki/Q91672712#sitelinks-wikipedia)
#   * nn:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573155) / not using
#      * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://nn.wikipedia.org/wiki/Kategori:Sider_som_nyttar_Mal:Nobelprize) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://nn.wikipedia.org/wiki/Kategori:Sider_som_nyttar_Mal:Nobelprize)
#   * pt:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573158) / [not using](https://petscan.wmflabs.org/?psid=17579612)
#      * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://pt.wikipedia.org/wiki/Categoria:Predefini%25C3%25A7%25C3%25A3o_sobre_pr%25C3%25A9mios_Nobel_que_usam_a_propriedade_do_Wikidata_P8024) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://pt.wikipedia.org/wiki/Categoria:Predefini%25C3%25A7%25C3%25A3o_sobre_pr%25C3%25A9mios_Nobel_que_usam_a_propriedade_do_Wikidata_P8024)
#   * sv:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573129) / not using
#     * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://sv.wikipedia.org/wiki/Kategori:Sidor_som_anv%25C3%25A4nder_Mall:Nobelprize) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://sv.wikipedia.org/wiki/Kategori:Sidor_som_anv%25C3%25A4nder_Mall:Nobelprize)
#   * sr:Wikipedia miss track category [Q91672712](https://www.wikidata.org/wiki/Q91672712#sitelinks-wikipedia)
#
# Task [T251055](https://phabricator.wikimedia.org/T251055)

# %% [markdown]
# # Next Nobelprize announcement
# see https://www.nobelprize.org/
