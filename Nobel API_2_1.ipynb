# %% [markdown]
# **Work in progress**
#
#
# # Nobel API 2.1 - check Wikidata and Nobel API
#
# The purpose of this Notebook is to have Nobelprize winners in Wikidata in synch with the prizewinners at Nobelprize... lesson learned is that we also find vandalization in Wikidata....
#
#
# * This [Jupyter Notebook](https://github.com/salgo60/open-data-examples/blob/master/Nobel%20API_2_1.ipynb)  using API 2.1 [api.nobelprize.org/2.1/laureates](https://api.nobelprize.org/2.1/laureates)
#   * old [Notebook](https://github.com/salgo60/open-data-examples/blob/master/Nobel%20API.ipynb)
#   * [notebook for Nobelprize motivation](https://github.com/salgo60/open-data-examples/blob/master/Nobel%20API_2_1-motivation.ipynb)
#
#
#   * Wikidata property [Property:P8024](https://www.wikidata.org/wiki/Property:P8024)
#   * [Developer zone nobelprize.org](https://www.nobelprize.org/about/developer-zone-2/)
#       * API 2.1 [api.nobelprize.org/2.1/laureates](https://api.nobelprize.org/2.1/laureates)
#   * [video](https://youtu.be/Iu1JtefueM8) explaining what we do
#
# #### Misc
# Version history
# * 0.1 use API 2.1 --> Nobel API also includes Wikidata Q numbers
# ##### See also
# * Kaggle [nobelfoundation/nobel-laureates](https://www.kaggle.com/nobelfoundation/nobel-laureates) and my [Kaggle Notebook](https://www.kaggle.com/magnusslg/wikidata-nobelprize-synch)
#
# #### Other sources we sync
# * Famous people on Uppsala old cemetery [Kulturpersoner Uppsalakyrkogård](https://github.com/salgo60/open-data-examples/blob/master/Check%20WD%20kulturpersoner%20uppsalakyrkogardar.ipynb)
# * Swedish Literature Bank - [Litteraturbanken](https://github.com/salgo60/open-data-examples/blob/master/Litteraturbanken%20Author.ipynb)
#   * WD property [P5101](https://www.wikidata.org/wiki/Property_talk:P5101) [P5123](https://www.wikidata.org/wiki/Property_talk:P5123)
# * [Nobelprize.org](https://github.com/salgo60/open-data-examples/blob/master/Nobel%20API.ipynb)
#   * WD [property 8024](https://www.wikidata.org/wiki/Property:P8024)
# * The Swedish National Archive [SBL](https://github.com/salgo60/open-data-examples/blob/master/SBL.ipynb)
#   * WD [property 3217](https://www.wikidata.org/wiki/Property:P3217)
# * The Biographical Dictionary of Swedish Women [SKBL](https://github.com/salgo60/open-data-examples/blob/master/Svenskt%20Kvinnobiografiskt%20lexikon%20part%203.ipynb)
#   * WD [property 4963](https://www.wikidata.org/wiki/Property:P4963)
# * Swedish Academy - [Svenska Akademien](https://github.com/salgo60/open-data-examples/blob/master/Svenska%20Akademien.ipynb)
#   * WD [property 5325](https://www.wikidata.org/wiki/Property:P5325)

# %%
from datetime import datetime
start_time = datetime.now()
print("Last run: ", datetime.now())
# Out:
# Last run:  2021-10-10 04:43:05.117965

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 
from flatten_json import flatten 
url ="https://api.nobelprize.org/2.1/laureates?offset=0&limit=1500"
dftot = pd.DataFrame()
r = http.request('GET', url)
data = json.loads(r.data)
#dftot = dftot.append(pd.DataFrame(data["laureates"]),sort=False)
from flatten_json import flatten
dftot = pd.json_normalize(data["laureates"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-922554e9d25a> in <module>
#       2 import pandas as pd
#       3 http = urllib3.PoolManager()
# ----> 4 from flatten_json import flatten
#       5 url ="https://api.nobelprize.org/2.1/laureates?offset=0&limit=1500"
#       6 dftot = pd.DataFrame()
#
# ModuleNotFoundError: No module named 'flatten_json'

# %%
#dfnorm.info()

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957 entries, 0 to 956
# Data columns (total 107 columns):
#  #    Column                           Non-Null Count  Dtype
# ---   ------                           --------------  -----
#  0    id                               957 non-null    object
#  1    fileName                         957 non-null    object
#  2    gender                           932 non-null    object
#  3    sameAs                           957 non-null    object
#  4    links                            957 non-null    object
#  5    nobelPrizes                      957 non-null    object
#  6    knownName.en                     932 non-null    object
#  7    knownName.se                     932 non-null    object
#  8    givenName.en                     932 non-null    object
#  9    givenName.se                     932 non-null    object
#  10   familyName.en                    930 non-null    object
#  11   familyName.se                    930 non-null    object
#  12   fullName.en                      932 non-null    object
#  13   fullName.se                      932 non-null    object
#  14   birth.date                       931 non-null    object
#  15   birth.place.city.en              930 non-null    object
#  16   birth.place.city.no              930 non-null    object
#  17   birth.place.city.se              930 non-null    object
#  18   birth.place.country.en           931 non-null    object
#  19   birth.place.country.no           931 non-null    object
#  20   birth.place.country.se           931 non-null    object
#  21   birth.place.cityNow.en           930 non-null    object
#  22   birth.place.cityNow.no           930 non-null    object
#  23   birth.place.cityNow.se           930 non-null    object
#  24   birth.place.cityNow.sameAs       913 non-null    object
#  25   birth.place.countryNow.en        931 non-null    object
#  26   birth.place.countryNow.no        931 non-null    object
#  27   birth.place.countryNow.se        931 non-null    object
#  28   birth.place.countryNow.sameAs    926 non-null    object
#  29   birth.place.continent.en         931 non-null    object
#  30   birth.place.continent.no         931 non-null    object
#  31   birth.place.continent.se         931 non-null    object
#  32   birth.place.locationString.en    931 non-null    object
#  33   birth.place.locationString.no    931 non-null    object
#  34   birth.place.locationString.se    931 non-null    object
#  35   wikipedia.slug                   957 non-null    object
#  36   wikipedia.english                957 non-null    object
#  37   wikidata.id                      957 non-null    object
#  38   wikidata.url                     957 non-null    object
#  39   death.date                       641 non-null    object
#  40   death.place.city.en              622 non-null    object
#  41   death.place.city.no              622 non-null    object
#  42   death.place.city.se              622 non-null    object
#  43   death.place.country.en           628 non-null    object
#  44   death.place.country.no           628 non-null    object
#  45   death.place.country.se           628 non-null    object
#  46   death.place.country.sameAs       588 non-null    object
#  47   death.place.cityNow.en           622 non-null    object
#  48   death.place.cityNow.no           622 non-null    object
#  49   death.place.cityNow.se           622 non-null    object
#  50   death.place.cityNow.sameAs       611 non-null    object
#  51   death.place.countryNow.en        628 non-null    object
#  52   death.place.countryNow.no        628 non-null    object
#  53   death.place.countryNow.se        628 non-null    object
#  54   death.place.countryNow.sameAs    625 non-null    object
#  55   death.place.continent.en         628 non-null    object
#  56   death.place.continent.no         628 non-null    object
#  57   death.place.continent.se         628 non-null    object
#  58   death.place.locationString.en    641 non-null    object
#  59   death.place.locationString.no    641 non-null    object
#  60   death.place.locationString.se    641 non-null    object
#  61   nativeName                       24 non-null     object
#  62   acronym                          11 non-null     object
#  63   orgName.en                       25 non-null     object
#  64   orgName.no                       21 non-null     object
#  65   orgName.se                       25 non-null     object
#  66   founded.date                     24 non-null     object
#  67   founded.place.city.en            19 non-null     object
#  68   founded.place.city.no            19 non-null     object
#  69   founded.place.city.se            19 non-null     object
#  70   founded.place.country.en         21 non-null     object
#  71   founded.place.country.no         21 non-null     object
#  72   founded.place.country.se         21 non-null     object
#  73   founded.place.country.sameAs     21 non-null     object
#  74   founded.place.cityNow.en         19 non-null     object
#  75   founded.place.cityNow.no         19 non-null     object
#  76   founded.place.cityNow.se         19 non-null     object
#  77   founded.place.cityNow.sameAs     19 non-null     object
#  78   founded.place.countryNow.en      21 non-null     object
#  79   founded.place.countryNow.no      21 non-null     object
#  80   founded.place.countryNow.se      21 non-null     object
#  81   founded.place.countryNow.sameAs  21 non-null     object
#  82   founded.place.continent.en       21 non-null     object
#  83   founded.place.continent.no       21 non-null     object
#  84   founded.place.continent.se       21 non-null     object
#  85   founded.place.locationString.en  24 non-null     object
#  86   founded.place.locationString.no  24 non-null     object
#  87   founded.place.locationString.se  24 non-null     object
#  88   penName                          11 non-null     object
#  89   birthCountry.en                  1 non-null      object
#  90   birthCountry.no                  1 non-null      object
#  91   birthCountry.se                  1 non-null      object
#  92   birthCountryNow.en               1 non-null      object
#  93   birthCountryNow.no               1 non-null      object
#  94   birthCountryNow.se               1 non-null      object
#  95   birthContinent.en                1 non-null      object
#  96   knownName.no                     4 non-null      object
#  97   givenName.no                     3 non-null      object
#  98   familyName.no                    3 non-null      object
#  99   fullName.no                      3 non-null      object
#  100  foundedCountry.en                1 non-null      object
#  101  foundedCountry.no                1 non-null      object
#  102  foundedCountry.se                1 non-null      object
#  103  foundedCountryNow.en             1 non-null      object
#  104  foundedCountryNow.no             1 non-null      object
#  105  foundedCountryNow.se             1 non-null      object
#  106  foundedContinent.en              1 non-null      object
# dtypes: object(107)
# memory usage: 800.1+ KB

# %%
dftot["id"] = dftot["id"].astype("int") 
dftot["id"] = dftot["id"].astype("int") 


dftot.sort_values(by=['id'], ascending=[True], inplace=True)
dftot.tail(4)
# Out:
#       id     fileName gender                                             sameAs                                              links                                        nobelPrizes       knownName.en       knownName.se givenName.en givenName.se familyName.en familyName.se        fullName.en        fullName.se  birth.date birth.place.city.en birth.place.city.no birth.place.city.se birth.place.country.en birth.place.country.no birth.place.country.se birth.place.cityNow.en birth.place.cityNow.no birth.place.cityNow.se                         birth.place.cityNow.sameAs birth.place.countryNow.en birth.place.countryNow.no birth.place.countryNow.se         birth.place.countryNow.sameAs birth.place.continent.en birth.place.continent.no birth.place.continent.se birth.place.locationString.en birth.place.locationString.no birth.place.locationString.se     wikipedia.slug                                wikipedia.english wikidata.id                             wikidata.url death.date death.place.city.en death.place.city.no death.place.city.se death.place.country.en death.place.country.no death.place.country.se death.place.country.sameAs death.place.cityNow.en death.place.cityNow.no death.place.cityNow.se death.place.cityNow.sameAs death.place.countryNow.en death.place.countryNow.no death.place.countryNow.se death.place.countryNow.sameAs death.place.continent.en death.place.continent.no death.place.continent.se death.place.locationString.en death.place.locationString.no death.place.locationString.se nativeName acronym orgName.en orgName.no orgName.se founded.date founded.place.city.en founded.place.city.no founded.place.city.se founded.place.country.en founded.place.country.no founded.place.country.se founded.place.country.sameAs founded.place.cityNow.en founded.place.cityNow.no founded.place.cityNow.se founded.place.cityNow.sameAs founded.place.countryNow.en founded.place.countryNow.no founded.place.countryNow.se founded.place.countryNow.sameAs founded.place.continent.en founded.place.continent.no founded.place.continent.se founded.place.locationString.en founded.place.locationString.no founded.place.locationString.se penName birthCountry.en birthCountry.no birthCountry.se birthCountryNow.en birthCountryNow.no birthCountryNow.se birthContinent.en knownName.no givenName.no familyName.no fullName.no foundedCountry.en foundedCountry.no foundedCountry.se foundedCountryNow.en foundedCountryNow.no foundedCountryNow.se foundedContinent.en
# 682  995      milgrom   male  [https://www.wikidata.org/wiki/Q1359990, https...  [{'rel': 'laureate', 'href': 'https://api.nobe...  [{'awardYear': '2020', 'category': {'en': 'Eco...    Paul R. Milgrom    Paul R. Milgrom         Paul         Paul       Milgrom       Milgrom    Paul R. Milgrom    Paul R. Milgrom  1948-04-20         Detroit, MI         Detroit, MI         Detroit, MI                    USA                    USA                    USA            Detroit, MI            Detroit, MI            Detroit, MI  [https://www.wikidata.org/wiki/Q12439, https:/...                       USA                       USA                       USA   [https://www.wikidata.org/wiki/Q30]            North America             Nord-Amerika              Nordamerika              Detroit, MI, USA              Detroit, MI, USA              Detroit, MI, USA       Paul_Milgrom       https://en.wikipedia.org/wiki/Paul_Milgrom    Q1359990   https://www.wikidata.org/wiki/Q1359990        NaN                 NaN                 NaN                 NaN                    NaN                    NaN                    NaN                        NaN                    NaN                    NaN                    NaN                        NaN                       NaN                       NaN                       NaN                           NaN                      NaN                      NaN                      NaN                           NaN                           NaN                           NaN        NaN     NaN        NaN        NaN        NaN          NaN                   NaN                   NaN                   NaN                      NaN                      NaN                      NaN                          NaN                      NaN                      NaN                      NaN                          NaN                         NaN                         NaN                         NaN                             NaN                        NaN                        NaN                        NaN                             NaN                             NaN                             NaN     NaN             NaN             NaN             NaN                NaN                NaN                NaN               NaN          NaN          NaN           NaN         NaN               NaN               NaN               NaN                  NaN                  NaN                  NaN                 NaN
# 743  996       wilson   male  [https://www.wikidata.org/wiki/Q377265, https:...  [{'rel': 'laureate', 'href': 'https://api.nobe...  [{'awardYear': '2020', 'category': {'en': 'Eco...   Robert B. Wilson   Robert B. Wilson       Robert       Robert        Wilson        Wilson   Robert B. Wilson   Robert B. Wilson  1937-05-16          Geneva, NE          Geneva, NE          Geneva, NE                    USA                    USA                    USA             Geneva, NE             Geneva, NE             Geneva, NE  [https://www.wikidata.org/wiki/Q967228, https:...                       USA                       USA                       USA   [https://www.wikidata.org/wiki/Q30]            North America             Nord-Amerika              Nordamerika               Geneva, NE, USA               Geneva, NE, USA               Geneva, NE, USA   Robert_B._Wilson   https://en.wikipedia.org/wiki/Robert_B._Wilson     Q377265    https://www.wikidata.org/wiki/Q377265        NaN                 NaN                 NaN                 NaN                    NaN                    NaN                    NaN                        NaN                    NaN                    NaN                    NaN                        NaN                       NaN                       NaN                       NaN                           NaN                      NaN                      NaN                      NaN                           NaN                           NaN                           NaN        NaN     NaN        NaN        NaN        NaN          NaN                   NaN                   NaN                   NaN                      NaN                      NaN                      NaN                          NaN                      NaN                      NaN                      NaN                          NaN                         NaN                         NaN                         NaN                             NaN                        NaN                        NaN                        NaN                             NaN                             NaN                             NaN     NaN             NaN             NaN             NaN                NaN                NaN                NaN               NaN          NaN          NaN           NaN         NaN               NaN               NaN               NaN                  NaN                  NaN                  NaN                 NaN
# 168  997       julius   male  [https://www.wikidata.org/wiki/Q1174906, https...  [{'rel': 'laureate', 'href': 'https://api.nobe...  [{'awardYear': '2021', 'category': {'en': 'Phy...       David Julius       David Julius        David        David        Julius        Julius       David Julius       David Julius  1955-11-04        New York, NY        New York, NY        New York, NY                    USA                    USA                    USA           New York, NY           New York, NY           New York, NY  [https://www.wikidata.org/wiki/Q60, https://ww...                       USA                       USA                       USA   [https://www.wikidata.org/wiki/Q30]            North America             Nord-Amerika              Nordamerika             New York, NY, USA             New York, NY, USA             New York, NY, USA       David_Julius       https://en.wikipedia.org/wiki/David_Julius    Q1174906   https://www.wikidata.org/wiki/Q1174906        NaN                 NaN                 NaN                 NaN                    NaN                    NaN                    NaN                        NaN                    NaN                    NaN                    NaN                        NaN                       NaN                       NaN                       NaN                           NaN                      NaN                      NaN                      NaN                           NaN                           NaN                           NaN        NaN     NaN        NaN        NaN        NaN          NaN                   NaN                   NaN                   NaN                      NaN                      NaN                      NaN                          NaN                      NaN                      NaN                      NaN                          NaN                         NaN                         NaN                         NaN                             NaN                        NaN                        NaN                        NaN                             NaN                             NaN                             NaN     NaN             NaN             NaN             NaN                NaN                NaN                NaN               NaN          NaN          NaN           NaN         NaN               NaN               NaN               NaN                  NaN                  NaN                  NaN                 NaN
# 65   998  patapoutian   male  [https://www.wikidata.org/wiki/Q60322501, http...  [{'rel': 'laureate', 'href': 'https://api.nobe...  [{'awardYear': '2021', 'category': {'en': 'Phy...  Ardem Patapoutian  Ardem Patapoutian        Ardem        Ardem   Patapoutian   Patapoutian  Ardem Patapoutian  Ardem Patapoutian  1967-00-00              Beirut              Beirut              Beirut                Lebanon                Libanon                Libanon                 Beirut                 Beirut                 Beirut  [https://www.wikidata.org/wiki/Q3820, https://...                   Lebanon                   Libanon                   Libanon  [https://www.wikidata.org/wiki/Q822]                     Asia                     Asia                    Asien               Beirut, Lebanon               Beirut, Libanon               Beirut, Libanon  Ardem_Patapoutian  https://en.wikipedia.org/wiki/Ardem_Patapoutian   Q60322501  https://www.wikidata.org/wiki/Q60322501        NaN                 NaN                 NaN                 NaN                    NaN                    NaN                    NaN                        NaN                    NaN                    NaN                    NaN                        NaN                       NaN                       NaN                       NaN                           NaN                      NaN                      NaN                      NaN                           NaN                           NaN                           NaN        NaN     NaN        NaN        NaN        NaN          NaN                   NaN                   NaN                   NaN                      NaN                      NaN                      NaN                          NaN                      NaN                      NaN                      NaN                          NaN                         NaN                         NaN                         NaN                             NaN                        NaN                        NaN                        NaN                             NaN                             NaN                             NaN     NaN             NaN             NaN             NaN                NaN                NaN                NaN               NaN          NaN          NaN           NaN         NaN               NaN               NaN               NaN                  NaN                  NaN                  NaN                 NaN

# %%
#Test flatten 
#from pandas.json_normalize import json_normalize
#from pandas.io.json.normalize import nested_to_record
from pandas import json_normalize
#dftotPrize = json_normalize(data=data['laureates'], record_path='nobelPrizes', 
#                            meta=['id', 'filename','gender', 'wikidata'],errors='ignore') 
dftotPrize = json_normalize(data=data["laureates"])
dftotPrize.shape
# Out:
# (957, 107)

# %%
dftotPrize.sample(5)
# Out:
#       id    fileName gender  \
# 334  491  stresemann   male
# 936  328      murphy   male
# 595  352     theiler   male
# 84   845       obama   male
# 605  890      levitt   male
#
#                                                 sameAs  \
# 334  [https://www.wikidata.org/wiki/Q103955, https:...
# 936  [https://www.wikidata.org/wiki/Q80323, https:/...
# 595  [https://www.wikidata.org/wiki/Q46928, https:/...
# 84   [https://www.wikidata.org/wiki/Q76, https://en...
# 605  [https://www.wikidata.org/wiki/Q6832227, https...
#
#                                                  links  \
# 334  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 936  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 595  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 84   [{'rel': 'laureate', 'href': 'https://api.nobe...
# 605  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                            nobelPrizes       knownName.en  \
# 334  [{'awardYear': '1926', 'category': {'en': 'Pea...  Gustav Stresemann
# 936  [{'awardYear': '1934', 'category': {'en': 'Phy...  William P. Murphy
# 595  [{'awardYear': '1951', 'category': {'en': 'Phy...        Max Theiler
# 84   [{'awardYear': '2009', 'category': {'en': 'Pea...    Barack H. Obama
# 605  [{'awardYear': '2013', 'category': {'en': 'Che...     Michael Levitt
#
#           knownName.se givenName.en givenName.se  ... givenName.no  \
# 334  Gustav Stresemann       Gustav       Gustav  ...          NaN
# 936  William P. Murphy   William P.   William P.  ...          NaN
# 595        Max Theiler          Max          Max  ...          NaN
# 84     Barack H. Obama       Barack       Barack  ...          NaN
# 605     Michael Levitt      Michael      Michael  ...          NaN
#
#     familyName.no fullName.no foundedCountry.en foundedCountry.no  \
# 334           NaN         NaN               NaN               NaN
# 936           NaN         NaN               NaN               NaN
# 595           NaN         NaN               NaN               NaN
# 84            NaN         NaN               NaN               NaN
# 605           NaN         NaN               NaN               NaN
#
#     foundedCountry.se foundedCountryNow.en foundedCountryNow.no  \
# 334               NaN                  NaN                  NaN
# 936               NaN                  NaN                  NaN
# 595               NaN                  NaN                  NaN
# 84                NaN                  NaN                  NaN
# 605               NaN                  NaN                  NaN
#
#     foundedCountryNow.se foundedContinent.en
# 334                  NaN                 NaN
# 936                  NaN                 NaN
# 595                  NaN                 NaN
# 84                   NaN                 NaN
# 605                  NaN                 NaN
#
# [5 rows x 107 columns]

# %%
dftotPrize["penName"].value_counts()
# Out:
# (pen-name of Grazia Madesani, née Deledda)      1
# (pen-name of Alexis Léger)                      1
# (pen-name of Lucila Godoy y Alcayaga)           1
# (pen-name of Rejment)                           1
# (pen-name of Odysseus Alepoudhelis)             1
# (pen-name of René François Armand Prudhomme)    1
# (pen-name of Neftalí Ricardo Reyes Basoalto)    1
# (pen-name of Pearl Walsh, née Sydenstricker)    1
# (pen-name of Guan Moye)                         1
# (pen-name of Giorgos Seferiadis)                1
# (pen-name of Jacques Anatole Thibault)          1
# Name: penName, dtype: int64

# %%
dftotPrize["birth.place.countryNow.en"].value_counts()
# Out:
# USA               280
# United Kingdom     87
# Germany            82
# France             57
# Sweden             29
#                  ...
# Cyprus              1
# Bangladesh          1
# Nigeria             1
# Peru                1
# Zimbabwe            1
# Name: birth.place.countryNow.en, Length: 83, dtype: int64

# %%
dftotPrize.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957 entries, 0 to 956
# Columns: 107 entries, id to foundedContinent.en
# dtypes: object(107)
# memory usage: 800.1+ KB

# %%
#dftotPrize["death.place.country.sameAs"].value_counts()

# %%
dftotPrize.sample(4)
# Out:
#       id   fileName  gender  \
# 516  121     wilson    male
# 104  629  pasternak    male
# 649  808      pamuk    male
# 318  438      elion  female
#
#                                                 sameAs  \
# 516  [https://www.wikidata.org/wiki/Q193503, https:...
# 104  [https://www.wikidata.org/wiki/Q41223, https:/...
# 649  [https://www.wikidata.org/wiki/Q241248, https:...
# 318  [https://www.wikidata.org/wiki/Q35703, https:/...
#
#                                                  links  \
# 516  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 104  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 649  [{'rel': 'laureate', 'href': 'https://api.nobe...
# 318  [{'rel': 'laureate', 'href': 'https://api.nobe...
#
#                                            nobelPrizes       knownName.en  \
# 516  [{'awardYear': '1982', 'category': {'en': 'Phy...  Kenneth G. Wilson
# 104  [{'awardYear': '1958', 'category': {'en': 'Lit...    Boris Pasternak
# 649  [{'awardYear': '2006', 'category': {'en': 'Lit...        Orhan Pamuk
# 318  [{'awardYear': '1988', 'category': {'en': 'Phy...  Gertrude B. Elion
#
#           knownName.se givenName.en givenName.se  ... givenName.no  \
# 516  Kenneth G. Wilson   Kenneth G.   Kenneth G.  ...          NaN
# 104    Boris Pasternak        Boris        Boris  ...          NaN
# 649        Orhan Pamuk        Orhan        Orhan  ...          NaN
# 318  Gertrude B. Elion  Gertrude B.  Gertrude B.  ...          NaN
#
#     familyName.no fullName.no foundedCountry.en foundedCountry.no  \
# 516           NaN         NaN               NaN               NaN
# 104           NaN         NaN               NaN               NaN
# 649           NaN         NaN               NaN               NaN
# 318           NaN         NaN               NaN               NaN
#
#     foundedCountry.se foundedCountryNow.en foundedCountryNow.no  \
# 516               NaN                  NaN                  NaN
# 104               NaN                  NaN                  NaN
# 649               NaN                  NaN                  NaN
# 318               NaN                  NaN                  NaN
#
#     foundedCountryNow.se foundedContinent.en
# 516                  NaN                 NaN
# 104                  NaN                 NaN
# 649                  NaN                 NaN
# 318                  NaN                 NaN
#
# [4 rows x 107 columns]

# %% [markdown]
# ## Check Wikidata matches

# %%
# pip install sparqlwrapper
# https://rdflib.github.io/sparqlwrapper/

import sys
from SPARQLWrapper import SPARQLWrapper, JSON

endpoint_url = "https://query.wikidata.org/sparql"

query = """SELECT ?WDitem ?WDitemLabel ?WDNobelAPI ?WDdeath WHERE {
  # ?WDitem wdt:P8024 ?WDNobelAPI.
  OPTIONAL {?WDitem wdt:P570 ?WDdeath}
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
} order by xsd:integer(?WDNobelAPI)"""


def get_sparql_dataframe(endpoint_url, query):
    """
    Helper function to convert SPARQL results into a Pandas data frame.
    """
    user_agent = "salgo60/%s.%s" % (sys.version_info[0], sys.version_info[1])
 
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    result = sparql.query()

    processed_results = json.load(result.response)
    cols = processed_results['head']['vars']
    out = []
    for row in processed_results['results']['bindings']:
        item = []
        for c in cols:
            item.append(row.get(c, {}).get('value'))
        out.append(item)

    return pd.DataFrame(out, columns=cols)

WDNobel = get_sparql_dataframe(endpoint_url, query)

# %%
WDNobel["WDNobelAPI"] = WDNobel["WDNobelAPI"].astype("int")
WDNobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978 entries, 0 to 977
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WDitem       978 non-null    object
#  1   WDitemLabel  978 non-null    object
#  2   WDNobelAPI   978 non-null    int64
#  3   WDdeath      655 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 30.7+ KB

# %% [markdown]
# ### Compare WD <-> Nobel

# %%
WDNobel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978 entries, 0 to 977
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WDitem       978 non-null    object
#  1   WDitemLabel  978 non-null    object
#  2   WDNobelAPI   978 non-null    int64
#  3   WDdeath      655 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 30.7+ KB

# %%
dftotPrize["id"] = dftotPrize["id"].astype("int")

#dftotPrize.info()

# %%
dfmerge = pd.merge(WDNobel, dftotPrize,how='outer', left_on="WDNobelAPI",right_on="id",indicator=True)
dfmerge['_merge'] = dfmerge['_merge'].str.replace('left_only','WD_only').str.replace('right_only','Nobel_only')
dfmerge.rename(columns={"_merge": "WD_Nobel"},inplace = True)    
#dfmerge[-10:]

# %%
dfmerge[dfmerge["WD_Nobel"]!="both"]
# Out:
#                                       WDitem        WDitemLabel  WDNobelAPI  \
# 970  http://www.wikidata.org/entity/Q3675789     Syukuro Manabe         999
# 971   http://www.wikidata.org/entity/Q109370   Klaus Hasselmann        1000
# 972  http://www.wikidata.org/entity/Q1235614     Giorgio Parisi        1001
# 973   http://www.wikidata.org/entity/Q105572      Benjamin List        1002
# 974  http://www.wikidata.org/entity/Q5237001    David MacMillan        1003
# 975   http://www.wikidata.org/entity/Q317877  Abdulrazak Gurnah        1004
# 976  http://www.wikidata.org/entity/Q6761526        Maria Ressa        1005
# 977  http://www.wikidata.org/entity/Q1823418     Dmitry Muratov        1006
#
#     WDdeath  id fileName gender sameAs links nobelPrizes  ... familyName.no  \
# 970    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 971    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 972    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 973    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 974    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 975    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 976    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 977    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
#
#     fullName.no foundedCountry.en foundedCountry.no foundedCountry.se  \
# 970         NaN               NaN               NaN               NaN
# 971         NaN               NaN               NaN               NaN
# 972         NaN               NaN               NaN               NaN
# 973         NaN               NaN               NaN               NaN
# 974         NaN               NaN               NaN               NaN
# 975         NaN               NaN               NaN               NaN
# 976         NaN               NaN               NaN               NaN
# 977         NaN               NaN               NaN               NaN
#
#     foundedCountryNow.en foundedCountryNow.no foundedCountryNow.se  \
# 970                  NaN                  NaN                  NaN
# 971                  NaN                  NaN                  NaN
# 972                  NaN                  NaN                  NaN
# 973                  NaN                  NaN                  NaN
# 974                  NaN                  NaN                  NaN
# 975                  NaN                  NaN                  NaN
# 976                  NaN                  NaN                  NaN
# 977                  NaN                  NaN                  NaN
#
#     foundedContinent.en WD_Nobel
# 970                 NaN  WD_only
# 971                 NaN  WD_only
# 972                 NaN  WD_only
# 973                 NaN  WD_only
# 974                 NaN  WD_only
# 975                 NaN  WD_only
# 976                 NaN  WD_only
# 977                 NaN  WD_only
#
# [8 rows x 112 columns]

# %%
WDNobel['wikidata'] = WDNobel['WDitem'].str.replace('http://www.wikidata.org/entity/','')
# Out:
# <ipython-input-18-148fcb106129>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   WDNobel['wikidata'] = WDNobel['WDitem'].str.replace('http://www.wikidata.org/entity/','')

# %%
WDNobel.head()
# Out:
#                                   WDitem      WDitemLabel  WDNobelAPI  \
# 0  http://www.wikidata.org/entity/Q35149  Wilhelm Röntgen           1
# 1  http://www.wikidata.org/entity/Q41688  Hendrik Lorentz           2
# 2  http://www.wikidata.org/entity/Q79000    Pieter Zeeman           3
# 3  http://www.wikidata.org/entity/Q41269  Henri Becquerel           4
# 4  http://www.wikidata.org/entity/Q37463     Pierre Curie           5
#
#                 WDdeath wikidata
# 0  1923-02-10T00:00:00Z   Q35149
# 1  1928-02-04T00:00:00Z   Q41688
# 2  1943-10-09T00:00:00Z   Q79000
# 3  1908-08-25T00:00:00Z   Q41269
# 4  1906-04-19T00:00:00Z   Q37463

# %%
WDNobel.tail()
# Out:
#                                       WDitem        WDitemLabel  WDNobelAPI  \
# 973   http://www.wikidata.org/entity/Q105572      Benjamin List        1002
# 974  http://www.wikidata.org/entity/Q5237001    David MacMillan        1003
# 975   http://www.wikidata.org/entity/Q317877  Abdulrazak Gurnah        1004
# 976  http://www.wikidata.org/entity/Q6761526        Maria Ressa        1005
# 977  http://www.wikidata.org/entity/Q1823418     Dmitry Muratov        1006
#
#     WDdeath  wikidata
# 973    None   Q105572
# 974    None  Q5237001
# 975    None   Q317877
# 976    None  Q6761526
# 977    None  Q1823418

# %%
#Merge on the Wikidata Qnumber at NobelTot  
dfmergeWD = pd.merge(WDNobel, dftotPrize,how='outer', left_on="wikidata",right_on="wikidata.id",indicator=True)
dfmergeWD['_merge'] = dfmergeWD['_merge'].str.replace('left_only','WD_only').str.replace('right_only','Nobel_only')
dfmergeWD.rename(columns={"_merge": "WD_Nobel"},inplace = True)    
dfmergeWD["WD_Nobel"].value_counts()
# Out:
# both          969
# WD_only         9
# Nobel_only      2
# Name: WD_Nobel, dtype: int64

# %%
dfmergeWD[dfmergeWD["WD_Nobel"]!="both"]
# Out:
#                                       WDitem                   WDitemLabel  \
# 819    http://www.wikidata.org/entity/Q42037  Jean-Marie Gustave Le Clézio
# 970  http://www.wikidata.org/entity/Q3675789                Syukuro Manabe
# 971   http://www.wikidata.org/entity/Q109370              Klaus Hasselmann
# 972  http://www.wikidata.org/entity/Q1235614                Giorgio Parisi
# 973   http://www.wikidata.org/entity/Q105572                 Benjamin List
# 974  http://www.wikidata.org/entity/Q5237001               David MacMillan
# 975   http://www.wikidata.org/entity/Q317877             Abdulrazak Gurnah
# 976  http://www.wikidata.org/entity/Q6761526                   Maria Ressa
# 977  http://www.wikidata.org/entity/Q1823418                Dmitry Muratov
# 978                                      NaN                           NaN
# 979                                      NaN                           NaN
#
#      WDNobelAPI WDdeath  wikidata     id          fileName gender  \
# 819       832.0    None    Q42037    NaN               NaN    NaN
# 970       999.0    None  Q3675789    NaN               NaN    NaN
# 971      1000.0    None   Q109370    NaN               NaN    NaN
# 972      1001.0    None  Q1235614    NaN               NaN    NaN
# 973      1002.0    None   Q105572    NaN               NaN    NaN
# 974      1003.0    None  Q5237001    NaN               NaN    NaN
# 975      1004.0    None   Q317877    NaN               NaN    NaN
# 976      1005.0    None  Q6761526    NaN               NaN    NaN
# 977      1006.0    None  Q1823418    NaN               NaN    NaN
# 978         NaN     NaN       NaN  832.0            clezio   male
# 979         NaN     NaN       NaN  523.0  red-cross-league    NaN
#
#                                                 sameAs  \
# 819                                                NaN
# 970                                                NaN
# 971                                                NaN
# 972                                                NaN
# 973                                                NaN
# 974                                                NaN
# 975                                                NaN
# 976                                                NaN
# 977                                                NaN
# 978  [https://www.wikidata.org/wiki/Q7884119, https...
# 979  [https://www.wikidata.org/wiki/Q1069175, https...
#
#                                                  links  ... familyName.no  \
# 819                                                NaN  ...           NaN
# 970                                                NaN  ...           NaN
# 971                                                NaN  ...           NaN
# 972                                                NaN  ...           NaN
# 973                                                NaN  ...           NaN
# 974                                                NaN  ...           NaN
# 975                                                NaN  ...           NaN
# 976                                                NaN  ...           NaN
# 977                                                NaN  ...           NaN
# 978  [{'rel': 'laureate', 'href': 'https://api.nobe...  ...           NaN
# 979  [{'rel': 'laureate', 'href': 'https://api.nobe...  ...           NaN
#
#     fullName.no foundedCountry.en foundedCountry.no foundedCountry.se  \
# 819         NaN               NaN               NaN               NaN
# 970         NaN               NaN               NaN               NaN
# 971         NaN               NaN               NaN               NaN
# 972         NaN               NaN               NaN               NaN
# 973         NaN               NaN               NaN               NaN
# 974         NaN               NaN               NaN               NaN
# 975         NaN               NaN               NaN               NaN
# 976         NaN               NaN               NaN               NaN
# 977         NaN               NaN               NaN               NaN
# 978         NaN               NaN               NaN               NaN
# 979         NaN               NaN               NaN               NaN
#
#     foundedCountryNow.en foundedCountryNow.no foundedCountryNow.se  \
# 819                  NaN                  NaN                  NaN
# 970                  NaN                  NaN                  NaN
# 971                  NaN                  NaN                  NaN
# 972                  NaN                  NaN                  NaN
# 973                  NaN                  NaN                  NaN
# 974                  NaN                  NaN                  NaN
# 975                  NaN                  NaN                  NaN
# 976                  NaN                  NaN                  NaN
# 977                  NaN                  NaN                  NaN
# 978                  NaN                  NaN                  NaN
# 979                  NaN                  NaN                  NaN
#
#     foundedContinent.en    WD_Nobel
# 819                 NaN     WD_only
# 970                 NaN     WD_only
# 971                 NaN     WD_only
# 972                 NaN     WD_only
# 973                 NaN     WD_only
# 974                 NaN     WD_only
# 975                 NaN     WD_only
# 976                 NaN     WD_only
# 977                 NaN     WD_only
# 978                 NaN  Nobel_only
# 979                 NaN  Nobel_only
#
# [11 rows x 113 columns]

# %% [markdown]
# #### Check that Wikidata and api.nobelprize.org is in synch

# %%
dfmerge["WD_Nobel"].value_counts()
# Out:
# both       970
# WD_only      8
# Name: WD_Nobel, dtype: int64

# %%
Nobelonly = dfmerge[dfmerge["WD_Nobel"]=="Nobel_only"].copy() 

from IPython.display import HTML
#Nobelonly["Nobel"] = "<a href='https://api.nobelprize.org/v1/laureate.json?id=" + Nobelonly["id"] + "'>link</a>"
#Nobelonly["Nobelhtml"] = "<a href='https://www.nobelprize.org/laureate/" + Nobelonly["id"] + "'>html</a>"
#pd.set_option("display.max.columns", None) 
#HTML(Nobelonly.to_html(escape=False))

# %%
dfmerge.to_csv("Nobel_dfmerge_2_1.csv")
Nobelonly.to_csv("Nobel_only.csv")

# %%
WDonly = dfmerge[dfmerge["WD_Nobel"]=="WD_only"].copy() 
WDonly
# Out:
#                                       WDitem        WDitemLabel  WDNobelAPI  \
# 970  http://www.wikidata.org/entity/Q3675789     Syukuro Manabe         999
# 971   http://www.wikidata.org/entity/Q109370   Klaus Hasselmann        1000
# 972  http://www.wikidata.org/entity/Q1235614     Giorgio Parisi        1001
# 973   http://www.wikidata.org/entity/Q105572      Benjamin List        1002
# 974  http://www.wikidata.org/entity/Q5237001    David MacMillan        1003
# 975   http://www.wikidata.org/entity/Q317877  Abdulrazak Gurnah        1004
# 976  http://www.wikidata.org/entity/Q6761526        Maria Ressa        1005
# 977  http://www.wikidata.org/entity/Q1823418     Dmitry Muratov        1006
#
#     WDdeath  id fileName gender sameAs links nobelPrizes  ... familyName.no  \
# 970    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 971    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 972    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 973    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 974    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 975    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 976    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
# 977    None NaN      NaN    NaN    NaN   NaN         NaN  ...           NaN
#
#     fullName.no foundedCountry.en foundedCountry.no foundedCountry.se  \
# 970         NaN               NaN               NaN               NaN
# 971         NaN               NaN               NaN               NaN
# 972         NaN               NaN               NaN               NaN
# 973         NaN               NaN               NaN               NaN
# 974         NaN               NaN               NaN               NaN
# 975         NaN               NaN               NaN               NaN
# 976         NaN               NaN               NaN               NaN
# 977         NaN               NaN               NaN               NaN
#
#     foundedCountryNow.en foundedCountryNow.no foundedCountryNow.se  \
# 970                  NaN                  NaN                  NaN
# 971                  NaN                  NaN                  NaN
# 972                  NaN                  NaN                  NaN
# 973                  NaN                  NaN                  NaN
# 974                  NaN                  NaN                  NaN
# 975                  NaN                  NaN                  NaN
# 976                  NaN                  NaN                  NaN
# 977                  NaN                  NaN                  NaN
#
#     foundedContinent.en WD_Nobel
# 970                 NaN  WD_only
# 971                 NaN  WD_only
# 972                 NaN  WD_only
# 973                 NaN  WD_only
# 974                 NaN  WD_only
# 975                 NaN  WD_only
# 976                 NaN  WD_only
# 977                 NaN  WD_only
#
# [8 rows x 112 columns]

# %%
print("End run: ", datetime.now())
# Out:
# End run:  2021-10-10 04:43:18.707199

# %%
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Time elapsed (hh:mm:ss.ms) 0:00:13.600146

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.expand_frame_repr', False)  
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
dfmerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 978 entries, 0 to 977
# Columns: 112 entries, WDitem to WD_Nobel
# dtypes: float64(1), int64(1), object(110)
# memory usage: 863.4+ KB

# %%
for l, r in dfmerge.iterrows():
    try:
#        print (l,r["nobelPrizes"][0]["awardYear"],r["nobelPrizes"][0]["category"]["en"])
#        print (l,r["nobelPrizes"][0]["category"]["en"])
#        print (l,r["nobelPrizes"][0]["category"])
#        print (l,r["nobelPrizes"]["awardYear"])
#        print (l,r["nobelPrizes"][0]["awardYear"])
#        print (l,type(r["nobelPrizes"][0]["awardYear"]))
#        print (l,type(r["nobelPrizes"][0]))
#        print (l,r["nobelPrizes"][0].keys())
#        print (l,r["id"],r["nobelPrizes"])
        print (l,"\tid:",r["id"])
        #dfmerge.at[l,"awardYear"] = r["nobelPrizes"][0]["awardYear"]
        #dfmerge.at[l,"category"]= r["nobelPrizes"][0]["category"]["en"]
    except Exception as e: 
        print(e)    
        print (l,r.keys())
#        print (l,r["nobelPrizes"])
# Out:
# 0 	id: 1.0
# 1 	id: 2.0
# 2 	id: 3.0
# 3 	id: 4.0
# 4 	id: 5.0
# 5 	id: 6.0
# 6 	id: 8.0
# 7 	id: 9.0
# 8 	id: 10.0
# 9 	id: 11.0
# 10 	id: 12.0
# 11 	id: 13.0
# 12 	id: 14.0
# 13 	id: 15.0
# 14 	id: 16.0
# 15 	id: 17.0
# 16 	id: 18.0
# 17 	id: 19.0
# 18 	id: 20.0
# 19 	id: 21.0
# 20 	id: 22.0
# 21 	id: 23.0
# 22 	id: 23.0
# 23 	id: 24.0
# 24 	id: 25.0
# 25 	id: 26.0
# 26 	id: 27.0
# 27 	id: 28.0
# 28 	id: 29.0
# 29 	id: 30.0
# 30 	id: 31.0
# 31 	id: 32.0
# 32 	id: 33.0
# 33 	id: 34.0
# 34 	id: 35.0
# 35 	id: 36.0
# 36 	id: 37.0
# 37 	id: 38.0
# 38 	id: 39.0
# 39 	id: 40.0
# 40 	id: 41.0
# 41 	id: 41.0
# 42 	id: 42.0
# 43 	id: 43.0
# 44 	id: 44.0
# 45 	id: 45.0
# 46 	id: 46.0
# 47 	id: 47.0
# 48 	id: 48.0
# 49 	id: 49.0
# 50 	id: 50.0
# 51 	id: 51.0
# 52 	id: 52.0
# 53 	id: 53.0
# 54 	id: 54.0
# 55 	id: 55.0
# 56 	id: 56.0
# 57 	id: 57.0
# 58 	id: 58.0
# 59 	id: 59.0
# 60 	id: 60.0
# 61 	id: 61.0
# 62 	id: 62.0
# 63 	id: 63.0
# 64 	id: 64.0
# 65 	id: 65.0
# 66 	id: 66.0
# 67 	id: 67.0
# 68 	id: 68.0
# 69 	id: 69.0
# 70 	id: 70.0
# 71 	id: 71.0
# 72 	id: 72.0
# 73 	id: 73.0
# 74 	id: 74.0
# 75 	id: 75.0
# 76 	id: 76.0
# 77 	id: 77.0
# 78 	id: 78.0
# 79 	id: 79.0
# 80 	id: 80.0
# 81 	id: 81.0
# 82 	id: 82.0
# 83 	id: 83.0
# 84 	id: 84.0
# 85 	id: 85.0
# 86 	id: 86.0
# 87 	id: 87.0
# 88 	id: 88.0
# 89 	id: 89.0
# 90 	id: 90.0
# 91 	id: 91.0
# 92 	id: 92.0
# 93 	id: 93.0
# 94 	id: 95.0
# 95 	id: 96.0
# 96 	id: 97.0
# 97 	id: 98.0
# 98 	id: 99.0
# 99 	id: 100.0
# 100 	id: 101.0
# 101 	id: 102.0
# 102 	id: 103.0
# 103 	id: 104.0
# 104 	id: 105.0
# 105 	id: 106.0
# 106 	id: 107.0
# 107 	id: 108.0
# 108 	id: 109.0
# 109 	id: 110.0
# 110 	id: 111.0
# 111 	id: 112.0
# 112 	id: 113.0
# 113 	id: 114.0
# 114 	id: 115.0
# 115 	id: 116.0
# 116 	id: 117.0
# 117 	id: 117.0
# 118 	id: 118.0
# 119 	id: 119.0
# 120 	id: 120.0
# 121 	id: 121.0
# 122 	id: 122.0
# 123 	id: 123.0
# 124 	id: 124.0
# 125 	id: 125.0
# 126 	id: 126.0
# 127 	id: 127.0
# 128 	id: 128.0
# 129 	id: 129.0
# 130 	id: 130.0
# 131 	id: 131.0
# 132 	id: 132.0
# 133 	id: 133.0
# 134 	id: 134.0
# 135 	id: 135.0
# 136 	id: 136.0
# 137 	id: 137.0
# 138 	id: 138.0
# 139 	id: 139.0
# 140 	id: 140.0
# 141 	id: 141.0
# 142 	id: 142.0
# 143 	id: 143.0
# 144 	id: 144.0
# 145 	id: 145.0
# 146 	id: 146.0
# 147 	id: 147.0
# 148 	id: 148.0
# 149 	id: 149.0
# 150 	id: 150.0
# 151 	id: 151.0
# 152 	id: 152.0
# 153 	id: 153.0
# 154 	id: 154.0
# 155 	id: 155.0
# 156 	id: 156.0
# 157 	id: 157.0
# 158 	id: 158.0
# 159 	id: 159.0
# 160 	id: 160.0
# 161 	id: 161.0
# 162 	id: 162.0
# 163 	id: 163.0
# 164 	id: 164.0
# 165 	id: 165.0
# 166 	id: 166.0
# 167 	id: 167.0
# 168 	id: 168.0
# 169 	id: 169.0
# 170 	id: 172.0
# 171 	id: 173.0
# 172 	id: 174.0
# 173 	id: 175.0
# 174 	id: 176.0
# 175 	id: 177.0
# 176 	id: 178.0
# 177 	id: 179.0
# 178 	id: 180.0
# 179 	id: 181.0
# 180 	id: 182.0
# 181 	id: 183.0
# 182 	id: 184.0
# 183 	id: 185.0
# 184 	id: 186.0
# 185 	id: 187.0
# 186 	id: 188.0
# 187 	id: 189.0
# 188 	id: 190.0
# 189 	id: 191.0
# 190 	id: 192.0
# 191 	id: 193.0
# 192 	id: 194.0
# 193 	id: 195.0
# 194 	id: 196.0
# 195 	id: 197.0
# 196 	id: 198.0
# 197 	id: 198.0
# 198 	id: 199.0
# 199 	id: 200.0
# 200 	id: 201.0
# 201 	id: 202.0
# 202 	id: 203.0
# 203 	id: 204.0
# 204 	id: 205.0
# 205 	id: 206.0
# 206 	id: 207.0
# 207 	id: 208.0
# 208 	id: 209.0
# 209 	id: 210.0
# 210 	id: 211.0
# 211 	id: 212.0
# 212 	id: 213.0
# 213 	id: 214.0
# 214 	id: 215.0
# 215 	id: 216.0
# 216 	id: 217.0
# 217 	id: 217.0
# 218 	id: 218.0
# 219 	id: 219.0
# 220 	id: 220.0
# 221 	id: 221.0
# 222 	id: 222.0
# 223 	id: 223.0
# 224 	id: 224.0
# 225 	id: 225.0
# 226 	id: 226.0
# 227 	id: 227.0
# 228 	id: 228.0
# 229 	id: 229.0
# 230 	id: 230.0
# 231 	id: 231.0
# 232 	id: 232.0
# 233 	id: 233.0
# 234 	id: 234.0
# 235 	id: 235.0
# 236 	id: 236.0
# 237 	id: 237.0
# 238 	id: 238.0
# 239 	id: 239.0
# 240 	id: 240.0
# 241 	id: 241.0
# 242 	id: 242.0
# 243 	id: 243.0
# 244 	id: 244.0
# 245 	id: 245.0
# 246 	id: 246.0
# 247 	id: 247.0
# 248 	id: 248.0
# 249 	id: 249.0
# 250 	id: 250.0
# 251 	id: 251.0
# 252 	id: 252.0
# 253 	id: 253.0
# 254 	id: 254.0
# 255 	id: 255.0
# 256 	id: 257.0
# 257 	id: 258.0
# 258 	id: 259.0
# 259 	id: 260.0
# 260 	id: 261.0
# 261 	id: 262.0
# 262 	id: 263.0
# 263 	id: 264.0
# 264 	id: 265.0
# 265 	id: 266.0
# 266 	id: 267.0
# 267 	id: 268.0
# 268 	id: 269.0
# 269 	id: 270.0
# 270 	id: 271.0
# 271 	id: 272.0
# 272 	id: 273.0
# 273 	id: 274.0
# 274 	id: 275.0
# 275 	id: 276.0
# 276 	id: 277.0
# 277 	id: 278.0
# 278 	id: 279.0
# 279 	id: 280.0
# 280 	id: 281.0
# 281 	id: 282.0
# 282 	id: 283.0
# 283 	id: 284.0
# 284 	id: 285.0
# 285 	id: 286.0
# 286 	id: 287.0
# 287 	id: 288.0
# 288 	id: 289.0
# 289 	id: 290.0
# 290 	id: 291.0
# 291 	id: 292.0
# 292 	id: 293.0
# 293 	id: 294.0
# 294 	id: 295.0
# 295 	id: 296.0
# 296 	id: 297.0
# 297 	id: 298.0
# 298 	id: 299.0
# 299 	id: 300.0
# 300 	id: 301.0
# 301 	id: 301.0
# 302 	id: 302.0
# 303 	id: 303.0
# 304 	id: 304.0
# 305 	id: 305.0
# 306 	id: 306.0
# 307 	id: 306.0
# 308 	id: 307.0
# 309 	id: 307.0
# 310 	id: 308.0
# 311 	id: 309.0
# 312 	id: 310.0
# 313 	id: 311.0
# 314 	id: 312.0
# 315 	id: 313.0
# 316 	id: 314.0
# 317 	id: 315.0
# 318 	id: 316.0
# 319 	id: 317.0
# 320 	id: 318.0
# 321 	id: 319.0
# 322 	id: 320.0
# 323 	id: 321.0
# 324 	id: 322.0
# 325 	id: 323.0
# 326 	id: 324.0
# 327 	id: 325.0
# 328 	id: 326.0
# 329 	id: 327.0
# 330 	id: 328.0
# 331 	id: 329.0
# 332 	id: 330.0
# 333 	id: 331.0
# 334 	id: 332.0
# 335 	id: 333.0
# 336 	id: 334.0
# 337 	id: 335.0
# 338 	id: 336.0
# 339 	id: 337.0
# 340 	id: 338.0
# 341 	id: 339.0
# 342 	id: 340.0
# 343 	id: 341.0
# 344 	id: 342.0
# 345 	id: 343.0
# 346 	id: 343.0
# 347 	id: 344.0
# 348 	id: 345.0
# 349 	id: 346.0
# 350 	id: 347.0
# 351 	id: 347.0
# 352 	id: 348.0
# 353 	id: 349.0
# 354 	id: 350.0
# 355 	id: 351.0
# 356 	id: 352.0
# 357 	id: 353.0
# 358 	id: 354.0
# 359 	id: 355.0
# 360 	id: 356.0
# 361 	id: 357.0
# 362 	id: 358.0
# 363 	id: 359.0
# 364 	id: 360.0
# 365 	id: 361.0
# 366 	id: 362.0
# 367 	id: 363.0
# 368 	id: 364.0
# 369 	id: 365.0
# 370 	id: 366.0
# 371 	id: 367.0
# 372 	id: 368.0
# 373 	id: 369.0
# 374 	id: 370.0
# 375 	id: 371.0
# 376 	id: 372.0
# 377 	id: 373.0
# 378 	id: 374.0
# 379 	id: 375.0
# 380 	id: 376.0
# 381 	id: 377.0
# 382 	id: 378.0
# 383 	id: 379.0
# 384 	id: 380.0
# 385 	id: 381.0
# 386 	id: 382.0
# 387 	id: 383.0
# 388 	id: 384.0
# 389 	id: 385.0
# 390 	id: 386.0
# 391 	id: 387.0
# 392 	id: 388.0
# 393 	id: 389.0
# 394 	id: 390.0
# 395 	id: 391.0
# 396 	id: 392.0
# 397 	id: 393.0
# 398 	id: 394.0
# 399 	id: 395.0
# 400 	id: 396.0
# 401 	id: 397.0
# 402 	id: 398.0
# 403 	id: 399.0
# 404 	id: 400.0
# 405 	id: 401.0
# 406 	id: 402.0
# 407 	id: 403.0
# 408 	id: 404.0
# 409 	id: 405.0
# 410 	id: 406.0
# 411 	id: 407.0
# 412 	id: 408.0
# 413 	id: 409.0
# 414 	id: 410.0
# 415 	id: 411.0
# 416 	id: 412.0
# 417 	id: 413.0
# 418 	id: 414.0
# 419 	id: 415.0
# 420 	id: 416.0
# 421 	id: 417.0
# 422 	id: 418.0
# 423 	id: 419.0
# 424 	id: 420.0
# 425 	id: 421.0
# 426 	id: 422.0
# 427 	id: 423.0
# 428 	id: 424.0
# 429 	id: 425.0
# 430 	id: 426.0
# 431 	id: 427.0
# 432 	id: 428.0
# 433 	id: 429.0
# 434 	id: 430.0
# 435 	id: 431.0
# 436 	id: 432.0
# 437 	id: 433.0
# 438 	id: 434.0
# 439 	id: 435.0
# 440 	id: 436.0
# 441 	id: 437.0
# 442 	id: 438.0
# 443 	id: 439.0
# 444 	id: 440.0
# 445 	id: 441.0
# 446 	id: 442.0
# 447 	id: 443.0
# 448 	id: 444.0
# 449 	id: 445.0
# 450 	id: 446.0
# 451 	id: 447.0
# 452 	id: 448.0
# 453 	id: 449.0
# 454 	id: 450.0
# 455 	id: 451.0
# 456 	id: 452.0
# 457 	id: 453.0
# 458 	id: 454.0
# 459 	id: 455.0
# 460 	id: 456.0
# 461 	id: 457.0
# 462 	id: 458.0
# 463 	id: 459.0
# 464 	id: 460.0
# 465 	id: 461.0
# 466 	id: 462.0
# 467 	id: 463.0
# 468 	id: 464.0
# 469 	id: 465.0
# 470 	id: 466.0
# 471 	id: 467.0
# 472 	id: 468.0
# 473 	id: 470.0
# 474 	id: 471.0
# 475 	id: 472.0
# 476 	id: 473.0
# 477 	id: 474.0
# 478 	id: 475.0
# 479 	id: 476.0
# 480 	id: 477.0
# 481 	id: 478.0
# 482 	id: 478.0
# 483 	id: 479.0
# 484 	id: 480.0
# 485 	id: 481.0
# 486 	id: 482.0
# 487 	id: 483.0
# 488 	id: 484.0
# 489 	id: 485.0
# 490 	id: 486.0
# 491 	id: 487.0
# 492 	id: 488.0
# 493 	id: 489.0
# 494 	id: 490.0
# 495 	id: 491.0
# 496 	id: 492.0
# 497 	id: 493.0
# 498 	id: 494.0
# 499 	id: 495.0
# 500 	id: 496.0
# 501 	id: 497.0
# 502 	id: 498.0
# 503 	id: 499.0
# 504 	id: 500.0
# 505 	id: 501.0
# 506 	id: 502.0
# 507 	id: 503.0
# 508 	id: 505.0
# 509 	id: 506.0
# 510 	id: 507.0
# 511 	id: 508.0
# 512 	id: 509.0
# 513 	id: 510.0
# 514 	id: 511.0
# 515 	id: 512.0
# 516 	id: 513.0
# 517 	id: 514.0
# 518 	id: 515.0
# 519 	id: 516.0
# 520 	id: 517.0
# 521 	id: 518.0
# 522 	id: 519.0
# 523 	id: 520.0
# 524 	id: 523.0
# 525 	id: 524.0
# 526 	id: 525.0
# 527 	id: 526.0
# 528 	id: 527.0
# 529 	id: 528.0
# 530 	id: 529.0
# 531 	id: 530.0
# 532 	id: 531.0
# 533 	id: 532.0
# 534 	id: 533.0
# 535 	id: 534.0
# 536 	id: 535.0
# 537 	id: 536.0
# 538 	id: 537.0
# 539 	id: 538.0
# 540 	id: 539.0
# 541 	id: 540.0
# 542 	id: 541.0
# 543 	id: 543.0
# 544 	id: 544.0
# 545 	id: 545.0
# 546 	id: 546.0
# 547 	id: 547.0
# 548 	id: 548.0
# 549 	id: 549.0
# 550 	id: 550.0
# 551 	id: 551.0
# 552 	id: 552.0
# 553 	id: 553.0
# 554 	id: 554.0
# 555 	id: 555.0
# 556 	id: 556.0
# 557 	id: 557.0
# 558 	id: 558.0
# 559 	id: 559.0
# 560 	id: 560.0
# 561 	id: 561.0
# 562 	id: 562.0
# 563 	id: 563.0
# 564 	id: 564.0
# 565 	id: 565.0
# 566 	id: 566.0
# 567 	id: 567.0
# 568 	id: 568.0
# 569 	id: 569.0
# 570 	id: 571.0
# 571 	id: 572.0
# 572 	id: 573.0
# 573 	id: 574.0
# 574 	id: 575.0
# 575 	id: 576.0
# 576 	id: 577.0
# 577 	id: 578.0
# 578 	id: 578.0
# 579 	id: 579.0
# 580 	id: 580.0
# 581 	id: 581.0
# 582 	id: 582.0
# 583 	id: 583.0
# 584 	id: 584.0
# 585 	id: 585.0
# 586 	id: 586.0
# 587 	id: 587.0
# 588 	id: 588.0
# 589 	id: 589.0
# 590 	id: 590.0
# 591 	id: 592.0
# 592 	id: 593.0
# 593 	id: 594.0
# 594 	id: 596.0
# 595 	id: 597.0
# 596 	id: 600.0
# 597 	id: 601.0
# 598 	id: 602.0
# 599 	id: 603.0
# 600 	id: 604.0
# 601 	id: 605.0
# 602 	id: 606.0
# 603 	id: 607.0
# 604 	id: 608.0
# 605 	id: 609.0
# 606 	id: 610.0
# 607 	id: 613.0
# 608 	id: 614.0
# 609 	id: 615.0
# 610 	id: 617.0
# 611 	id: 618.0
# 612 	id: 619.0
# 613 	id: 620.0
# 614 	id: 621.0
# 615 	id: 622.0
# 616 	id: 623.0
# 617 	id: 624.0
# 618 	id: 625.0
# 619 	id: 626.0
# 620 	id: 627.0
# 621 	id: 628.0
# 622 	id: 629.0
# 623 	id: 630.0
# 624 	id: 631.0
# 625 	id: 633.0
# 626 	id: 634.0
# 627 	id: 635.0
# 628 	id: 637.0
# 629 	id: 638.0
# 630 	id: 639.0
# 631 	id: 640.0
# 632 	id: 641.0
# 633 	id: 642.0
# 634 	id: 643.0
# 635 	id: 644.0
# 636 	id: 645.0
# 637 	id: 647.0
# 638 	id: 648.0
# 639 	id: 648.0
# 640 	id: 649.0
# 641 	id: 650.0
# 642 	id: 651.0
# 643 	id: 652.0
# 644 	id: 653.0
# 645 	id: 654.0
# 646 	id: 655.0
# 647 	id: 657.0
# 648 	id: 658.0
# 649 	id: 659.0
# 650 	id: 660.0
# 651 	id: 661.0
# 652 	id: 662.0
# 653 	id: 663.0
# 654 	id: 664.0
# 655 	id: 665.0
# 656 	id: 666.0
# 657 	id: 667.0
# 658 	id: 668.0
# 659 	id: 669.0
# 660 	id: 670.0
# 661 	id: 671.0
# 662 	id: 672.0
# 663 	id: 673.0
# 664 	id: 674.0
# 665 	id: 675.0
# 666 	id: 676.0
# 667 	id: 677.0
# 668 	id: 678.0
# 669 	id: 679.0
# 670 	id: 680.0
# 671 	id: 681.0
# 672 	id: 682.0
# 673 	id: 683.0
# 674 	id: 684.0
# 675 	id: 685.0
# 676 	id: 686.0
# 677 	id: 687.0
# 678 	id: 688.0
# 679 	id: 689.0
# 680 	id: 690.0
# 681 	id: 691.0
# 682 	id: 692.0
# 683 	id: 693.0
# 684 	id: 694.0
# 685 	id: 695.0
# 686 	id: 696.0
# 687 	id: 697.0
# 688 	id: 698.0
# 689 	id: 699.0
# 690 	id: 700.0
# 691 	id: 701.0
# 692 	id: 702.0
# 693 	id: 703.0
# 694 	id: 704.0
# 695 	id: 705.0
# 696 	id: 706.0
# 697 	id: 707.0
# 698 	id: 708.0
# 699 	id: 709.0
# 700 	id: 710.0
# 701 	id: 711.0
# 702 	id: 712.0
# 703 	id: 713.0
# 704 	id: 714.0
# 705 	id: 715.0
# 706 	id: 716.0
# 707 	id: 717.0
# 708 	id: 718.0
# 709 	id: 719.0
# 710 	id: 720.0
# 711 	id: 721.0
# 712 	id: 722.0
# 713 	id: 723.0
# 714 	id: 724.0
# 715 	id: 725.0
# 716 	id: 726.0
# 717 	id: 727.0
# 718 	id: 728.0
# 719 	id: 729.0
# 720 	id: 730.0
# 721 	id: 731.0
# 722 	id: 732.0
# 723 	id: 733.0
# 724 	id: 734.0
# 725 	id: 735.0
# 726 	id: 736.0
# 727 	id: 737.0
# 728 	id: 738.0
# 729 	id: 739.0
# 730 	id: 740.0
# 731 	id: 741.0
# 732 	id: 742.0
# 733 	id: 743.0
# 734 	id: 744.0
# 735 	id: 745.0
# 736 	id: 746.0
# 737 	id: 747.0
# 738 	id: 748.0
# 739 	id: 749.0
# 740 	id: 750.0
# 741 	id: 751.0
# 742 	id: 752.0
# 743 	id: 753.0
# 744 	id: 754.0
# 745 	id: 755.0
# 746 	id: 756.0
# 747 	id: 757.0
# 748 	id: 758.0
# 749 	id: 759.0
# 750 	id: 760.0
# 751 	id: 761.0
# 752 	id: 762.0
# 753 	id: 763.0
# 754 	id: 764.0
# 755 	id: 765.0
# 756 	id: 766.0
# 757 	id: 767.0
# 758 	id: 768.0
# 759 	id: 769.0
# 760 	id: 770.0
# 761 	id: 771.0
# 762 	id: 772.0
# 763 	id: 773.0
# 764 	id: 774.0
# 765 	id: 775.0
# 766 	id: 776.0
# 767 	id: 777.0
# 768 	id: 778.0
# 769 	id: 779.0
# 770 	id: 780.0
# 771 	id: 781.0
# 772 	id: 782.0
# 773 	id: 783.0
# 774 	id: 786.0
# 775 	id: 787.0
# 776 	id: 789.0
# 777 	id: 790.0
# 778 	id: 791.0
# 779 	id: 792.0
# 780 	id: 793.0
# 781 	id: 794.0
# 782 	id: 795.0
# 783 	id: 796.0
# 784 	id: 797.0
# 785 	id: 798.0
# 786 	id: 799.0
# 787 	id: 800.0
# 788 	id: 801.0
# 789 	id: 802.0
# 790 	id: 803.0
# 791 	id: 804.0
# 792 	id: 805.0
# 793 	id: 806.0
# 794 	id: 807.0
# 795 	id: 808.0
# 796 	id: 809.0
# 797 	id: 810.0
# 798 	id: 811.0
# 799 	id: 812.0
# 800 	id: 813.0
# 801 	id: 814.0
# 802 	id: 815.0
# 803 	id: 816.0
# 804 	id: 817.0
# 805 	id: 818.0
# 806 	id: 819.0
# 807 	id: 820.0
# 808 	id: 821.0
# 809 	id: 822.0
# 810 	id: 823.0
# 811 	id: 824.0
# 812 	id: 825.0
# 813 	id: 826.0
# 814 	id: 827.0
# 815 	id: 828.0
# 816 	id: 829.0
# 817 	id: 830.0
# 818 	id: 831.0
# 819 	id: 832.0
# 820 	id: 833.0
# 821 	id: 834.0
# 822 	id: 835.0
# 823 	id: 836.0
# 824 	id: 837.0
# 825 	id: 838.0
# 826 	id: 839.0
# 827 	id: 840.0
# 828 	id: 841.0
# 829 	id: 842.0
# 830 	id: 843.0
# 831 	id: 844.0
# 832 	id: 845.0
# 833 	id: 846.0
# 834 	id: 847.0
# 835 	id: 848.0
# 836 	id: 849.0
# 837 	id: 850.0
# 838 	id: 851.0
# 839 	id: 852.0
# 840 	id: 853.0
# 841 	id: 854.0
# 842 	id: 855.0
# 843 	id: 856.0
# 844 	id: 857.0
# 845 	id: 858.0
# 846 	id: 861.0
# 847 	id: 862.0
# 848 	id: 863.0
# 849 	id: 864.0
# 850 	id: 865.0
# 851 	id: 866.0
# 852 	id: 867.0
# 853 	id: 868.0
# 854 	id: 869.0
# 855 	id: 870.0
# 856 	id: 871.0
# 857 	id: 872.0
# 858 	id: 873.0
# 859 	id: 874.0
# 860 	id: 875.0
# 861 	id: 876.0
# 862 	id: 877.0
# 863 	id: 878.0
# 864 	id: 879.0
# 865 	id: 880.0
# 866 	id: 881.0
# 867 	id: 882.0
# 868 	id: 883.0
# 869 	id: 884.0
# 870 	id: 885.0
# 871 	id: 886.0
# 872 	id: 887.0
# 873 	id: 888.0
# 874 	id: 889.0
# 875 	id: 890.0
# 876 	id: 891.0
# 877 	id: 892.0
# 878 	id: 893.0
# 879 	id: 894.0
# 880 	id: 895.0
# 881 	id: 896.0
# 882 	id: 903.0
# 883 	id: 904.0
# 884 	id: 905.0
# 885 	id: 906.0
# 886 	id: 907.0
# 887 	id: 908.0
# 888 	id: 909.0
# 889 	id: 910.0
# 890 	id: 911.0
# 891 	id: 912.0
# 892 	id: 913.0
# 893 	id: 914.0
# 894 	id: 915.0
# 895 	id: 916.0
# 896 	id: 917.0
# 897 	id: 918.0
# 898 	id: 919.0
# 899 	id: 920.0
# 900 	id: 921.0
# 901 	id: 922.0
# 902 	id: 923.0
# 903 	id: 924.0
# 904 	id: 925.0
# 905 	id: 926.0
# 906 	id: 927.0
# 907 	id: 928.0
# 908 	id: 929.0
# 909 	id: 930.0
# 910 	id: 931.0
# 911 	id: 932.0
# 912 	id: 933.0
# 913 	id: 934.0
# 914 	id: 935.0
# 915 	id: 936.0
# 916 	id: 937.0
# 917 	id: 938.0
# 918 	id: 939.0
# 919 	id: 940.0
# 920 	id: 941.0
# 921 	id: 942.0
# 922 	id: 943.0
# 923 	id: 944.0
# 924 	id: 945.0
# 925 	id: 946.0
# 926 	id: 947.0
# 927 	id: 948.0
# 928 	id: 949.0
# 929 	id: 958.0
# 930 	id: 959.0
# 931 	id: 960.0
# 932 	id: 961.0
# 933 	id: 962.0
# 934 	id: 963.0
# 935 	id: 964.0
# 936 	id: 965.0
# 937 	id: 966.0
# 938 	id: 967.0
# 939 	id: 968.0
# 940 	id: 969.0
# 941 	id: 970.0
# 942 	id: 971.0
# 943 	id: 972.0
# 944 	id: 973.0
# 945 	id: 974.0
# 946 	id: 975.0
# 947 	id: 976.0
# 948 	id: 977.0
# 949 	id: 978.0
# 950 	id: 979.0
# 951 	id: 980.0
# 952 	id: 981.0
# 953 	id: 982.0
# 954 	id: 983.0
# 955 	id: 984.0
# 956 	id: 985.0
# 957 	id: 986.0
# 958 	id: 987.0
# 959 	id: 988.0
# 960 	id: 989.0
# 961 	id: 990.0
# 962 	id: 991.0
# 963 	id: 992.0
# 964 	id: 993.0
# 965 	id: 994.0
# 966 	id: 995.0
# 967 	id: 996.0
# 968 	id: 997.0
# 969 	id: 998.0
# 970 	id: nan
# 971 	id: nan
# 972 	id: nan
# 973 	id: nan
# 974 	id: nan
# 975 	id: nan
# 976 	id: nan
# 977 	id: nan

# %% [markdown]
# ## Lesson learned
# Its a delay when the html page is linked after the announcement --> we do this list below to check when its ready and we can add it to Wikidata and the WIkipedia article

# %%
pd.set_option("max_info_columns", 140)
#dfmerge.info()

# %%
# see task xxx we can create links JSOn and HTML using the ID

dfmerge["linkjson"] = "<a href='http://api.nobelprize.org/2.1/laureate/" + dfmerge["id"].astype(str) + "'>json</a>"
dfmerge["linkhtml"] = "<a href='https://www.nobelprize.org/laureate/" + dfmerge["id"].astype(str) + "'>html</a>"
dfmerge["wd"] = "<a href='" + dfmerge["WDitem"].astype(str) + "'>Wikidata</a>"

pd.set_option("display.max.columns", None) 
HTML(dfmerge[{'wd','knownName.en','awardYear','category','linkjson','linkhtml'}].tail(15).to_html(escape=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-0e06009e6b00> in <module>
#       6
#       7 pd.set_option("display.max.columns", None)
# ----> 8 HTML(dfmerge[{'wd','knownName.en','awardYear','category','linkjson','linkhtml'}].tail(15).to_html(escape=False))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['awardYear', 'category'] not in index"

# %% [markdown]
# Status 20201009 :
# * Ok all has html pages
#
# Templates supporting Wikidata Property 8024 = Wikidata [Q91652187](https://www.wikidata.org/wiki/Q91652187)
# * ar:Wikipedia [قالب:جائزة_نوبل](https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D9%84%D8%A8:%D8%AC%D8%A7%D8%A6%D8%B2%D8%A9_%D9%86%D9%88%D8%A8%D9%84)
# * ca:wikipedia [Plantilla:Nobelprize](https://ca.wikipedia.org/wiki/Plantilla:Nobelprize)
# * en:Wikipedia [Template:Nobelprize](https://en.wikipedia.org/wiki/Template:Nobelprize)
# * ka:Wikipedia [თარგი:Nobelprize](https://ka.wikipedia.org/wiki/%E1%83%97%E1%83%90%E1%83%A0%E1%83%92%E1%83%98:Nobelprize)
# * nn:Wikipedia [Mal:Nobelprize](https://nn.wikipedia.org/wiki/Mal:Nobelprize)
# * pt:Wikipedia [Predefinição:Prémio Nobel](https://pt.wikipedia.org/wiki/Predefini%C3%A7%C3%A3o:Pr%C3%A9mio_Nobel)
# * sv:Wikipedia [Mall:Nobelprize](https://sv.wikipedia.org/wiki/Mall:Nobelprize)
# * sr:WIkipedia [Шаблон:Nobelprize](https://sr.wikipedia.org/wiki/%D0%A8%D0%B0%D0%B1%D0%BB%D0%BE%D0%BD:Nobelprize)

# %% [markdown]
# * Articles using [template](https://www.wikidata.org/wiki/Q91652187) and view statistics this year and during the [Nobel week](https://www.nobelprize.org/press/#/publication/5f1719e411aab40004a17f36/552bd85dccc8e20c00e7f979?&sh=false)  5-12 October 2020 on those articles see also [video](https://youtu.be/Iu1JtefueM8)
#   * ar:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573153) / not using
#     * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://ar.wikipedia.org/wiki/%25D8%25AA%25D8%25B5%25D9%2586%25D9%258A%25D9%2581:%25D9%2582%25D8%25A7%25D9%2584%25D8%25A8_%25D8%25AC%25D8%25A7%25D8%25A6%25D8%25B2%25D8%25A9_%25D9%2586%25D9%2588%25D8%25A8%25D9%2584_%25D9%258A%25D8%25B3%25D8%25AA%25D8%25B9%25D9%2585%25D9%2584_%25D8%25AE%25D8%25A7%25D8%25B5%25D8%25A9_%25D9%2588%25D9%258A%25D9%2583%25D9%258A_%25D8%25A8%25D9%258A%25D8%25A7%25D9%2586%25D8%25A7%25D8%25AA_P8024) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://ar.wikipedia.org/wiki/%25D8%25AA%25D8%25B5%25D9%2586%25D9%258A%25D9%2581:%25D9%2582%25D8%25A7%25D9%2584%25D8%25A8_%25D8%25AC%25D8%25A7%25D8%25A6%25D8%25B2%25D8%25A9_%25D9%2586%25D9%2588%25D8%25A8%25D9%2584_%25D9%258A%25D8%25B3%25D8%25AA%25D8%25B9%25D9%2585%25D9%2584_%25D8%25AE%25D8%25A7%25D8%25B5%25D8%25A9_%25D9%2588%25D9%258A%25D9%2583%25D9%258A_%25D8%25A8%25D9%258A%25D8%25A7%25D9%2586%25D8%25A7%25D8%25AA_P8024)
#   * ca:Wikipedia miss track category [Q91672712](https://www.wikidata.org/wiki/Q91672712#sitelinks-wikipedia)
#   * en:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573140) / [not using](https://petscan.wmflabs.org/?psid=17579263)
#     * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://en.wikipedia.org/wiki/Category:Nobelprize_template_using_Wikidata_property_P8024) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://en.wikipedia.org/wiki/Category:Nobelprize_template_using_Wikidata_property_P8024) as a [chart](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-10&subjectpage=0&subcategories=0&sort=views&direction=1&view=chart&target=https://en.wikipedia.org/wiki/Category:Nobelprize%20template%20using%20Wikidata%20property%20P8024)
#   * ka:Wikipedia miss track category [Q91672712](https://www.wikidata.org/wiki/Q91672712#sitelinks-wikipedia)
#   * nn:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573155) / not using
#      * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://nn.wikipedia.org/wiki/Kategori:Sider_som_nyttar_Mal:Nobelprize) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://nn.wikipedia.org/wiki/Kategori:Sider_som_nyttar_Mal:Nobelprize)
#   * pt:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573158) / [not using](https://petscan.wmflabs.org/?psid=17579612)
#      * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://pt.wikipedia.org/wiki/Categoria:Predefini%25C3%25A7%25C3%25A3o_sobre_pr%25C3%25A9mios_Nobel_que_usam_a_propriedade_do_Wikidata_P8024) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://pt.wikipedia.org/wiki/Categoria:Predefini%25C3%25A7%25C3%25A3o_sobre_pr%25C3%25A9mios_Nobel_que_usam_a_propriedade_do_Wikidata_P8024)
#   * sv:Wikipedia [using](https://petscan.wmflabs.org/?psid=17573129) / not using
#     * [statistics](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&range=this-year&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://sv.wikipedia.org/wiki/Kategori:Sidor_som_anv%25C3%25A4nder_Mall:Nobelprize) / [Nobel week](https://pageviews.toolforge.org/massviews/?platform=all-access&agent=user&source=category&start=2020-10-05&end=2020-10-12&subjectpage=0&subcategories=0&sort=views&direction=1&view=list&target=https://sv.wikipedia.org/wiki/Kategori:Sidor_som_anv%25C3%25A4nder_Mall:Nobelprize)
#   * sr:Wikipedia miss track category [Q91672712](https://www.wikidata.org/wiki/Q91672712#sitelinks-wikipedia)
#
# Task [T251055](https://phabricator.wikimedia.org/T251055)

# %% [markdown]
# # Next Nobelprize announcement
# see https://www.nobelprize.org/
