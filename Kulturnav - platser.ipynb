# %% [markdown]
# ## Kulturnav - platser

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 
pd.set_option("display.max.columns", None) 
urlbase = "https://kulturnav.org/api/search/entityType:Place?start=" 

dftot = pd.DataFrame()
for i in range(1,10000,20):
    url = urlbase + str(i)
    if ((i-1) % 1000) == 0:
       print('*', end='', flush=True)
    r = http.request('GET', url)
    try:
        data = json.loads(r.data)
        dftot = dftot.append(pd.DataFrame(data),sort=False)
    except:
        print("\tError in i=",i)
# Out:
# **********

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 19
# Data columns (total 13 columns):
# uuid                   10000 non-null object
# entityType             10000 non-null object
# acl                    10000 non-null object
# currentVersion         10000 non-null bool
# createdAt              10000 non-null object
# createdBy              10000 non-null object
# updatedAt              10000 non-null object
# updatedBy              10000 non-null object
# inline                 10000 non-null bool
# caption                10000 non-null object
# properties             10000 non-null object
# entityTypeName         10000 non-null object
# entityTypeHierarchy    10000 non-null object
# dtypes: bool(2), object(11)
# memory usage: 957.0+ KB

# %%
dftot
# Out:
#                                     uuid entityType  \
# 0   7d2af8fe-e49f-4e60-ad3d-6d15bd9ad5a2      Place
# 1   93b4b747-f6ff-4941-9037-bef13f301996      Place
# 2   5696452b-9f42-4f57-b055-7728f3cb9fc7      Place
# 3   6831f531-3bc8-4195-baf5-af88508d1ba3      Place
# 4   ed33f494-9f8c-4965-aa33-5ee292ae2e75      Place
# 5   ba367d18-5c7c-467d-87ce-b42791708561      Place
# 6   76619346-5863-4236-bb60-77fcbfd45b81      Place
# 7   f99a7638-04d0-4ef4-b888-e549884fd5ac      Place
# 8   3dc28bdd-dc7c-45de-86eb-dffde3251f05      Place
# 9   5eaddab7-fe42-4d52-a517-a7c34b31c516      Place
# 10  b9622ca3-c9cd-4c19-a3c4-8c2e51cb2d49      Place
# 11  b8bfe85e-69c9-49fa-aa7a-9e633f25546d      Place
# 12  649f0915-f0f0-4600-a0e8-80268f0a1ce5      Place
# 13  b1f30246-eda8-43e7-b62a-7a6fd86448bb      Place
# 14  4ac8952b-b027-43eb-a682-dfa2c683f10a      Place
# 15  57f2ab10-0e89-488f-9477-abec2e0acd29      Place
# 16  21571579-870c-493e-8e13-33412fd0ae30      Place
# 17  a2e71779-6584-4f9a-9b0e-1da44dab97ec      Place
# 18  732f588a-acdd-4bd1-831e-0880dc924567      Place
# 19  b65b2e63-5872-4b08-8f29-0f7bd54e97f4      Place
#
#                                             acl  currentVersion  \
# 0   20f38d04-1f20-4011-9732-fa1f0853ce1b_SHARED            True
# 1   0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 2   0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 3   0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 4   0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 5   0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 6   0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 7   0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 8   0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 9   0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 10  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 11  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 12  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 13  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 14  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 15  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 16  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 17  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 18  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
# 19  0d67c666-260b-4c7e-95cd-b7f440d46d5c_SHARED            True
#
#                    createdAt                             createdBy  \
# 0   Nov 13, 2013 11:54:02 PM                                  root
# 1    Apr 18, 2016 4:46:44 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 2    Apr 18, 2016 4:39:58 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 3    Apr 18, 2016 4:40:26 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 4    Apr 18, 2016 4:49:19 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 5    Apr 18, 2016 4:47:53 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 6    Apr 18, 2016 4:40:50 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 7    Apr 18, 2016 4:49:44 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 8    Apr 18, 2016 4:39:13 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 9    Apr 18, 2016 4:40:11 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 10   Apr 18, 2016 4:47:50 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 11   Apr 18, 2016 4:47:49 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 12   Apr 18, 2016 4:40:21 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 13   Apr 18, 2016 4:47:37 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 14   Apr 18, 2016 4:39:36 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 15   Apr 18, 2016 4:40:00 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 16   Apr 18, 2016 4:38:19 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 17   Apr 18, 2016 4:47:11 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 18   Apr 18, 2016 4:40:44 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
# 19   Apr 18, 2016 4:47:45 PM  7b89c094-da28-4fdb-bcd2-ce0db0df923e
#
#                   updatedAt                             updatedBy  inline  \
# 0    Jan 9, 2015 1:20:16 PM                                  root    True
# 1   Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 2   Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 3   Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 4   Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 5   Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 6   Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 7   Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 8   Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 9   Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 10  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 11  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 12  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 13  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 14  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 15  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 16  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 17  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 18  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
# 19  Apr 19, 2016 4:10:52 AM  7b89c094-da28-4fdb-bcd2-ce0db0df923e   False
#
#                                               caption  \
# 0          {'no': '(Lille) Lunnerød (Befolket sted)'}
# 1   {'sv': '1:A BLEKINGE INDELTA BÅTSMANSKOMPANI 1...
# 2   {'sv': '1:A BOHUSLÄNS BÅTSMANSKOMPANI 14 (Mili...
# 3   {'sv': '1:A GOTLANDS BÅTSMANSKOMPANI 09 (Milit...
# 4   {'sv': '1:A LIVGRENADJÄRREGEMENTET 05 (Militär...
# 5   {'sv': '1:A LIVGRENADJÄRREGEMENTET 06 (Militär...
# 6   {'sv': '1:A LIVGRENADJÄRREGEMENTET 08 (Militär...
# 7   {'sv': '1:A NORRLANDS 1:A KOMPANI 21 (Militär ...
# 8   {'sv': '1:A NORRLANDS 1:ADELS KOMPANI 21 (Mili...
# 9   {'sv': '1:A NORRLANDS 2:A KOMPANI 21 (Militär ...
# 10  {'sv': '1:A NORRLANDS 2:ADELS BÅTSMANSKOMPANI ...
# 11  {'sv': '1:A SÖDERMANLANDS BÅTSMANSKOMPANI 01 (...
# 12  {'sv': '1:A SÖDRA MÖRE INDELTA BÅTSMANSKOMPANI...
# 13  {'sv': '1:A ÖLANDS BÅTSMANSKOMPANI 08 (Militär...
# 14  {'sv': '2:A BLEKINGE INDELTA BÅTSMANSKOMPANI 1...
# 15  {'sv': '2:A BOHUSLÄNS BÅTSMANSKOMPANI 14 (Mili...
# 16  {'sv': '2:A GOTLANDS BÅTSMANSKOMPANI 09 (Milit...
# 17  {'sv': '2:A LIVGRENADJÄRREGEMENTET 05 (Militär...
# 18  {'sv': '2:A LIVGRENADJÄRREGEMENTET 06 (Militär...
# 19  {'sv': '2:A LIVGRENADJÄRREGEMENTET 08 (Militär...
#
#                                            properties  \
# 0   {'entity.alternativeId': [{'uuid': '637541f9-5...
# 1   {'entity.alternativeId': [{'uuid': '8fb2447f-8...
# 2   {'entity.alternativeId': [{'uuid': '88b31445-0...
# 3   {'entity.alternativeId': [{'uuid': 'acdece40-e...
# 4   {'entity.alternativeId': [{'uuid': '4c012280-2...
# 5   {'entity.alternativeId': [{'uuid': 'fe05960b-7...
# 6   {'entity.alternativeId': [{'uuid': 'd94c2822-f...
# 7   {'entity.alternativeId': [{'uuid': '33c4677e-d...
# 8   {'entity.alternativeId': [{'uuid': '6ad73fc9-c...
# 9   {'entity.alternativeId': [{'uuid': '8b03a90b-9...
# 10  {'entity.alternativeId': [{'uuid': '05d3bc7c-5...
# 11  {'entity.alternativeId': [{'uuid': 'e4e6c1c0-9...
# 12  {'entity.alternativeId': [{'uuid': 'd141d54e-7...
# 13  {'entity.alternativeId': [{'uuid': '3033dbc8-7...
# 14  {'entity.alternativeId': [{'uuid': 'f38d3b04-e...
# 15  {'entity.alternativeId': [{'uuid': '48cf0e42-7...
# 16  {'entity.alternativeId': [{'uuid': '8f09c30f-a...
# 17  {'entity.alternativeId': [{'uuid': '6af5c532-4...
# 18  {'entity.alternativeId': [{'uuid': 'b6f74bf4-0...
# 19  {'entity.alternativeId': [{'uuid': 'acfee613-e...
#
#                                        entityTypeName entityTypeHierarchy
# 0   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 1   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 2   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 3   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 4   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 5   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 6   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 7   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 8   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 9   {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 10  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 11  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 12  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 13  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 14  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 15  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 16  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 17  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 18  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
# 19  {'nn': 'Stad', 'no': 'Sted', 'sv': 'Plats', 'f...             [Place]
