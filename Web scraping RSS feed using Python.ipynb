# %% [markdown]
# ## Web scraping RSS feed using Python
# * [article](https://medium.com/@darshipatel/web-scrapping-rss-feed-using-python-fb82370562b3)

# %%
import requests 
from bs4 import BeautifulSoup
url = "http://feeds.bbci.co.uk/news/rss.xml"

resp = requests.get(url)

soup = BeautifulSoup(resp.content, features="xml")  

print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <?xml-stylesheet title="XSL_formatting" type="text/xsl" href="/shared/bsp/xsl/rss/nolsol.xsl"?>
# <rss version="2.0" xmlns:atom="http://www.w3.org/2005/Atom" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:media="http://search.yahoo.com/mrss/">
#  <channel>
#   <title>
#    BBC News - Home
#   </title>
#   <description>
#    BBC News - Home
#   </description>
#   <link>
#    https://www.bbc.co.uk/news/
#   </link>
#
#    <url>
#     https://news.bbcimg.co.uk/nol/shared/img/bbc_news_120x60.gif
#    </url>
#    <title>
#     BBC News - Home
#    </title>
#    <link>
#     https://www.bbc.co.uk/news/
#    </link>
#
#   <generator>
#    RSS for Node
#   </generator>
#   <lastBuildDate>
#    Fri, 03 Jul 2020 19:34:35 GMT
#   </lastBuildDate>
#   <copyright>
# ...

# %%
items = soup.findAll('title')
len(items)
# Out:
# 69

# %%
item = items[1]
item
# Out:
# <title>BBC News - Home</title>

# %%
item.pubdate

# %%
news_items = []

# %%
#scarring HTML tags such as Title, Description, Links and Publication date
for item in items:
    news_item = {}
    news_item['title'] = item.title.text
    news_item['description'] = item.description.text
    news_item['link'] = item.link.text
    news_item['pubDate'] = item.pubDate.text
    news_items.append(news_item)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-1bfd2e8e3b6d> in <module>
#       2 for item in items:
#       3     news_item = {}
# ----> 4     news_item['title'] = item.title.text
#       5     news_item['description'] = item.description.text
#       6     news_item['link'] = item.link.text
#
# AttributeError: 'NoneType' object has no attribute 'text'
