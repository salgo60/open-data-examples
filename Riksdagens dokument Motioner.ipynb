# %% [markdown]
# ## Riksdagen motioner
#
# * Denna [Jupyter Notebook](https://github.com/salgo60/open-data-examples/blob/master/Riksdagens%20dokument%20Motioner.ipynb)
#   * samma men 10000 motioner och [engelska](https://github.com/salgo60/open-data-examples/blob/master/Riksdagens%20dokument%20Motioner-en.ipynb)
#   * [GITHUB Riksdagen](https://github.com/salgo60/Riksdagen)
#   * [video](https://www.youtube.com/watch?v=WaEpU0FCnK8) om Open Refine och Lagstiftande [#WikidataRiksdahge](https://www.youtube.com/hashtag/wikidatariksdagen)
# * [Skapa sökfråga](http://data.riksdagen.se/dokumentlista/)  --> 245204 Motioner
#
# * Wikipedia [WikiProject_Sweden/Swedish_Riksdag_documents](https://www.wikidata.org/wiki/Wikidata:WikiProject_Sweden/Swedish_Riksdag_documents)
#
# * [Sida med prefix](https://data.riksdagen.se/dokumentation/sa-funkar-dokument-id/#:~:text=kod%20for%20riksmote%20eller%20ar)
#
# * [Buggar Riksdagens öppna api](https://github.com/salgo60/Wikidata_riksdagen-corpus/issues/50)
#   * verkar vara en bug att man mpste ange rm för att äldre dokument skall hämtas
#
#
# ### Test H7023008 Motion 2019/20:3008 av Jonas Sjöstedt m.fl. (V)
# * [text](http://data.riksdagen.se/dokument/H7023008.text) / [html](http://data.riksdagen.se/dokument/H7023008.html) /  [json](http://data.riksdagen.se/dokumentlista/?sok=H7023008&utformat=json)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2022-10-01 14:01:19.605614

# %%
import urllib3, json
import pandas as pd  
from tqdm.notebook import trange 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

http = urllib3.PoolManager() 
pd.set_option("display.max.columns", None) 
#pd.set_option("display.max.rows", None) 
#urlbase ="http://data.riksdagen.se/dokumentlista/?sok=&doktyp=mot&utformat=json&p="
urlbase ="http://data.riksdagen.se/dokumentlista/?sok=&typ=mot&utformat=json&p="
#1990/91
urlbase ="http://data.riksdagen.se/dokumentlista/?sok=&typ=mot&utformat=json&rm=1990%2F91&p="
dftot = pd.DataFrame()
maxrun = int(245208/15)+1
#maxrun = int(5094/20)+1
maxrun = int(5000/15)
for i in trange(1,maxrun):
#for i in trange(1,10):
    url = urlbase + str(i)
    #print(url)
    r = http.request('GET', url)
    try:
        data = json.loads(r.data)
        dftot = dftot.append(pd.DataFrame(data["dokumentlista"]["dokument"]),sort=False)
    except:
        print("\tError in i=",i," can be html problem") 
dftot.head()
# Out:
#   0%|          | 0/332 [00:00<?, ?it/s]
# 	Error in i= 250  can be html problem
# 	Error in i= 251  can be html problem
# 	Error in i= 252  can be html problem
# 	Error in i= 253  can be html problem
# 	Error in i= 254  can be html problem
# 	Error in i= 255  can be html problem
# 	Error in i= 256  can be html problem
# 	Error in i= 257  can be html problem
# 	Error in i= 258  can be html problem
# 	Error in i= 259  can be html problem
# 	Error in i= 260  can be html problem
# 	Error in i= 261  can be html problem
# 	Error in i= 262  can be html problem
# 	Error in i= 263  can be html problem
# 	Error in i= 264  can be html problem
# 	Error in i= 265  can be html problem
# 	Error in i= 266  can be html problem
# 	Error in i= 267  can be html problem
# 	Error in i= 268  can be html problem
# 	Error in i= 269  can be html problem
# 	Error in i= 270  can be html problem
# 	Error in i= 271  can be html problem
# 	Error in i= 272  can be html problem
# 	Error in i= 273  can be html problem
# 	Error in i= 274  can be html problem
# 	Error in i= 275  can be html problem
# 	Error in i= 276  can be html problem
# 	Error in i= 277  can be html problem
# 	Error in i= 278  can be html problem
# 	Error in i= 279  can be html problem
# 	Error in i= 280  can be html problem
# 	Error in i= 281  can be html problem
# 	Error in i= 282  can be html problem
# 	Error in i= 283  can be html problem
# 	Error in i= 284  can be html problem
# 	Error in i= 285  can be html problem
# 	Error in i= 286  can be html problem
# 	Error in i= 287  can be html problem
# 	Error in i= 288  can be html problem
# 	Error in i= 289  can be html problem
# 	Error in i= 290  can be html problem
# 	Error in i= 291  can be html problem
# 	Error in i= 292  can be html problem
# 	Error in i= 293  can be html problem
# 	Error in i= 294  can be html problem
# 	Error in i= 295  can be html problem
# 	Error in i= 296  can be html problem
# 	Error in i= 297  can be html problem
# 	Error in i= 298  can be html problem
# 	Error in i= 299  can be html problem
# 	Error in i= 300  can be html problem
# 	Error in i= 301  can be html problem
# 	Error in i= 302  can be html problem
# 	Error in i= 303  can be html problem
# 	Error in i= 304  can be html problem
# 	Error in i= 305  can be html problem
# 	Error in i= 306  can be html problem
# 	Error in i= 307  can be html problem
# 	Error in i= 308  can be html problem
# 	Error in i= 309  can be html problem
# 	Error in i= 310  can be html problem
# 	Error in i= 311  can be html problem
# 	Error in i= 312  can be html problem
# 	Error in i= 313  can be html problem
# 	Error in i= 314  can be html problem
# 	Error in i= 315  can be html problem
# 	Error in i= 316  can be html problem
# 	Error in i= 317  can be html problem
# 	Error in i= 318  can be html problem
# 	Error in i= 319  can be html problem
# 	Error in i= 320  can be html problem
# 	Error in i= 321  can be html problem
# 	Error in i= 322  can be html problem
# 	Error in i= 323  can be html problem
# 	Error in i= 324  can be html problem
# 	Error in i= 325  can be html problem
# 	Error in i= 326  can be html problem
# 	Error in i= 327  can be html problem
# 	Error in i= 328  can be html problem
# 	Error in i= 329  can be html problem
# 	Error in i= 330  can be html problem
# 	Error in i= 331  can be html problem
# 	Error in i= 332  can be html problem
#   traff  domain  database       datum        id rdrest slutdatum rddata plats  \
# 0     1  rdwebb  dokument  1991-06-13   GE02L31   None             None
# 1     2  rdwebb  dokument  1991-06-13   GE02K98   None             None
# 2     3  rdwebb  dokument  1991-06-12  GE02Sf62   None             None
# 3     4  rdwebb  dokument  1991-06-12  GE02Sf61   None             None
# 4     5  rdwebb  dokument  1991-06-12  GE02Sf60   None             None
#
#   klockslag  publicerad          systemdatum                      undertitel  \
# 0            1991-06-13  2005-11-02 19:37:45     av Bengt Harding Olson (fp)
# 1            1991-06-13  2005-11-02 19:51:24      av Jan Bergqvist m.fl. (s)
# 2            1991-06-12  2005-11-02 19:45:06    av Maria Leissner m.fl. (fp)
# 3            1991-06-12  2005-11-02 19:44:52  av Hans Göran Franck m.fl. (s)
# 4            1991-06-12  2005-11-02 19:44:39  av Ragnhild Pohanka m.fl. (mp)
#
#      kalla                                 kall_id    dok_id dokumentformat  \
# 0  webbnav  {B27F988C-9A9B-4A7B-B6AE-4251BEFB3989}   GE02L31
# 1  webbnav  {68B187B1-6B53-4A16-9AF7-7187EC329CC9}   GE02K98
# 2  webbnav  {9A150F63-8B4A-4A31-AED1-E907A449A32D}  GE02Sf62
# 3  webbnav  {47D96459-C790-4D0B-B16D-4104E57FD4AC}  GE02Sf61
# 4  webbnav  {4E4B7C44-AE59-4E04-82F3-077B00713347}  GE02Sf60
#
#                             dokument_url_text  \
# 0   //data.riksdagen.se/dokument/GE02L31.text
# 1   //data.riksdagen.se/dokument/GE02K98.text
# 2  //data.riksdagen.se/dokument/GE02Sf62.text
# 3  //data.riksdagen.se/dokument/GE02Sf61.text
# 4  //data.riksdagen.se/dokument/GE02Sf60.text
#
#                             dokument_url_html inlamnad motionstid tilldelat  \
# 0   //data.riksdagen.se/dokument/GE02L31.html
# 1   //data.riksdagen.se/dokument/GE02K98.html
# 2  //data.riksdagen.se/dokument/GE02Sf62.html
# 3  //data.riksdagen.se/dokument/GE02Sf61.html
# 4  //data.riksdagen.se/dokument/GE02Sf60.html
#
#   lang url relurl                                              titel       rm  \
# 0                  med anledning av prop. 1990/91:194 Förverkande...  1990/91
# 1                  med anledning av prop. 1990/91:200 Statsrådens...  1990/91
# 2                  med anledning av prop. 1990/91:195 Aktiv flykt...  1990/91
# 3                  med anledning av prop. 1990/91:195 Aktiv flykt...  1990/91
# 4                  med anledning av prop. 1990/91:195 Aktiv flykt...  1990/91
#
#   organ relaterat_id doktyp  typ subtyp beteckning tempbeteckning nummer  \
# 0    LU                 mot  mot               L31            fp?     31
# 1    KU                 mot  mot               K98             s?     98
# 2   SfU                 mot  mot              Sf62            fp?     62
# 3   SfU                 mot  mot              Sf61             s?     61
# 4   SfU                 mot  mot              Sf60            mp?     60
#
#   status score                                            sokdata  \
# 0           72  {'titel': 'med anledning av prop. 1990/91:194 ...
# 1           72  {'titel': 'med anledning av prop. 1990/91:200 ...
# 2           72  {'titel': 'med anledning av prop. 1990/91:195 ...
# 3           72  {'titel': 'med anledning av prop. 1990/91:195 ...
# 4           72  {'titel': 'med anledning av prop. 1990/91:195 ...
#
#                                              summary  \
# 0  Motion till riksdagen\n 1990/91:L31\n av Bengt...
# 1  Motion till riksdagen\n 1990/91:K98\n av Jan B...
# 2  Motion till riksdagen\n 1990/91:Sf62\n av Mari...
# 3  Motion till riksdagen\n 1990/91:Sf61\n av Hans...
# 4  Motion till riksdagen\n 1990/91:Sf60\n av Ragn...
#
#                                          notisrubrik  \
# 0  med anledning av prop. 1990/91:194 Förverkande...
# 1  med anledning av prop. 1990/91:200 Statsrådens...
# 2  med anledning av prop. 1990/91:195 Aktiv flykt...
# 3  med anledning av prop. 1990/91:195 Aktiv flykt...
# 4  med anledning av prop. 1990/91:195 Aktiv flykt...
#
#                                                notis  \
# 0  Motion till riksdagen\n 1990/91:L31\n av Bengt...
# 1  Motion till riksdagen\n 1990/91:K98\n av Jan B...
# 2  Motion till riksdagen\n 1990/91:Sf62\n av Mari...
# 3  Motion till riksdagen\n 1990/91:Sf61\n av Hans...
# 4  Motion till riksdagen\n 1990/91:Sf60\n av Ragn...
#
#                                        dokintressent filbilaga avdelning  \
# 0  {'intressent': [{'roll': 'undertecknare', 'nam...      None  dokument
# 1  {'intressent': [{'roll': 'undertecknare', 'nam...      None  dokument
# 2  {'intressent': [{'roll': 'undertecknare', 'nam...      None  dokument
# 3  {'intressent': [{'roll': 'undertecknare', 'nam...      None  dokument
# 4  {'intressent': [{'roll': 'undertecknare', 'nam...      None  dokument
#
#   struktur audio video debattgrupp debattdag beslutsdag beredningsdag  \
# 0
# 1
# 2
# 3
# 4
#
#   justeringsdag beslutad debattsekunder ardometyp reservationer debatt  \
# 0                                                                 None
# 1                                                                 None
# 2                                                                 None
# 3                                                                 None
# 4                                                                 None
#
#   debattnamn dokumentnamn
# 0     Motion       Motion
# 1     Motion       Motion
# 2     Motion       Motion
# 3     Motion       Motion
# 4     Motion       Motion

# %%
dftot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4976 entries, 0 to 15
# Data columns (total 59 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   traff              4976 non-null   object
#  1   domain             4976 non-null   object
#  2   database           4976 non-null   object
#  3   datum              4976 non-null   object
#  4   id                 4976 non-null   object
#  5   rdrest             0 non-null      object
#  6   slutdatum          4976 non-null   object
#  7   rddata             0 non-null      object
#  8   plats              4976 non-null   object
#  9   klockslag          4976 non-null   object
#  10  publicerad         4976 non-null   object
#  11  systemdatum        4976 non-null   object
#  12  undertitel         4976 non-null   object
#  13  kalla              4976 non-null   object
#  14  kall_id            4976 non-null   object
#  15  dok_id             4976 non-null   object
#  16  dokumentformat     4976 non-null   object
#  17  dokument_url_text  4976 non-null   object
#  18  dokument_url_html  4976 non-null   object
#  19  inlamnad           4976 non-null   object
#  20  motionstid         4976 non-null   object
#  21  tilldelat          4976 non-null   object
#  22  lang               4976 non-null   object
#  23  url                4976 non-null   object
#  24  relurl             4976 non-null   object
#  25  titel              4976 non-null   object
#  26  rm                 4976 non-null   object
#  27  organ              4976 non-null   object
#  28  relaterat_id       4976 non-null   object
#  29  doktyp             4976 non-null   object
#  30  typ                4976 non-null   object
#  31  subtyp             4976 non-null   object
#  32  beteckning         4976 non-null   object
#  33  tempbeteckning     4976 non-null   object
#  34  nummer             4976 non-null   object
#  35  status             4976 non-null   object
#  36  score              4976 non-null   object
#  37  sokdata            4976 non-null   object
#  38  summary            4976 non-null   object
#  39  notisrubrik        4976 non-null   object
#  40  notis              4976 non-null   object
#  41  dokintressent      4974 non-null   object
#  42  filbilaga          0 non-null      object
#  43  avdelning          4976 non-null   object
#  44  struktur           4976 non-null   object
#  45  audio              4976 non-null   object
#  46  video              4976 non-null   object
#  47  debattgrupp        4976 non-null   object
#  48  debattdag          4976 non-null   object
#  49  beslutsdag         4976 non-null   object
#  50  beredningsdag      4976 non-null   object
#  51  justeringsdag      4976 non-null   object
#  52  beslutad           4976 non-null   object
#  53  debattsekunder     4976 non-null   object
#  54  ardometyp          4976 non-null   object
#  55  reservationer      4976 non-null   object
#  56  debatt             0 non-null      object
#  57  debattnamn         4976 non-null   object
#  58  dokumentnamn       4976 non-null   object
# dtypes: object(59)
# memory usage: 2.3+ MB

# %%
pd.set_option("display.max.rows", None) 
#dftot

# %%
#dftot.id.value_counts()

# %%
#dftot.dok_id.value_counts()

# %%
#dftot[['nummer','titel','publicerad','beslutad','datum','summary']]

# %%
#dftot.publicerad.unique()

# %%
#dftot.publicerad.value_counts()

# %%
#matplotlib inline  
#import matplotlib.pyplot as plt   
#plot = dftot.publicerad.value_counts()[1:30].plot.bar(y='counts', figsize=(25, 5)) 
#plt.show()

# %%
organCount = dftot.organ.value_counts() 
organCount
# Out:
# UbU    594
# JoU    520
# TU     467
# SoU    414
# SkU    384
# NU     373
# AU     321
# SfU    300
# KU     273
# UU     227
# BoU    226
# KrU    217
# JuU    204
# FiU    195
# LU     179
# FöU     82
# Name: organ, dtype: int64

# %%
dftot.undertitel.value_counts()[1:50]
# Out:
# av Bengt Westerberg m.fl. (fp)                    112
# av Inger Schörling m.fl. (mp)                     106
# av Claes Roxbergh m.fl. (mp)                       76
# av Olof Johansson m.fl. (c)                        68
# av Carl Bildt m.fl. (m)                            65
# av Sten Svensson m.fl. (m)                         38
# av Annika Åhnberg m.fl. (v)                        38
# av Eva Goës m.fl. (mp)                             36
# av Bo Lundgren m.fl. (m)                           29
# av Ann-Cathrine Haglund m.fl. (m)                  27
# av Anita Stenberg m.fl. (mp)                       27
# av Bengt Harding Olson (fp)                        27
# av Roy Ottosson m.fl. (mp)                         26
# av Agne Hansson m.fl. (c)                          25
# av Rolf Dahlberg m.fl. (m)                         24
# av Sven Eric Lorentzon m.fl. (m)                   24
# av Ragnhild Pohanka m.fl. (mp)                     24
# av Sonja Rembo m.fl. (m)                           23
# av Hans Göran Franck m.fl. (s)                     23
# av Ylva Annerstedt m.fl. (fp)                      22
# av Gullan Lindblad m.fl. (m)                       21
# av Gösta Lyngå m.fl. (mp)                          21
# av Daniel Tarschys m.fl. (fp)                      20
# av Ylva Annerstedt (fp)                            20
# av Ulla Orring (fp)                                19
# av Karl Erik Olsson m.fl. (c)                      18
# av Börje Hörnlund (c)                              18
# av Charlotte Cederschiöld (m)                      18
# av Görel Thurdin m.fl. (c)                         18
# av Lars Norberg m.fl. (mp)                         18
# av Martin Olsson (c)                               17
# av Karin Israelsson (c)                            17
# av Knut Billing m.fl. (m)                          17
# av Gunhild Bolander (c)                            17
# av Karin Israelsson m.fl. (c)                      17
# av Carl Frick (mp)                                 17
# av Agne Hansson och Marianne Jönsson (c)           17
# av Allan Ekström (m)                               17
# av Ivar Virgin (m)                                 17
# av Kurt Ove Johansson och Lars-Erik Lövdén (s)     17
# av Göran Ericsson (m)                              16
# av Tom Heyman (m)                                  16
# av Bertil Måbrink m.fl. (v)                        16
# av Sven-Olof Petersson (c)                         16
# av Mona Saint Cyr (m)                              16
# av Roland Sundgren m.fl. (s)                       16
# av Stina Eliasson (c)                              15
# av Barbro Sandberg (fp)                            15
# av Börje Hörnlund m.fl. (c)                        15
# Name: undertitel, dtype: int64

# %%
dftot.subtyp.value_counts()
# Out:
#     4976
# Name: subtyp, dtype: int64

# %%
dftot.doktyp.value_counts()
# Out:
# mot    4976
# Name: doktyp, dtype: int64

# %%
dftot.typ.value_counts()
# Out:
# mot    4976
# Name: typ, dtype: int64

# %%
dftot.rm.value_counts()
# Out:
# 1990/91    4976
# Name: rm, dtype: int64

# %%
dftot.status.value_counts()
# Out:
#     4976
# Name: status, dtype: int64

# %%
#dftot.beteckning.value_counts()

# %%
#dftot.tempbeteckning.value_counts()

# %%
dftot.rm.value_counts()
# Out:
# 1990/91    4976
# Name: rm, dtype: int64

# %%
dftot.score.value_counts()
# Out:
# 72    4976
# Name: score, dtype: int64

# %%
#dftot.sokdata.value_counts()

# %%
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
#sns.heatmap(dftot.isnull(), 
#            yticklabels=False, 
#            cbar=False, 
#            cmap='viridis')

# %%
#plt.show()

# %% [markdown]
# ## Lagstiftande utskott
#
# Fält **organ**

# %%
dftot.organ.unique()
# Out:
# array(['LU', 'KU', 'SfU', 'NU', 'UbU', 'JoU', 'BoU', 'FiU', 'SoU', 'UU',
#        'FöU', 'AU', 'SkU', 'TU', 'JuU', 'KrU'], dtype=object)

# %%
dftot[['id','organ']].head()
# Out:
#          id organ
# 0   GE02L31    LU
# 1   GE02K98    KU
# 2  GE02Sf62   SfU
# 3  GE02Sf61   SfU
# 4  GE02Sf60   SfU

# %%
dftot[['id','organ']].to_csv("Lagstiftande.csv")

# %%
dftot.organ.value_counts()
# Out:
# UbU    594
# JoU    520
# TU     467
# SoU    414
# SkU    384
# NU     373
# AU     321
# SfU    300
# KU     273
# UU     227
# BoU    226
# KrU    217
# JuU    204
# FiU    195
# LU     179
# FöU     82
# Name: organ, dtype: int64

# %%
dftot.value_counts(["organ","rm"])
# Out:
# organ  rm
# UbU    1990/91    594
# JoU    1990/91    520
# TU     1990/91    467
# SoU    1990/91    414
# SkU    1990/91    384
# NU     1990/91    373
# AU     1990/91    321
# SfU    1990/91    300
# KU     1990/91    273
# UU     1990/91    227
# BoU    1990/91    226
# KrU    1990/91    217
# JuU    1990/91    204
# FiU    1990/91    195
# LU     1990/91    179
# FöU    1990/91     82
# dtype: int64

# %%
dftotCounts = dftot.value_counts(["organ","rm"])
dftotCounts.to_csv("Value_counts_organ_rm.csv")

# %%
dftot.value_counts(["rm"])
# Out:
# rm
# 1990/91    4976
# dtype: int64

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2022-10-01 14:01:53.432787
# Time elapsed (hh:mm:ss.ms) 0:00:33.827549

# %%
# GE02Bo518
dftot[dftot["id"] == "GE02Bo518"]
# Out:
#   traff  domain  database       datum         id rdrest slutdatum rddata  \
# 0  1481  rdwebb  dokument  1991-01-25  GE02Bo518   None             None
#
#   plats klockslag  publicerad          systemdatum               undertitel  \
# 0                  1991-01-25  2005-11-02 21:00:44  av Inger Schörling (mp)
#
#      kalla                                 kall_id     dok_id dokumentformat  \
# 0  webbnav  {2D3746DD-27D9-4CA9-A219-26C46659BFAA}  GE02Bo518
#
#                              dokument_url_text  \
# 0  //data.riksdagen.se/dokument/GE02Bo518.text
#
#                              dokument_url_html inlamnad motionstid tilldelat  \
# 0  //data.riksdagen.se/dokument/GE02Bo518.html
#
#   lang url relurl             titel       rm organ relaterat_id doktyp  typ  \
# 0                  Naturresurslagen  1990/91   BoU                 mot  mot
#
#   subtyp beteckning tempbeteckning nummer status score  \
# 0             Bo518            mp?    518           72
#
#                                              sokdata  \
# 0  {'titel': 'Naturresurslagen', 'undertitel': 'M...
#
#                                              summary       notisrubrik  \
# 0  Motion till riksdagen\n 1990/91:Bo518\n av Ing...  Naturresurslagen
#
#                                                notis  \
# 0  Motion till riksdagen\n 1990/91:Bo518\n av Ing...
#
#                                        dokintressent filbilaga avdelning  \
# 0  {'intressent': [{'roll': 'undertecknare', 'nam...      None  dokument
#
#   struktur audio video debattgrupp debattdag beslutsdag beredningsdag  \
# 0
#
#   justeringsdag beslutad debattsekunder ardometyp reservationer debatt  \
# 0                                                                 None
#
#   debattnamn dokumentnamn
# 0     Motion       Motion
