# %% [markdown]
# ## Skolmaten - Open-Meal
# * den här [Notebook](https://github.com/salgo60/open-data-examples/blob/master/Skolmat.se%20API.ipynb) version 2.2
#
#
# Enl. [dataportal.se identifierare ifrån RDF](https://community.dataportal.se/topic/368/dataportal-ses-identifierare-ifr%C3%A5n-rdf)
# * finns ett API för [skolmat.se](https://skolmaten.se/) på [skolmaten about](https://skolmaten.se/about/api)
# * via API:et kan skolor hämtas med [openmeal/v2/distributors.json](https://skolmaten.se/api/openmeal/v2/distributors.json)
#   * finns GITHUB [Samburk/Open-Meal](https://github.com/Sambruk/Open-Meal) och [orebrokommun/Open-Meal-Information](https://github.com/orebrokommun/Open-Meal-Information/)(senast uppdaterad för [6 år sedan](https://github.com/Orebrokommun/Open-Meal-Information/commit/4fa521c07fa41e9b43cd87c03ece905643bebf14))
# * dataportal.se diskuterar även vilka kategorier som skall anges på datat [länk](https://community.dataportal.se/topic/364/kategorier-av-%C3%B6ppna-data/10)
#   * för skolmaten finns lite spretiga specar kanske redan i dessa specar bör det finnas vilka kategorier man pekar på detta data från svenska dataportalen/ europiska dataportalen
#     * mer proffsigt vore att detta var data i en kunskapsgraf ung. som Wikidata skapats för att dela WIkipedia se [video](https://www.youtube.com/watch?v=m_9_23jXPoE)
# * massa statliga pengar/resurser har lagts på detta [Vinnova projekt 2015](https://youtu.be/JEc6vuys17c?t=1314) och nu 7 år senare [NSÖD projektet](https://community.dataportal.se/topic/169/projektet-ns%C3%B6d-nationell-skalning-%C3%B6ppna-data?_=1655102286079) dock är denna resa dåligt dokumenterad?!?!? jag hittar inte användarfall (vore bra [stories som denna](https://github.com/christerresin/thetable/issues/18)), projektyta osv. det [som sägs](https://sambruk.github.io/Open-Meal/docs/background#tag/Meal/paths/~1meals/get)
#
# > The goal was to create an open specification that could be used by all suppliers of systems for planning meals and delivering menus and to keep it as small as possible as to not create unnecessary overhead for suppliers. The project delivered a specification for delivering the content as JSON and another as iCalendar for use with electronic calendars.
#
# > One motivation for this project was to create a proof-of-concept for solving one of the problems identified by the national coordination of municipal open data headed by SKR (an organisation for cooperation run by the municipalities) namely that open data published by 290 municipalities in 290 different ways will be very hard to reuse. Since the value of open data is realized in the reuse this aspect is critical in achieving the desired effects (new and better services and transparency in government).
#
#   * [Dopter](http://dopter.se/) var inblandade 2015
#     * [Anders Krohn](https://www.linkedin.com/in/andreaskrohn) - github []()
#     * [Gustaf Rosenblad](https://www.linkedin.com/in/gustaf-rosenblad) - github [](https://github.com/rosecoder)
#
# >   The project ran from november 2014 thru june 2015 and involved the municipality och Örebro with Björn Hagström as project lead, Dopter AB represented by Andreas Krohn and Mashie AB, the supplier och the system for planing meals at the municipality, represented by Erik Arnwald and Jörgen Brandt.
#
#
#   * verkar som [Matilda Foodtech](https://www.matildafoodtech.com) och IST?!?! jobbar med detta nu ([GITHUB changes](https://github.com/Sambruk/Open-Meal/commits))
#      * [Rickard Svensson](https://www.linkedin.com/in/rickardsvenssonlund/) github [ricsv](https://github.com/ricsv)
#      * [Jimmy Revtorp](https://www.linkedin.com/in/jimmy-revtorp-7635a758) - github [Lonestarrk](https://github.com/Lonestarrk)
#
# >  No work was done on the specification until the Swedish project NSÖD (a national project helping municipalities and regions to publish open data in standardized formats). NSÖD created a new version of the specification (3.0) and worked together with Matilda FoodTech and IST to further improve the specification. Soon version 3.1, 3.2 and 3.3 were released with improvements like more structured ingredient- and nutritional information.
#
# ## Misc
# * **relaterat projekt med större visioner** [Utforma framtidens hållbara skolmåltidssystem!](https://www.vinnova.se/e/hallbart-matsystem/utforma-framtidens-hallbara-skolmaltidssystem/) - 7 miljarder kostar skolmaten per år --> [vi skall skapa hållbart skolmatssystem](https://www.livsmedelsverket.se/ettnyttrecept)
#   * ["Ett nytt recept för skolmåltider – hur blir hela matsystemet hållbart?"](https://www.livsmedelsverket.se/ettnyttrecept)
#
#    ![](https://blogger.googleusercontent.com/img/a/AVvXsEhqmzRkP5gSjsXnzJg_cu0BDNq9oYu9VYkFB_QUGxVHnhkaovpgdydJHWQqBkppCEnOBtIscYROolwG6lpAIILkPerMhCUkHSgxAHPxAsDWhsSOQARetuv4qbsZBW9nvS8YtbIdFdmyM_6dkRYVt_vnf3LiDfrIgN8ptnbA7Bj2agny3NJQ1OZVb7qGNw=w426-h241)
#
#      * [Systemkarta](https://www.livsmedelsverket.se/globalassets/matvanor-halsa-miljo/maltider-vard-skola-omsorg/skola/systemkarta_ett-nytt-recept-pa-skolmaltider_2020.pdf) / [fas 1](https://www.livsmedelsverket.se/globalassets/matvanor-halsa-miljo/maltider-vard-skola-omsorg/skola/sammanstallning-fas-1_ett-nytt-recept-for-skolmaltider_2020.pdf)
#
#      ![](https://blogger.googleusercontent.com/img/a/AVvXsEjTxo_p1uQS1Vli8Cy8WppYCl_E_t0PKMqzEtMz1yjcJJiz2TuhGmoX97w-_auQ2HRFlAB63SPqY81QL7H0fg7y6VhJra-to0ey_vmtOXiXQFOtGqQixadhKhmlVhFBO21btL5Igg_T1q3MipN9Z_ioi-in_xiDfQYRR55cKQ_t8SXDrhqxpZE2rfFtAQ=w634-h347)
#
#      <div>
# <img src="https://media-exp2.licdn.com/dms/image/C4E22AQHh8J3g_sohDg/feedshare-shrink_1280/0/1653758907458?e=1657756800&v=beta&t=v63-DkCkbzkdFpIHgz4oJXBEoXfj6fYNGOeC1x8AqTc" width="200"/>
# </div>
#
# >> Projektet är en del i en större satsning kring mat och hållbarhet som ska öka olika aktörers förmåga att bidra till de globala hållbarhetsmålen Agenda 2030
#   * [8 oktober 2021](https://www.livsmedelsverket.se/matvanor-halsa--miljo/maltider-i-vard-skola-och-omsorg/skola/hallbart-skolmaltidssystem/projektets-arbetsmetoder) ordnade Vinnova och Livsmedelsverket ett webbinarium om det pågående arbetet i projektet Ett nytt recept för skolmåltider
#   * projektledare Livsmedelsverket [Elin Sandström](https://www.linkedin.com/in/elin-sandstr%C3%B6m-710aa84a)
# * [Nationella riktlinjer för måltider i skolan](https://www.livsmedelsverket.se/globalassets/publikationsdatabas/broschyrer-foldrar/riktlinjer-for-maltider-i-skolan.pdf)
#   * vore proffsigt om serverad måltid kunde kopplas tillbaka till dessa riktlinjer men även [Agenda 2030](https://fn.se/vi-gor/vi-stodjer-viktiga-fn-projekt-i-varlden/skolmat/skolmatsprojektet/#:~:text=Skolmat%20minskar%20oj%C3%A4mlikhet%20och%20m%C3%B6jligg%C3%B6r%20h%C3%A5llbar%20utveckling&text=Skolmaten%20m%C3%B6jligg%C3%B6r%20f%C3%B6r%20familjerna%20att,m%C3%A5nga%20barn%20har%20brist%20p%C3%A5.)
#
# * [Long-Term Effects of Childhood Nutrition: Evidence from a School Lunch Reform](https://academic.oup.com/restud/article/89/2/876/6273674) DOI [10.1093/restud/rdab028](https://doi.org/10.1093/restud/rdab028)
#
# * [Äta bör man | Vårt ohållbara ätande (5 juni 2021)](https://www.youtube.com/watch?v=LtCczQMtpA4) - samtal på Järvaveckan
#
# * [SchoolFood4Change](https://www.wwf.se/mat-och-jordbruk/projekt/schoolfood4change/) / projektledare [Ulrika Backlund](https://www.linkedin.com/in/ulrikabacklund)
#   * Appar [matguiden](https://www.wwf.se/mat-och-jordbruk/matguiden/)/ [matkalkylator](https://www.wwf.se/mat-och-jordbruk/matkalkylator/)
#
# > är ett EU-finansierat projekt där WWF tillsammans med flera samarbetspartners arbetar för att skapa mer hållbara skolmåltider och matsystem som främjar både miljön och hälsan. Skolor har stor potential att visa och engagera unga för en mer hållbar livsstil kopplat till sina matval. Projektet är en del av EU-programmet Horizon 2020 och startade januari 2022.
# <div>
# <img src="https://blogger.googleusercontent.com/img/a/AVvXsEjmEs5foxFDaKW4mXswM0Mh5C3LPdCF-rLhWblR4WdYddSu4ieLwoXqeDLHHq6Up0AMjBe-FGf-NR8l_i7Z03jv8OVjO34IiMOJ1KZRe_SgENLyxZ2m_Nzdl-ZN9RVPZV8ef4qIf9NKy-1_egw_P4g08NMovvn0gtAtFwVM-wF23nZzXYcAEnKuBYlmwg=w615-h233" width="600"/>
# </div>
#
# ### Skolmaten - dataportalen: Massa poster som pekar på ett API
# känns enormt geggigt med vissa kommuner laddar upp ett "dataset" på [portalen](https://www.dataportal.se/datasets?p=1&q=skolmat&s=2&t=20&f=&rt=dataset%24esterms_IndependentDataService%24esterms_ServedByDataService&c=false) och alla verkar peka på samma API för skolmat, i de olika portalerna finns ingen konsekvent id för detta API utan varje kommun i detta API som skapar en post i portalen skapar en ny egen identifierare verkar det som.... när man för en gångs skull har något gemensamt som är enkelt att konsumera så lyckas man ändå skapa denna röra... denna "det blir som det blir" mentalitet funkar inte någon bör peka med rakhand... plus enormt slöseri med resurser att "meningslösa" dataset skall administreras... där saker skall maskinöversättas, alla sätter "egna kategorier" känns som någon borde gå tillbaka till ritbordet...
# * dataportalen "[Skolmaten i Lund](https://www.dataportal.se/datasets/233_9780/skolmaten-i-lunds-kommun#ref=?p=1&q=skolmat%20Lund&s=2&t=20&f=&rt=dataset%24esterms_IndependentDataService%24esterms_ServedByDataService&c=false)" -> metadata **[233_9780](https://admin.dataportal.se/store/233/metadata/9780?recursive=dcat)**
#   * data.europa.eu "[School meals in the City of Lund](https://data.europa.eu/data/datasets/https-katalog-lund-se-store-1-resource-9?locale=en)
#     * datasettet har kategorierna:
#        * [Skolmat](https://data.europa.eu/data/datasets?keywords=skolmat&locale=en) --> 4 datasets
#        * [School meal](https://data.europa.eu/data/datasets?keywords=school-meals&locale=en) --> 1 dataset
#        * [City of Lund](https://data.europa.eu/data/datasets?keywords=city-of-lund&locale=en) --> 7 datasets
# * dataportalen "[Skolmatsmenyer för Ale kommuns skolor](https://www.dataportal.se/datasets/446_2244)" -> metadata **[446_2244](https://admin.dataportal.se/store/446/metadata/2244?recursive=dcat)**
#   * data.europa.eu "[School food menus for Ale municipality schools](https://data.europa.eu/data/datasets/https-catalog-ale-se-store-1-resource-55?locale=en)" pekar på samma API saknar kategorier och är maskinöversatt...
# * dataportalen "[Skolmatsmenyer för Mariestads kommuns skolor](https://www.dataportal.se/datasets/506_1661) -> metadata **[506_1661](https://admin.dataportal.se/store/506/metadata/1661?recursive=dcat)**
#   * data.europa.eu "[School restaurant menu for the municipality of Mariestad](https://data.europa.eu/data/datasets/https-catalog-mariestad-se-store-1-resource-15?locale=en)" pekar på samma API men saknar kategorier finns dock engelsk metadata i svenska portalen se [506_1661](https://admin.dataportal.se/store/506/metadata/1661?recursive=dcat)
# * dataportalen "[Skolmaten på Lidingö](https://www.dataportal.se/datasets/238_35328)" -> metadata **[238_35328](https://admin.dataportal.se/store/238/metadata/35328?recursive=dcat)**
#   * data.europa.eu "[Skolmaten på Lidingö](https://data.europa.eu/data/datasets/https-lidingo-entryscape-net-store-1-resource-72?locale=en)" pekar på samma API men finns bara med svenskt namn och har bara kategorin "[lidingo-city-in-sweden](https://data.europa.eu/data/datasets?keywords=lidingo-city-in-sweden&locale=en)"
# * dataportalen "[Skolmat i Skövde kommun](https://www.dataportal.se/datasets/286_4451)" -> metadata **[286_4451](https://admin.dataportal.se/store/286/metadata/4451?recursive=dcat)**
#   * data.europa.eu "[School meals in Skövde municipality](https://data.europa.eu/data/datasets/https-skovde-entryscape-net-store-1-resource-10?locale=en) pekar på samma API men skrivit ihop kategorierna **[skolmat,-mat,-meny](https://data.europa.eu/data/datasets?keywords=skolmat,-mat,-meny&locale=en)**
#     * keyword felet kommer från [metadatat på svenska portalen](https://admin.dataportal.se/store/238/metadata/35328?recursive=dcat) - kanske saknas kontrollmekanismer?!?!?
#
# >> <dcat:keyword xml:lang="sv">skolmat, mat, meny</dcat:keyword>
# >> <dcat:keyword xml:lang="en">school meals, food, menu</dcat:keyword>
#
# * dataportalen "[Skolmaten - Södertälje](https://www.dataportal.se/datasets/75_1264/skolmaten#ref=?p=1&q=skolmat&s=2&t=20&f=&rt=dataset%24esterms_IndependentDataService%24esterms_ServedByDataService&c=false)" -> metadata **[75_1264](https://admin.dataportal.se/store/75/metadata/1264?recursive=dcat)**
#   * data.europa.eu "[School food](https://data.europa.eu/data/datasets/https-catalog-sodertalje-se-store-1-resource-161?locale=en)" massa kategorier
#
# * dataportalen "[Skolmat - Linköpings kommun](https://www.dataportal.se/datasets/389_1039/skolmat#ref=?p=1&q=skolmat&s=2&t=20&f=&rt=dataset%24esterms_IndependentDataService%24esterms_ServedByDataService&c=false)" --> metadata **[389_1039](https://admin.dataportal.se/store/389/metadata/1039?recursive=dcat)**
#   * data.europa.eu "[Skolmat](https://data.europa.eu/data/datasets/https-linkoping-entryscape-net-store-1-resource-28?locale=en)" verkar vara Linköpings kommun
# * finns säkert fler som jag missat.... 😅
#
# **Fundering på www.dataportal.se och skolmatsdatat**
# 1. enkel koppling Europeiska dataportalen till den svenska portalen finns det för samma dataset?
#   1. borde vara i dct:identifier men den pekar även till portalen innan svenska dataportalen se Lund [233_9780](https://data.europa.eu/api/hub/repo/distributions/1d1c2a43-0099-449c-9ae5-71568a4c12b0.rdf) som i EU portalen pekar på https://katalog.lund.se/store/1/resource/11 dvs. tillbaka till Lund jmf svenska portalens metadata [233_9780](https://admin.dataportal.se/store/233/metadata/9780?recursive=dcat)
#      1. om det är ETT API varför hitta på nya identifierare?!?!? kanske **samma som** behövs
# 1. unikt id finns i svenska portalen men man borde ha [DOI](https://www.youtube.com/watch?v=ekn0qicVFJM) så man fattar att det är samma data i 2 olika portaler jag tog upp det 2020 men fick [ingen feedback](https://github.com/DIGGSweden/DCAT-AP-SE/issues/72#issuecomment-653731898)
#   udda att Europeiska dataportalen har **Cite this dataset** --> Lunds kommun, ‘School meals in the City of Lund’, accessed 2022-06-10, http://data.europa.eu/88u/dataset/https-katalog-lund-se-store-1-resource-9 dvs. pekar på sig själva... måste finnas något land som tänkt på detta?!?!?!
#   1. borde vara samma id både i svenska som Europeiska portalen annars blir det svårt att som Google AI kallar "[Connecting Replicas of Datasets](https://ai.googleblog.com/2018/09/building-google-dataset-search-and.html#:~:text=Connecting%20Replicas%20of%20Datasets)"
# 1. ett API borde räcka med en post i dataportalen, nu finns 281 kommuner i detta API men bara en handfull har skapat post i portalen....
# 1. ingen styrning finns att detta enstaka API får samma kategorier i dataportalen se även [diskussion om kategorier](https://github.com/DIGGSweden/DCAT-AP-SE/issues/86) där man vill ha flera kategorier... känns som i detta exempel så är det styrning/kvalitetssäkring som saknas
#   1. Jag skulle kalla detta kaos [#metadatadebt](https://twitter.com/salgo60/status/1237262589341687809?s=20&t=qYCj7VZ0jpQW0sYDv9gVsg) ingen är vinnare...
#   1. Borde man inte i den svenska portalen kunna ange engelska kategorier så det blir rätt på EU nivå... och/eller att alla kategorier finns på minst svenska/engelska
# 1. **Skolenheter identifieras** av Skolverket(enl. [SFS 2010:800](https://www.riksdagen.se/sv/dokument-lagar/dokument/svensk-forfattningssamling/skollag-2010800_sfs-2010-800)) och SCB med [skolenheter i skolenhetsregistret](https://www.scb.se/lamna-uppgifter/undersokningar/Skolenhetsregistret/)
#   1. i Wikidata har vi ett projekt där vi försöker identifiera **alla skolor som någonsin har funnits i Sverige** dvs. idag har vi alla skolor i skolenhetsregistret med unika Wikidata Qnummer se [Wikidata:WikiProject_Sweden/Schools](https://www.wikidata.org/wiki/Wikidata:WikiProject_Sweden/Schools)
#   1. Exempel Öxnered skola
#      1. Skolregistret har skolenhetskod [68637661](https://api.scb.se/UF0109/v2/skolenhetsregister/sv/skolenhet/68637661)
#         1. beskrivning av [SCB när nya skolenhetskoder skapas](https://www.scb.se/contentassets/6a9472ed9e474943bac8a30391b0ceb1/nar-ska-forandringar-av-skolenheter-leda-till-ny-skolenhetskod.pdf)
#      1. Wikidata har skolenheten = [Q89198196](https://www.wikidata.org/wiki/Q89198196?uselang=sv) som är en del av grundskolan = WD [Q89904732](https://www.wikidata.org/wiki/Q89904732?uselang=sv) Öxnered skola
#    1. Borde på svenska dataportalen att gå att söka ut vilka dataset som är kopplade till en skolenhet!!!
#    1. Förslag till [github.com/Sambruk/Open-Meal](https://github.com/Sambruk/Open-Meal/issues/14) med **[owl:sameAs](https://www.w3.org/TR/owl-ref/#sameAs-def)** som skall peka på skolenhetskoden
#
# >   [SFS 2010:800](https://www.riksdagen.se/sv/dokument-lagar/dokument/svensk-forfattningssamling/skollag-2010800_sfs-2010-800) **skolenhet**: av huvudman för annan skolform än förskola organiserad enhet som omfattar verksamhet i en eller flera skolbyggnader som ligger nära varandra och till enheten knuten verksamhet som inte bedrivs i någon skolbyggnad,
# 1. Maträtter verkar skickas runt som textsträngar dvs. man kan inte analysera maträtterna med avseende på näringsinnehåll, vad en skattekrona ger för typ av mat, matsvinn vs. typ av mat som serveras eller om det har med skolan att göra, går ej heller knyta en bild till maten eller skapa ett bildbibliotek med skolmat.... det pratades Sep 23, 2021 om att [Öppna skolplattformen ville ha bild](https://twitter.com/Landgren/status/1440975114200305665?s=20&t=29rZhe6Xxxx4DyrpPALQLw) på maten med NSÖD projektet på [twitter](https://twitter.com/Landgren/status/1446155666117304330?s=20&t=L4s0-FwJw84klDiDm8171Q) men svårt att veta om det blev något har inte hittat NSÖD dokumentation/spec som förklarar vad som gjorts även en brist på en projektyta där NSÖD samplar feedback är svår att hitta.... det som hittats....
#   1. GITHUB som inte säger mer https://sambruk.github.io/Open-Meal/docs/background
#      1. en [3.3 spec utan datum](https://sambruk.github.io/Open-Meal/openapi-specification) / [swagger.io](https://editor.swagger.io/?url=https://raw.githubusercontent.com/Sambruk/Open-Meal/main/OpenAPI%20Specification.json)
#         1. ett [exempel hittas](https://sambruk.github.io/Open-Meal/openapi-specification) men inte hittat dokumentation
#           1. nytt 3.3 gissar jag är ( se exempel nedan)
#              1. en textsträng med "ingredients" där ingridienserna är på engelska och separerade med komma
#              1. en array med "allergens" där allergenerna är textsträngar på engelska utan "samma som"
#              1. i exemplet finns "nutrients" men inget bra exempel hur man tänkt.... gissar man hamnat i en återvändsgränd med alla textsträngar....
#           1.
#      1. en [versions historik](https://sambruk.github.io/Open-Meal/docs/API/version_history) utan datum men med skillnad av senaste spec och Örebro 2015...
#   1. bra att man pekar på att geo koordinaterna skall vara [WGS84](https://sv.wikipedia.org/wiki/World_Geodetic_System_1984) ibland anges det som [epsg:4326](https://epsg.io/4326) se [Wikipedia](https://en.wikipedia.org/wiki/EPSG_Geodetic_Parameter_Dataset) vilket kanske kan vara tydligare....
#   1. NSÖD slutrapport sida 11 [länk](http://ri.diva-portal.org/smash/get/diva2:1654808/FULLTEXT01.pdf) där det vagt skrivs "___Stöd för specifikationen är inte helt implementerat i leverantörernas system på grund av att vi genom leverantörernas intresse tagit fram ytterligare en version av specifikationen under projektet___" vilken version av spec och var den finns/ innebär förtäljer inte detta hemliga projekt....
#   1. på [Facebook sägs april 27 2020](https://www.facebook.com/groups/openmealinformation/posts/2710894565798755/) att en spec skall presenteras inga tydliga länkar var... klickar man runt hamnar man på [orebrokommun.github.io/Open-Meal-Information](https://orebrokommun.github.io/Open-Meal-Information/swe/historien-bakom-mltidsdata.html)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2022-06-10 12:56:03.338723

# %%
import urllib3, json
import pandas as pd 
http = urllib3.PoolManager() 
pd.set_option("display.max.columns", None) 
urldistskolmat = "https://skolmaten.se/api/openmeal/v2/distributors.json"
r = http.request('GET', urldistskolmat)
try:
    data = json.loads(r.data)
    dfdist = pd.json_normalize(data["data"])
except Exception as e: print(e)

# %%
dfdist
# Out:
#      lang     distributorID  \
# 0      sv         321057002
# 1      sv  5225692681732096
# 2      sv          65637002
# 3      sv         392217004
# 4      sv          67497002
# ...   ...               ...
# 5499   sv  6501524796604416
# 5500   sv         292877002
# 5501   sv         328387002
# 5502   sv  6234450308366336
# 5503   sv  5236175891595264
#
#                                               iCalendar  \
# 0     https://skolmaten.se/bruksgardens-forskola/cal...
# 1     https://skolmaten.se/inspiration-och-menyforsl...
# 2                   https://skolmaten.se/amb2/calendar/
# 3                     https://skolmaten.se/aq/calendar/
# 4     https://skolmaten.se/abborrvagens-forskola2/ca...
# ...                                                 ...
# 5499       https://skolmaten.se/oxabackskolan/calendar/
# 5500    https://skolmaten.se/oxeryds-forskola/calendar/
# 5501   https://skolmaten.se/oxeryds-forskola2/calendar/
# ...

# %%
dfdist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5504 entries, 0 to 5503
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   lang                     5504 non-null   object
#  1   distributorID            5504 non-null   object
#  2   iCalendar                5504 non-null   object
#  3   name                     5504 non-null   object
#  4   address.addressCountry   5504 non-null   object
#  5   address.addressRegion    5504 non-null   object
#  6   address.addressLocality  5504 non-null   object
# dtypes: object(7)
# memory usage: 301.1+ KB

# %%
dfdist["address.addressRegion"].value_counts()
# Out:
# Västra Götalands län    1462
# Skåne län                803
# Stockholms län           779
# Jönköpings län           288
# Hallands län             239
# Östergötlands län        237
# Södermanlands län        232
# Västerbottens län        172
# Västmanlands län         167
# Norrbottens län          151
# Örebro län               150
# Värmlands län            133
# Blekinge län             126
# Kalmar län               121
# Gävleborgs län           105
# Västernorrlands län       89
# Dalarnas län              76
# Jämtlands län             64
# Uppsala län               56
# Kronobergs län            52
# Gotlands län               2
# Name: address.addressRegion, dtype: int64

# %%
pd.set_option("display.max.rows", None) 
dfdist["address.addressLocality"].value_counts()
# Out:
# Umeå kommun                                  149
# Stockholms stad                              139
# Jönköpings kommun                            134
# Västerås stad                                133
# Helsingborgs stad                            129
# Borås stad                                   124
# Kristianstads kommun                         103
# Göteborgs Stad - Sydväst Förskolor           102
# Huddinge kommun                               99
# Malmö stad                                    94
# Eskilstuna kommun                             93
# Kungsbacka kommun                             89
# Göteborgs Stad - Nordost Förskolor            88
# Lunds kommun                                  87
# Varbergs kommun                               86
# Karlskrona kommun                             82
# Linköpings kommun                             81
# Örebro kommun                                 78
# Botkyrka kommun                               72
# ...

# %%
dfdist.nunique(axis=0)
# Out:
# lang                          1
# distributorID              5504
# iCalendar                  5504
# name                       5039
# address.addressCountry        1
# address.addressRegion        21
# address.addressLocality     281
# dtype: int64

# %%
end = datetime.now()
print("Ended: ", end) 
print('Time elapsed (hh:mm:ss.ms) {}'.format(datetime.now() - start_time))
# Out:
# Ended:  2022-06-10 08:59:05.502522
# Time elapsed (hh:mm:ss.ms) 0:00:04.759080

# %% [markdown]
# ## Hämta mat serverad
# går ej eftersom nyckel behövs... dock finns [exempel](https://skolmaten.se/about/api/#applikation)

# %%
urlskolmat = "https://skolmaten.se/api/openmeal/v2/menu.json?client=TestNotebook"
r_skolmat = http.request('GET', urlskolmat)
try:
    dataMat = json.loads(r_skolmat.data)
    dfMat = pd.json_normalize(dataMat["data"])
except Exception as e: print(e)
# Out:
# Extra data: line 1 column 5 (char 4)

# %% [markdown]
# Fungerar ej måste ha en client token

# %% [markdown]
# * maträtter är textsträngar
# * en maträtt verkar inte ha en bild
# * saknas samma som för en maträtt så man kan analysera det vidare ...
#   * med "samma som" och inte textsträngar
#     * skulle man kunna
#        * analysera innehållet i maten
#        * jämföra likvärdiga maträtter i olika skolor
#        * kanske kunna se vad vi får för våra skattekronor då det gäller skolmat/näringeinnehåll
#        * om matsvinnet har en koppling till maträtten eller skolan eller?
#        * bygga upp ett bildbibliotek med skolmaträtter

# %% [markdown]
# Exempel från [dokumentationen](https://skolmaten.se/about/api/#applikation)
#
# ```
# HTTP/1.1 200 OK
# Last-Modified: Mon, 07 Mar 2016 19:05:38 GMT
# Expires: Mon, 31 Oct 2016 11:46:52 GMT
#
# {
#   "weeks": [
#     {
#       "year": 2016,
#       "number": 46,
#       "days": [
#         {
#           "date": 1479081600,
#           "meals": [
#             {
#               "value": "Korvgryta, ris",
#               "attributes": []
#             },
#             {
#               "value": "Vegetarisk korvgryta, ris",
#               "attributes": [1]
#             }
#           ]
#         },
#         {
#           "date": 1479168000,
#           "meals": [
#             {
#               "value": "Kycklingwok, matvete/ris",
#               "attributes": []
#             },
#             {
#               "value": "Bulgurpytt med bönor, kall sås",
#               "attributes": []
#             }
#           ]
#         },
#         {
#           "date": 1479254400,
#           "items": [
#             "Köttbullar, tomatsås, makaroner",
#             "Minibouletter, sås, makaroner"
#           ]
#         }
#       ]
#     }
#   ],
# ```

# %% [markdown]
# ## Spec version 3.0
#
# Hittar inte specen men ett [exempel hos sambruk GITHUB](https://sambruk.github.io/Open-Meal/openapi-specification/)
#
# ```
# "meals": [
#   {
#    "date": "2015-05-20T00:00:00",
#    "lang": "en",
#    "name": "Lunch",
#    "description": "Swedish Food Week",
#    "courses": [
#      {
#        "name": "Swedish Meatballs with mashed potatoes",
#        "order": 1,
#        "ingredients": "Meat, bread crumbs, eggs, milk, potatoes",
#        "allergens": [
#           "Egg",
#           "Milk",
#           "Nuts"
#           ],
#        "nutrients": [
#           {
#             "name": "Energy",
#             "amount": "540",
#             "unit": "kcal"
#           }
#         ]
#      }
#    ]
# ```
#
# ### Min fundering kring specen jag hitta
# 1. "ingredients" som text strängar på engelska borde vara "samma som" så man kan analysera maten
# 1. "allergens" även det textsträngar på engelska....
# 1. exemplet ovan med textsträngar verkar enormt hafsigt med **ingredients** som en textsträng med komma mellan olika ingridienser, medan allergens är en array ....

# %% [markdown]
# ### Hur borde man tänkt?
#
# ![](https://upload.wikimedia.org/wikipedia/commons/7/72/5-star_deployment_scheme_for_Open_Data.png)
#
# 1. inga text strängar och peka "samma som" så man kan analysera maträtten mera... dvs, **[5 star open data](https://5stardata.info/en/)**
#   1. vet ej vad som är bra finns initiativ som att [se.openfoodfacts.org](https://se.openfoodfacts.org/) att första specandet av sbensk skolmat verkar ha gjorts redan [2015](https://youtu.be/JEc6vuys17c?t=1319)  så man borde kanske kunnat under dessa 7 år ta fram en egen databas med skolmat som innehåller näring, allergener, bilder....
# 1. skolmats specandet [verkar startat 2015 med pengar från Vinnova](https://youtu.be/JEc6vuys17c?t=1319) och det borde finnas enklare sätt att lämna input eller se feedback som ges på [twitter](https://twitter.com/Landgren/status/1446155666117304330?s=20&t=L4s0-FwJw84klDiDm8171Q) att öppna skoldataplattformen vill ha bilder borde tas om hand lite mera strukturerat och kunna följas vad som händer eller inte händer...
#   1. använda tydlig versionshantering med datum på specar
#   1. ha en plats där alla synpunkter samlas in nu försvinner dom på [twitter](https://twitter.com/Landgren/status/1446155666117304330?s=20&t=L4s0-FwJw84klDiDm8171Q)
#   1. enkelt att se skillnad mellan olika versioner av specar
#   1. att redan i specandet ange hur [metadata skall laddas på svenska portalen/ europeiska portalen](https://community.dataportal.se/topic/364/kategorier-av-%C3%B6ppna-data/10) dagens ide att skapa nya "unika" dataset för varje kommun och att man inte enkelt kan hitta allt öppna data för en specifik skola är dålig design
#   1. definiera upp användarfall
#      1. gissar dagens lösning fungerar i vardagen att se att imorgon är det köttbullar
#      1. dagens lösning fungerar inte för användarfall som
#         1. att få en bild över näringsinnehållet på mat som serveras
#         1. att enkelt jmf olika skolor då datat inte har [skolverkets id](https://www.scb.se/lamna-uppgifter/undersokningar/Skolenhetsregistret/)
#            1. kanske intressant se matinnehåll vs. hur eleverna presterar på nationella prov, matsvinn, skattesats i kommunen vs. mat som serveras, socialgrupp som bor i området och mat som levereras, brottslighete vs. mat som serveras....
#         1. att presentera skolmaten på barnets hemspråk så att även föräldrar utan svenska kunskaper kan se vad barnet äter i skolan... (är idag tyvärr vanligt att i utsatta områden är språkkunskaperna så dåliga att läraren måste ha tolk på föräldrarsamtalen...)
#         1. att ha en bilddatabas med skolmaträtterna som kan användas
