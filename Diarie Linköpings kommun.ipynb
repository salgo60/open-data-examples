# %% [markdown]
# ## Diarie Linköpings kommun
# * Denna [Jupyter Notebook](https://github.com/salgo60/open-data-examples/blob/master/Diarie%20Link%C3%B6pings%20kommun.ipynb)
#
# * om [ärenden Linköping](https://www.linkoping.se/open/data/arende/)
#
# OBS unik nyckel måste begäras se [open](https://www.linkoping.se/open/)
#
# GITHUB [open-data-examples](https://github.com/salgo60/open-data-examples)

# %%
from IPython.display  import JSON
import requests
import json
key = "e4628c0b272a454f855ec3784b7b61a0"
baseUrl = "http://arendedata.linkoping.se/api/v1/"
endpoint = "Cases?maxItemsInResult=1000&api_key="
headers = {'content-type': 'application/json'}
url = baseUrl + endpoint + key
url
# Out:
# 'http://arendedata.linkoping.se/api/v1/Cases?maxItemsInResult=1000&api_key=e4628c0b272a454f855ec3784b7b61a0'

# %%
req = requests.get(url,headers=headers)
data = json.loads(req.text)
import pandas as pd
df = pd.DataFrame(data)
df.head(n=40) 
req
# Out:
# <Response [200]>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df
# Out:
#        caseNumber  ... hasEvents
# 0    SON 2020-984  ...      True
# 1    SON 2020-983  ...      True
# 2     ÄN 2020-752  ...      True
# 3     ÄN 2020-751  ...     False
# 4     ÄN 2020-750  ...      True
# ..            ...  ...       ...
# 995   ÄN 2020-632  ...      True
# 996   ÄN 2020-631  ...      True
# 997   ÄN 2020-630  ...     False
# 998   ÄN 2020-629  ...      True
# 999  SON 2020-814  ...      True
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Ärenden

# %%
endpointEvent = "Events?maxItemsInResult=1000&api_key=f3d212d2700f4c80aba7d2a88bc94529"
urlEvent = baseUrl + endpointEvent 
dataEvent = json.loads(requests.get(urlEvent).text)
import pandas as pd
dfEvent = pd.DataFrame(dataEvent)
dfEvent.head(n=100)
# Out:
#         eventNumber  ... documentNumber
# 0    ÄN 2020-699: 2  ...              2
# 1   ÄN 2020-650: 10  ...             10
# 2   SON 2020-984: 1  ...              1
# 3    ÄN 2020-650: 9  ...              9
# 4    ÄN 2020-650: 8  ...              8
# ..              ...  ...            ...
# 95  ÄN 2018-291: 12  ...             12
# 96   ÄN 2019-578: 8  ...              8
# 97  ÄN 2018-826: 27  ...             27
# 98   ÄN 2020-727: 3  ...              3
# 99  ÄN 2020-154: 19  ...             19
#
# [100 rows x 11 columns]

# %%
pd.set_option('display.max_rows', None) 
dfEvent["senderOrReceiver"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'dict'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'dict'
# {'name': '', 'organization': None}                                             245
# {'name': '', 'organization': 'Kommunledningsförvaltningen'}                     11
# {'name': '', 'organization': ''}                                                 9
# {'name': '', 'organization': 'Länsstyrelsen Östergötland'}                       9
# {'name': '', 'organization': 'Länsstyrelsen i Östergötland'}                     8
# {'name': '', 'organization': 'mos/mex'}                                          7
# {'name': '', 'organization': 'Samverkan Östergötland'}                           5
# {'name': '', 'organization': 'Lönecenter'}                                       4
# {'name': '', 'organization': 'Tekniska verken i Linköping AB'}                   4
# {'name': '', 'organization': 'Samhällsbyggnadsnämnden'}                          4
# {'name': '', 'organization': 'Bygg- och miljönämnden'}                           3
# {'name': '', 'organization': 'Trafikverket'}                                     3
# {'name': '', 'organization': 'Omsorg o äldrenämnd'}                              2
# {'name': '', 'organization': 'Grafiska museet i Gamla Linköping'}                2
# {'name': '', 'organization': 'Sweco Environment AB'}                             2
# {'name': '', 'organization': 'Överförmyndarenheten'}                             2
# {'name': '', 'organization': 'Barn- och ungdomsnämnden'}                         2
# {'name': '', 'organization': 'Förvaltningsrätten i Linköping'}                   2
# {'name': '', 'organization': 'Landerydskliniken'}                                2
# {'name': '', 'organization': 'Arbetsmarknadsnämnden'}                            2
# {'name': '', 'organization': 'Tekniska Verken i Linköping AB'}                   2
# {'name': '', 'organization': 'Vinnova'}                                          2
# {'name': '', 'organization': 'Länsstyrelsen'}                                    2
# {'name': '', 'organization': 'Lerboga Ekbackens Samfällighetsförening'}          2
# {'name': '', 'organization': 'Helsingborgs stad'}                                1
# {'name': '', 'organization': 'Euler Hermes Sverige filial'}                      1
# {'name': '', 'organization': 'Åklagarmyndigheten'}                               1
# {'name': '', 'organization': 'Kultur- och fritidskontoret'}                      1
# {'name': '', 'organization': 'Tyréns AB'}                                        1
# {'name': '', 'organization': 'Centrumförvaltning AB'}                            1
# {'name': '', 'organization': 'Polismyndigheten'}                                 1
# {'name': '', 'organization': 'Fackförbund och arbetsgivare'}                     1
# {'name': '', 'organization': 'Försvarsmakten'}                                   1
# {'name': '', 'organization': 'Stångåstaden'}                                     1
# {'name': '', 'organization': 'AB Göta kanalbolag'}                               1
# {'name': '', 'organization': 'Lönecenter '}                                      1
# {'name': '', 'organization': 'Länsstyrelsen i Stockholm & Sametinget'}           1
# {'name': '', 'organization': 'Tekniska verken'}                                  1
# {'name': '', 'organization': 'KFUM Linköping'}                                   1
# {'name': '', 'organization': 'Ekonomidirektör'}                                  1
# {'name': '', 'organization': 'Sweco Society AB'}                                 1
# {'name': '', 'organization': 'Bygg- och miljönämnden, Lkpg kommun'}              1
# {'name': '', 'organization': 'Miljö- och samhällsbyggnadsförvaltningen'}         1
# {'name': '', 'organization': 'Ledbergs hembygdsförening'}                        1
# {'name': '', 'organization': 'Myndigheten för samhällsskydd och beredskap'}      1
# {'name': '', 'organization': 'Kommunens revisorer'}                              1
# {'name': '', 'organization': 'RTOG'}                                             1
# {'name': '', 'organization': 'Utsikt Bredband AB'}                               1
# {'name': '', 'organization': '8220023009'}                                       1
# {'name': '', 'organization': 'Förvaltningsrådet Linköpings skyttecentrum'}       1
# {'name': '', 'organization': 'Lejonfastigheter AB'}                              1
# {'name': '', 'organization': 'Mark- och miljödomstolen Växjö Tingsrätt'}         1
# {'name': '', 'organization': 'Länsstyrelsen i Stockholm och Sametinget'}         1
# {'name': '', 'organization': 'Lantmäterimyndigheten'}                            1
# {'name': '', 'organization': 'White Arkitekter AB'}                              1
# {'name': '', 'organization': 'Ramböll Sverige AB'}                               1
# {'name': '', 'organization': 'Boxholms Kommun'}                                  1
# {'name': '', 'organization': 'Uppsala universitet'}                              1
# {'name': '', 'organization': 'Svefa AB'}                                         1
# {'name': '', 'organization': 'WSP Sverige AB'}                                   1
# {'name': '', 'organization': 'Structor Miljö Öst AB'}                            1
# {'name': '', 'organization': 'Leanlink'}                                         1
# {'name': '', 'organization': 'Bildningsnämnden'}                                 1
# {'name': '', 'organization': 'Regeringskansliet'}                                1
# {'name': '', 'organization': 'Hyres- och Arrendenämnden i Linköping'}            1
# {'name': '', 'organization': 'Växjö Tingsrätt, Mark och miljödomstolen'}         1
# Name: senderOrReceiver, dtype: int64
