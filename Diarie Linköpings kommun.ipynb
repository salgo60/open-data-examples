# %% [markdown]
# ## Diarie Linköpings kommun
# * Denna [Jupyter Notebook](https://github.com/salgo60/open-data-examples/blob/master/Diarie%20Link%C3%B6pings%20kommun.ipynb)
#
# * om [ärenden Linköping](https://www.linkoping.se/open/data/arende/)
#
# OBS unik nyckel måste begäras se [open](https://www.linkoping.se/open/)
#
# GITHUB [open-data-examples](https://github.com/salgo60/open-data-examples)

# %%
from IPython.display  import JSON
import requests
import json
key = "e4628c0b272a454f855ec3784b7b61a0"
baseUrl = "http://arendedata.linkoping.se/api/v1/"
endpoint = "Cases?maxItemsInResult=1000&api_key="
headers = {'content-type': 'application/json'}
url = baseUrl + endpoint + key
url
# Out:
# 'http://arendedata.linkoping.se/api/v1/Cases?maxItemsInResult=1000&api_key=e4628c0b272a454f855ec3784b7b61a0'

# %%
req = requests.get(url,headers=headers)
data = json.loads(req.text)
import pandas as pd
df = pd.DataFrame(data)
df.head(n=40) 
req
# Out:
# <Response [200]>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df
# Out:
#        caseNumber                                            subject  \
# 0    SBN 2021-603              Nya och upprustning av upplagsplatser
# 1    SBN 2021-602  Utbyggnad av allmän plats i Berg för Kungsbro ...
# 2    SBN 2021-601                          Hjälmparken Gottfridsberg
# 3    SBN 2021-600                        Gång- och cykelväg Bogestad
# 4    SBN 2021-599                   Eventsäkring el allmänna platser
# ..            ...                                                ...
# 995  SBN 2021-413  Lokalisering av ny regionaltågsstation i Malms...
# 996   ÄN 2021-217  Avvikelse kommun till region östergötland Vret...
# 997  BIN 2021-316                                  Kontantersättning
# 998  SON 2021-537         Begäran ur socialregistret -kriminalvården
# 999  SON 2021-536        Begäran ur socialregistret - Kriminalvården
#
#               registeredDate           closedDate     diary  hasEvents
# 0        2021-06-08T15:34:00                 None  SBN 2021      False
# 1        2021-06-08T15:32:00                 None  SBN 2021      False
# 2        2021-06-08T15:31:00                 None  SBN 2021      False
# 3        2021-06-08T15:29:00                 None  SBN 2021      False
# 4        2021-06-08T15:28:00                 None  SBN 2021      False
# ..                       ...                  ...       ...        ...
# 995      2021-04-19T13:52:00  2021-04-19T00:00:00  SBN 2021       True
# 996      2021-04-19T13:37:00                 None   ÄN 2021       True
# 997  2021-04-19T13:24:19.203                 None  BIN 2021       True
# 998      2021-04-19T13:23:00  2021-04-19T14:28:00  SON 2021       True
# 999      2021-04-19T13:10:00  2021-04-19T14:27:00  SON 2021       True
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Ärenden

# %%
endpointEvent = "Events?maxItemsInResult=1000&api_key=f3d212d2700f4c80aba7d2a88bc94529"
urlEvent = baseUrl + endpointEvent 
dataEvent = json.loads(requests.get(urlEvent).text)
import pandas as pd
dfEvent = pd.DataFrame(dataEvent)
dfEvent.head(n=100)
# Out:
#           eventNumber                                          eventName  \
# 0      KS 2020-605: 6                     KS beslut i korthet 2021-06-08
# 1      KS 2020-605: 5                     KS beslut i korthet 2021-06-08
# 2    SBN 2015-284: 30                           PM Trafik Djurgårdsgatan
# 3    SBN 2017-478: 39                           PM Trafik Djurgårdsgatan
# 4       AN 2021-76: 2  Registerutdrag , Kontrollnummer: 210607-Regist...
# ..                ...                                                ...
# 95  BOU 2021-338: 216                 Placering Björkö friskola - Avslag
# 96  BOU 2021-338: 215                          Placering Ljungsbro skola
# 97     BOU 2021-62: 3  Förhandsgranska rapport tillsyn förskolan skog...
# 98   BOU 2021-182: 28                                  Delgivningskvitto
# 99     BOU 2021-62: 2  Mail - Förhandsgranska rapport tillsyn förskol...
#
#    direction                     date              eventType senderOrReceiver  \
# 0         In      2021-06-08T16:45:00  Kallelse, publicering             None
# 1         In   2021-06-08T16:38:31.92              Skrivelse             None
# 2        Upp  2021-06-08T16:27:31.443              Utredning             None
# 3        Upp  2021-06-08T16:25:47.643              Utredning             None
# 4         In  2021-06-08T16:10:11.983              Skrivelse             None
# ..       ...                      ...                    ...              ...
# 95        Ut      2021-06-08T10:58:00      Beslut Delegation             None
# 96        Ut      2021-06-08T10:56:00      Beslut Delegation             None
# 97        Ut  2021-06-08T10:54:26.043              Skrivelse             None
# 98        In  2021-06-08T10:51:13.667              Skrivelse             None
# 99        Ut   2021-06-08T10:49:35.86              Skrivelse             None
#
#                                                  case    caseNumber  \
# 0                              Kommunstyrelsen 210608   KS 2020-605
# 1                              Kommunstyrelsen 210608   KS 2020-605
# 2    Detaljplan för Smedstad 1:18 (Ryttargårdskyrkan)  SBN 2015-284
# 3   Detaljplan i Östra Valla för del av Idrottsför...  SBN 2017-478
# 4   Registerutdrag , Kontrollnummer: 210607-Regist...    AN 2021-76
# ..                                                ...           ...
# 95    Skolplaceringar bytesperiod 1 läsåret 2021/2022  BOU 2021-338
# 96    Skolplaceringar bytesperiod 1 läsåret 2021/2022  BOU 2021-338
# 97             Rapport tillsyn - Förskolan Skogsmyran   BOU 2021-62
# 98  Statsbidrag - Förstärkt stöd till skolväsendet...  BOU 2021-182
# 99             Rapport tillsyn - Förskolan Skogsmyran   BOU 2021-62
#
#                        diary  diaryId  documentNumber
# 0            Kommunstyrelsen       56               6
# 1            Kommunstyrelsen       56               5
# 2    Samhällsbyggnadsnämnden      118              30
# 3    Samhällsbyggnadsnämnden      118              39
# 4      Arbetsmarknadsnämnden      214               2
# ..                       ...      ...             ...
# 95  Barn- och ungdomsnämnden       26             216
# 96  Barn- och ungdomsnämnden       26             215
# 97  Barn- och ungdomsnämnden       26               3
# 98  Barn- och ungdomsnämnden       26              28
# 99  Barn- och ungdomsnämnden       26               2
#
# [100 rows x 11 columns]

# %%
pd.set_option('display.max_rows', None) 
dfEvent["senderOrReceiver"].value_counts()
# Out:
# Series([], Name: senderOrReceiver, dtype: int64)
